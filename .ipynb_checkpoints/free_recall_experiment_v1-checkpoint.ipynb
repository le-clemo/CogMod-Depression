# %% [markdown]
# ## Backup Reminder : DO IT!

# %%
# All the necessary imports
import actr
import pickle
import random
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from itertools import groupby
# Out:
# ACT-R connection has been started.

# %%
help(actr)
# Out:
# Help on module actr:
#
# NAME
#     actr
#
# CLASSES
#     builtins.object
#         actr
#         interface
#         request
#
#     class actr(builtins.object)
#      |  actr(host, port)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, host, port)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  add_command(self, name, function, documentation='No documentation provided.', single=True, actr_name=None)
#      |
#      |  evaluate(self, *params)
#      |
#      |  evaluate_single(self, *params)
#      |
#      |  monitor_command(self, original, monitor)
#      |
#      |  remove_command(self, name)
#      |
#      |  remove_command_monitor(self, original, monitor)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class interface(builtins.object)
#      |  interface(host, port)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, host, port)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  add_command(self, name, function)
#      |
#      |  collect_data(self)
#      |
#      |  echo_output(self)
#      |
#      |  no_output(self)
#      |
#      |  output_monitor(self, string)
#      |
#      |  process_message(self, d)
#      |
#      |  run_command(self, command, command_name, model, id, params)
#      |
#      |  send(self, method, *params)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class request(builtins.object)
#      |  request(id)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, id)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  notify_result(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FUNCTIONS
#     act_r_output(output)
#
#     add_button_to_exp_window(window, text='', x=0, y=0, action=None, height=20, width=75, color='gray')
#
#     add_command(name, function=None, documentation='No documentation provided.', single=True, local_name=None)
#
#     add_dm(*chunks)
#
#     add_dm_fct(chunks)
#
#     add_image_to_exp_window(window, text, file, x=0, y=0, width=50, height=50, action=None)
#
#     add_items_to_exp_window(window, *items)
#
#     add_line_to_exp_window(window, start, end, color=False)
#
#     add_text_to_exp_window(window, text, x=0, y=0, color='black', height=20, width=75, font_size=12)
#
#     add_visicon_features(*features)
#
#     all_productions()
#
#     buffer_chunk(*params)
#
#     buffer_read(buffer)
#
#     buffer_status(*params)
#
#     buffers()
#
#     chunk_copied_from(chunk_name)
#
#     chunk_p(chunk_name)
#
#     chunk_slot_value(chunk_name, slot_name)
#
#     chunk_spec_to_chunk_def(spec_id)
#
#     clear_buffer(buffer)
#
#     clear_exp_window(win=None)
#
#     command_output(string)
#
#     connection()
#
#     copy_chunk(chunk_name)
#
#     correlation(results, data, output=True)
#
#     create_image_for_exp_window(window, text, file, x=0, y=0, width=50, height=50, action=None)
#
#     current_model()
#
#     define_chunk_spec(*spec)
#
#     define_chunks(*chunks)
#
#     define_chunks_fct(chunks)
#
#     define_module(name, buffers, params, interface=None)
#
#     delete_all_visicon_features()
#
#     delete_chunk(name)
#
#     delete_visicon_features(*features)
#
#     dm(*params)
#
#     extend_possible_slots(slot_name, warn=True)
#
#     get_history_data(history, *params)
#
#     get_parameter_value(param)
#
#     get_system_parameter_value(param)
#
#     get_time(model_time=True)
#
#     goal_focus(goal=None)
#
#     hide_output()
#
#     history_data_available(history, file=False, *params)
#
#     install_device(device)
#
#     load_act_r_code(path)
#
#     load_act_r_model(path)
#
#     mean_deviation(results, data, output=True)
#
#     mod_chunk(chunk_name, *mods)
#
#     mod_focus(*mods)
#
#     model_output(output_string)
#
#     modify_line_for_exp_window(line, start, end, color=False)
#
#     modify_visicon_features(*features)
#
#     modules_parameters(module)
#
#     modules_with_parameters()
#
#     monitor_command(original, monitor)
#
#     mp_models()
#
#     mp_show_queue(indicate_traced=False)
#
#     mp_time()
#
#     mp_time_ms()
#
#     new_digit_sound(digit, onset=False, time_in_ms=False)
#
#     new_tone_sound(freq, duration, onset=False, time_in_ms=False)
#
#     new_word_sound(word, onset=False, location='external', time_in_ms=False)
#
#     open_exp_window(title, visible=True, width=300, height=300, x=300, y=300)
#
#     pbreak(*params)
#
#     pdisable(*params)
#
#     penable(*params)
#
#     permute_list(l)
#
#     pp(*params)
#
#     pprint_chunks(*chunks)
#
#     predict_bold_response(start=None, end=None, output=None)
#
#     print_activation_trace(time, ms=True)
#
#     print_audicon()
#
#     print_chunk_activation_trace(chunk, time, ms=True)
#
#     print_dm_finsts()
#
#     print_visicon()
#
#     print_warning(warning)
#
#     printed_audicon()
#
#     printed_parameter_details(param)
#
#     printed_visicon()
#
#     process_events()
#
#     process_history_data(processor, file=False, data_params=None, processor_params=None)
#
#     punbreak(*params)
#
#     purge_chunk(name)
#
#     random(value)
#
#     record_history(*params)
#
#     release_chunk_spec(spec_id)
#
#     reload(compile=False)
#
#     remove_command(name)
#
#     remove_command_monitor(original, monitor)
#
#     remove_items_from_exp_window(window, *items)
#
#     reset()
#
#     resume_output()
#
#     run(time, real_time=False)
#
#     run_full_time(time, real_time=False)
#
#     run_n_events(event_count, real_time=False)
#
#     run_until_condition(condition, real_time=False)
#
#     run_until_time(time, real_time=False)
#
#     running()
#
#     save_history_data(history, file, comment='', *params)
#
#     saved_activation_history()
#
#     schedule_break_relative(time_delay, time_in_ms=False, priority=':max', details=None)
#
#     schedule_event(time, action, params=None, module=':NONE', priority=0, maintenance=False, destination=None, details=None, output=True, time_in_ms=False, precondition=None)
#
#     schedule_event_after_module(after_module, action, params=None, module=':NONE', maintenance=False, destination=None, details=None, output=True, precondition=None, dynamic=False, delay=True, include_maintenance=False)
#
#     schedule_event_now(action, params=None, module=':NONE', priority=0, maintenance=False, destination=None, details=None, output=True, precondition=None)
#
#     schedule_event_relative(time_delay, action, params=None, module=':NONE', priority=0, maintenance=False, destination=None, details=None, output=True, time_in_ms=False, precondition=None)
#
#     schedule_mod_buffer_chunk(buffer, mod_list_or_spec, time, module=':NONE', priority=0, output='low', time_in_ms=False)
#
#     schedule_set_buffer_chunk(buffer, chunk, time, module=':NONE', priority=0, output='low', time_in_ms=False, requested=True)
#
#     schedule_simple_mod_buffer_chunk(buffer, mod_list_or_spec, time, module='NONE', priority=0)
#
#     schedule_simple_set_buffer_chunk(buffer, chunk, time, module='NONE', priority=0, requested=True)
#
#     sdm(*params)
#
#     sdp(*params)
#
#     set_buffer_chunk(buffer_name, chunk_name, requested=True)
#
#     set_chunk_slot_value(chunk_name, slot_name, new_value)
#
#     set_current_model(name)
#
#     set_parameter_value(param, value)
#
#     set_system_parameter_value(param, value)
#
#     simulate_retrieval_request(*spec)
#
#     sorted_module_names()
#
#     spp(*params)
#
#     start(host=None, port=None)
#
#     start_hand_at_mouse()
#
#     stop()
#
#     stop_output()
#
#     stop_recording_history(*params)
#
#     trigger_reward(reward, maintenance=False)
#
#     undefine_module(name)
#
#     unhide_output()
#
#     used_production_buffers()
#
#     whynot(*params)
#
#     whynot_dm(*params)
#
# DATA
#     current_connection = <actr.actr object>
#     locals = <_thread._local object>
#
# FILE
#     c:\users\cleme\documents\education\rug\first-year_research\my_project\model\actr.py

# %% [markdown]
# ## Experiment Logs
#     - 10th June 2020: 06:50am
#         - Testing the plotting function.
#         - Backing up the code to github: Done

# %% [markdown]
# ## Control Flow Logs
#     - Flow of the program in simple words
#         -Need to understand the ACT-R Model first
#     - Data Structures, their shapes and the purpose of their existence

# %% [markdown]
# #### Word lists do not contain actual words?
#     No they don't, we will do this in later experiment
# #### Number of words in each list i.e. list_length should be n where (n-2)%3 == 0 because 2 neutral words are added in each list.
#
# #### The adjustable parameters in this experiment code.
#     - Number of lists
#     - Number of words in each list
#     - The time taken for rehearsal (6 + delay of .5 seconds) and recall(10)
# #### Adjustable parameters in ACT-R
#     - :declarative-num-finsts 21 ; number of items that are kept as recently retrieved (Change it to 5)
#     - :declarative-finst-span 21 ; how long items stay in the recently-retrieved state (5,100)

# %%
### Experiment part ###

subject = ''

current_list = ''

recalled_words = defaultdict(list)

rehearsed_words =  defaultdict(lambda: defaultdict(int))

list_amount = 1    # No of lists

list_length = 83    # No of words in a list

rehearsal_time = 6  # No of seconds for which rehearsal happens and each word is shown

delay = 0.1  #delay between rehearsal and recall

recall_time = 10

# %%
word_lists_dict = defaultdict(list)

# Ensure there are enough unique words to create the word lists
word_dict = {"positive": ["positive" + str(i) for i in range(999)],
             "negative": ["negative" + str(i) for i in range(999)],
             "neutral": ["neutral" + str(i) for i in range(999)]}

# %%
def add_words(i, list_length):
    '''
    Add the words to the word lists, ensures valence categories are balanced
    '''
    global word_lists_dict

    amnt_wanted = (list_length -2)/3   # Amount of each valence wanted, minus 2 neutrals controlling for primacy
    amt_positive, amt_negative, amt_neutral, count = 0, 0, 0, 0
    while len(word_lists_dict[i]) != list_length:
        count += 1
        #print(f"...................{count,word_lists_dict[i]}")
        if count >= 9999: # IF it takes too long to create a unique list at random, start over
            word_lists_dict[i] = []
            add_words(i, list_length)
        if len(word_lists_dict[i]) == 0: # Place two neutral words at the start to control for primacy effects
            word_to_add1 = word_dict["neutral"][random.randint(0, len(word_dict["neutral"])-1)]
            word_to_add2 = word_dict["neutral"][random.randint(0, len(word_dict["neutral"])-1)]
            if word_to_add1 not in word_lists_dict[i] and word_to_add2 not in word_lists_dict[i] and word_to_add1 != word_to_add2:
                word_lists_dict[i].append(word_to_add1)
                word_lists_dict[i].append(word_to_add2)
            else:
                continue # skip this loop iteration                   
        else: 
            random_valence = random.choice(["positive", "negative", "neutral"])
            word_to_add = word_dict[random_valence][random.randint(0, len(word_dict[random_valence])-1)]
            if word_to_add not in word_lists_dict[i] and word_lists_dict[i][-1] not in word_dict[random_valence] and \
               amt_positive <= amnt_wanted and amt_negative <= amnt_wanted and amt_neutral <= amnt_wanted:
                if random_valence == "positive" and amt_positive < amnt_wanted:
                    amt_positive += 1
                elif random_valence == "negative" and amt_negative < amnt_wanted:
                    amt_negative +=1
                elif random_valence == "neutral" and amt_neutral < amnt_wanted:
                    amt_neutral +=1
                else:
                    continue # skip this loop iteration
                word_lists_dict[i].append(word_to_add)

# %%
def create_lists(list_amount=3, list_length=2):
    '''
    Create the wordlists used during the free recall tasks 
    '''  
    global word_lists_dict 

    for i in range(list_amount):
        print(f'List {i+1}/{list_amount} created!', end="\r")
        add_words(i, list_length)

    # Save the dictionary to a .pickle file, so we do not have to create the word lists everytime we run the model                    
    file = open(f"word_lists\word_lists_dict_{list_length}_{list_amount}.pickle","wb")
    pickle.dump(word_lists_dict, file)
    file.close()
    return word_lists_dict

# %%
# Check if the word lists already exist, else create new word lists
try:
    file = open(f"word_lists\word_lists_dict_{list_length}_{list_amount}.pickle","rb")
    #file = open(f"word_lists_dict_100_items_only.pickle","rb")
    word_lists_dict = pickle.load(file)  
    file.close()
    print("\nSuccesfully loaded the word lists!\n")
except FileNotFoundError:
    print("\nCreating word lists!\n")
    #amount_to_create = list_amount                              
    word_lists_dict = create_lists(list_amount,list_length)
# Out:
# Succesfully loaded the word lists!

# %%
def display_word_lists():
    '''
    Display the word lists loaded/created
    '''
    for key, value in word_lists_dict.items():
        print(f'List {key}:\n {value}\n')

def close_exp_window():
    '''
    Close opened ACT-R window
    '''
    return actr.current_connection.evaluate_single("close-exp-window")

# %%
def prepare_for_recall(): 
    '''
    Disable rehearsing productions, and clearing buffer contents to start the recalling phase 
    '''
    disable_list = ["rehearse-first", "rehearse-second", "rehearse-third", "rehearse-fourth", 
                    "rehearse-it", "skip-first", "skip-second", "skip-third", "skip-fourth"]
    for prod in disable_list:
        actr.pdisable(prod)
    actr.run(1, False) 
    for buff in ["imaginal", "retrieval", "production"]:
        actr.clear_buffer(buff)

# %%
def setup_dm(word_list):
    '''
    Add words to declarative memory, since it can be assumed the test subjects know the English language already
    '''
    #print("\n\n############################################# Inside setup_dm i.e. Declarative Memory")
     
    colour_conversion = {'pos': 'GREEN', 'neg': 'RED', 'neu': 'BLACK'}
    for idx, word in enumerate(word_list):
        valence = ''.join([char for char in word if not char.isdigit()])[:3]
        actr.add_dm(('item'+str(idx), 'isa', 'memory', 'word', "'"+word+"'"))#, 'valence', colour_conversion[valence]))
#         if idx == 0:
#             print("\n Emaple of a chunk added in Declarative Memory is \n")
#             print('item'+str(idx), 'isa', 'memory', 'word', "'"+word+"'", 'valence', colour_conversion[valence],"\n")

# %%
def setup_experiment(human=True):
    '''
    Load the correct ACT-R model, and create a window to display the words
    '''
#     print("\n\n############################################# Inside setup_experiment")
#     print(f'\nSubject = {subject}\n')  

    loaded = None
    if subject == "controls":
        loaded = actr.load_act_r_model(r"C:\Users\cleme\Documents\Education\RUG\First-Year_Research\My_Project\Model\models\free_recall_regular_v1.lisp")
        #loaded = actr.load_act_r_model(r"C:\Users\cleme\Documents\Education\RUG\First-Year_Research\My_Project\Model\models\csm_free_recall_model_test.lisp")
    elif subject == "depressed":
        loaded = actr.load_act_r_model(r"C:\Users\cleme\Documents\Education\RUG\First-Year_Research\My_Project\Model\models\csm_free_recall_model_depressed.lisp")
    
    #print("\n\n############################################# Inside setup_experiment")
    #print(f'\nLoaded Act-r model = {loaded}\n')  



    window = actr.open_exp_window("Free Recall Experiment", width=1024, height=768, visible=human) # 15inch resolution window
    actr.install_device(window) 
    return window

# %%
def record_words_recalled(item):
    '''
    Register which words were recalled during the experiment for a specific wordlist and strip the numbers
    '''
    valence = ''.join(char for char in item if not char.isdigit())
    item_idx = ''.join(char for char in item if char.isdigit())
    recalled_words[current_list].append((valence, item_idx))

# %%
def create_result_dict():
    '''
    Use a module-level function, instead of lambda function, to enable pickling it
    '''
    return defaultdict(int)

# %%
def record_words_rehearsed(item):
    '''
    Register amount of rehearsals per word for each wordlist
    '''
    rehearsed_words[current_list][item] += 1

# %% [markdown]
# # Testing Creation of Plots which involves testing
#     - create_lplot(idx, xlabel, ylabel, x, y, xticks_len, filename, ytick_range=None, show=False)
#     - analysis(wlist_amount, show_plots=False)

# %%
def create_lplot(idx, xlabel, ylabel, x, y, xticks_len, filename, ytick_range=None, show=False):
    '''
    Create line plot using matplotlib
    Args:
        Input:
            -idx: The id of the type of plot to be made.
                  0: Rehearse Freuency
                  1: Starting Recall
                  2: Recall Probability
            -xlabel: Label for x-axis of the plot (Serial Input Position for this experiment).
            -ylabel: Label for y-axis of the plot (One of idx 0,1 or 2).
            -x: Serial Input Positions which depends on the length of the words list ex: range(1,20).
                shape: (1, list_length)
            -y: Values for the idx 0,1 or 2.
                shape: (list_length,)
            -xticks_len: length for ticks on x-axis, same as len(x)
            -filename: name for saving the file
            -ytick_range: length for ticks on y-axis, 0-1 for probabilities, None for rehearse frequency
            -show: To show the plot here or not.
        Output:
            Saved plots of rehearse frequency, starting recall and recall probability.
    '''
    plt.figure(idx)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.plot(x, y)
    plt.xticks(np.arange(0, xticks_len, 1)) 
    plt.yticks(ytick_range)
    plt.savefig("images/"+subject+"_"+filename, bbox_inches='tight')
    if show:
        plt.show()

# %%
def analysis(wlist_amount, show_plots=False):
    '''
    Review results of the recall experiment
    Args:
        Input:
            -wlist_amount: No of words inside each list
            -show_plots: Boolean to control the display of plots after experiment
        Output:
            -Saved plots for rehearse frequency, starting recall and recall probability after complete analysis.
    
    '''
    result_dict = defaultdict(create_result_dict) # instead of defaultdict(lambda: defaultdict(int))
    first_recall = defaultdict(int)
    recall_probability = defaultdict(int)
    rehearse_frequency = defaultdict(int)
    transitions_amnt = 0
    thought_train_len = []

    for key, val in recalled_words.items():
        thought_train_len.extend([(k, sum(1 for _ in count)) for k, count in groupby([val[0] for val in val[2:]])])
        for idx, (retrieved_word, item_num) in enumerate(val[2:]):
            if idx != 0:
                if retrieved_word != val[2:][idx-1][0]:
                    transitions_amnt += 1/wlist_amount # average over word lists

    print(f'Avg. Amount of recall transitions = {int(transitions_amnt)}')
    neg_thought_train_len = 0
    neg_divider = 0.0001
    for x in thought_train_len:
        if x[0] == 'negative':
            neg_divider += 1
            neg_thought_train_len += x[1]
    print(f'Avg. Negative Thought train length = {round(neg_thought_train_len/neg_divider, 3)}')            

    for list_num, wlist in word_lists_dict.items():
        if list_num < wlist_amount:
            for key, val in recalled_words.items():
                if key==list_num:
                    first_recall[wlist.index(''.join(val[0]))] += 1   
                    for idx, word in enumerate(wlist):
                        first_recall[idx] += 0
                        if ((''.join(char for char in word if not char.isdigit()), 
                             ''.join(char for char in word if char.isdigit()))) in val:
                            recall_probability[idx] += 1
                        else:
                            recall_probability[idx] += 0                            
                for retrieved_word, item_num in val[2:4]:
                    result_dict["pstart"][retrieved_word] += 1  
                for retrieved_word, item_num in val[4:-2]:
                    result_dict["pstay"][retrieved_word] += 1
                for retrieved_word, item_num in val[-2:]:
                    result_dict["pstop"][retrieved_word] += 1                                                        
            for key, val in rehearsed_words.items():
                if key==list_num:
                    for idx, word in enumerate(wlist):
                        rehearse_frequency[idx] += rehearsed_words[key][word]
    
    for key, val in first_recall.items():
        first_recall[key] = val/wlist_amount

    for key, val in recall_probability.items():
        recall_probability[key] = val/wlist_amount

    for key, val in rehearse_frequency.items():
        rehearse_frequency[key] = val/wlist_amount      

    xticks_len = len(word_lists_dict[0])
  
    create_lplot(0, 'Serial input position', 'Rehearse Frequency', range(len(word_lists_dict[0])), list(rehearse_frequency.values()), 
                xticks_len, f'v1_rehearse_frequency_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}.png', None, show_plots)

    create_lplot(1, 'Serial input position', 'Starting Recall', range(len(word_lists_dict[0])), list(first_recall.values()), 
                xticks_len, f'v1_starting_recall_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}.png', np.arange(0, .5, .1), show_plots)                

    create_lplot(2, 'Serial input position', 'Recall Probability', range(len(word_lists_dict[0])), list(recall_probability.values()), 
                xticks_len, f'v1_recall_probability_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}.png', np.arange(0, 1, .1), show_plots)   
    
#     create_lplot(3, 'Serial input position', 'Accuracy', range(len(word_lists_dict[0])), list(recall_accuracy.values()), 
#                 xticks_len, 'recall_accuracy.png', np.arange(0, 1, .1), show_plots) 

    file = open("results_"+subject+".pickle","wb")
    pickle.dump(result_dict, file)
    file.close()

    return result_dict

# %%
def do_experiment(subj="depressed", human=False, wlist_amount=2000):
    '''
    Run the experiment
    '''
    global subject
    subject = subj
    assert wlist_amount <= len(word_lists_dict), "Chosen too many lists, choose less or create more word lists using function: create_lists()"
    
#     print("###################################################\n")
#     print("The original word list \n")
#     print(display_word_lists())
    
    print("\n###################################################\n")
    print("Experiment started, Trying to understand the flow\n")
  
    for idx, (key, value) in enumerate(word_lists_dict.items()):
        actr.reset()
        print("ACT-R has been reset")
        print(actr.buffers())
        window = setup_experiment(human)
        actr.set_buffer_chunk("wm", "init", requested=True)
        
        #print(actr.buffer_chunk("wm"))
        
        print("Experiment has been set up!")
        
        global current_list
        current_list = idx # keep track for which list words are recalled
        setup_dm(value)
        
        actr.add_command("retrieved-word", record_words_recalled,"Retrieves recalled words.")
        actr.add_command("rehearsed-word", record_words_rehearsed,"Retrieves rehearsed words.")
        print("ACT-R.add_command has run")
#         print("\n##################  Model started rehearsal ")
        for word in value:
            if "neutral" in word:
                color = "black"
            elif "positive" in word:
                color = "green"
            else:
                color = "red"
            actr.add_text_to_exp_window(window, word, x=475-len(word) , y=374, color=color, font_size=20) # change later 
            actr.run(rehearsal_time, human) # True when choosing Human, False when choosing differently
            actr.clear_exp_window(window)
            actr.run(delay, human)  # 500-ms blank screen  
            
            
        print(actr.buffer_chunk("wm"))
        print(actr.dm())
        prepare_for_recall()       
        actr.remove_command("rehearsed-word")
#         print("\n##################  Model finished rehearsal, list of rehearsed words is ")
#         print(f'{rehearsed_words}\n')
#         print("\n##################  Model started recall ")
        actr.goal_focus("startrecall") # set goal to start recalling
        actr.run(recall_time, human)  
        actr.remove_command("retrieved-word")
#         print("\n##################  Model finished recall, list of recalled words is ")
#         print(f'{recalled_words}\n')
        print(f'Experiment {idx+1}/{wlist_amount} completed!', end="\r")
        if idx == wlist_amount-1: # run for a chosen number of word lists
            break
    close_exp_window() # close window at end of experiment 

    avg_recalled, avg_recalled_unique = 0, 0
    for key, val in recalled_words.items():
        avg_recalled += len(val)
        avg_recalled_unique += len(set(val))
    #    print(f'\nList {key} (length={len(val)}, unique={len(set(val))})')

    print("\n\n#############################################")
    print(f'\n[{subj}] Results!\n')  

    result = analysis(wlist_amount, False)        
    print(f'Avg. Amount of words recalled = {avg_recalled//wlist_amount}')
    print(f'Avg. Amount of unique words recalled = {avg_recalled_unique//wlist_amount}')

    for key, val in result.items():
        print(f'{key} = {dict(val)}')
    print()

# %%
# word_lists_dict[2],len(word_lists_dict)

# %%
do_experiment('controls',False,list_amount)
# Out:
# ###################################################
#
# Experiment started, Trying to understand the flow
#
# #|Warning: Chunk-type GOAL has the same specification as the chunk-type STUDY-WORDS. |#
# ACT-R has been reset
# ['WM', 'GOAL', 'TEMPORAL', 'AURAL', 'AURAL-LOCATION', 'MANUAL', 'VOCAL', 'RETRIEVAL', 'PRODUCTION', 'IMAGINAL', 'VISUAL', 'VISUAL-LOCATION', 'IMAGINAL-ACTION']
# #|Warning: Module WM already exists and cannot be redefined.  Delete it with undefine-module first if you want to redefine it. |#
# Experiment has been set up!
# ACT-R.add_command has run
#      0.000   GOAL                   SET-BUFFER-CHUNK GOAL GOAL NIL
#      0.000   VISION                 PROC-DISPLAY
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.000   VISION                 visicon-update
#      0.000   PROCEDURAL             CONFLICT-RESOLUTION
#      0.000   PROCEDURAL             PRODUCTION-SELECTED FIND-UNATTENDED-WORD
#      0.000   PROCEDURAL             BUFFER-READ-ACTION GOAL
#      0.050   PROCEDURAL             PRODUCTION-FIRED FIND-UNATTENDED-WORD
#      0.050   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#      0.050   PROCEDURAL             MODULE-REQUEST VISUAL-LOCATION
#      0.050   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.050   VISION                 Find-location
#      0.050   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0
#      0.050   VISION                 automatically attending VISICON-ID0
#      0.050   PROCEDURAL             CONFLICT-RESOLUTION
#      0.100   VISION                 Move-attention VISUAL-LOCATION0-1
#      0.100   PROCEDURAL             CONFLICT-RESOLUTION
#      0.185   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#      0.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.185   PROCEDURAL             CONFLICT-RESOLUTION
#      0.185   PROCEDURAL             PRODUCTION-SELECTED ATTEND-WORD
#      0.185   PROCEDURAL             BUFFER-READ-ACTION GOAL
#      0.185   PROCEDURAL             BUFFER-READ-ACTION VISUAL-LOCATION
#      0.185   PROCEDURAL             QUERY-BUFFER-ACTION VISUAL
#      0.235   PROCEDURAL             PRODUCTION-FIRED ATTEND-WORD
#      0.235   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#      0.235   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.235   PROCEDURAL             CONFLICT-RESOLUTION
#      0.235   PROCEDURAL             PRODUCTION-SELECTED HIGH-SECOND
#      0.235   PROCEDURAL             BUFFER-READ-ACTION GOAL
#
PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      9.908   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#      9.908   PROCEDURAL             MOD-BUFFER-CHUNK WM
#      9.908   PROCEDURAL             CONFLICT-RESOLUTION
#      9.908   PROCEDURAL             PRODUCTION-SELECTED SKIP-FOURTH
#      9.908   PROCEDURAL             BUFFER-READ-ACTION GOAL
#      9.908   PROCEDURAL             BUFFER-READ-ACTION WM
#      9.958   PROCEDURAL             PRODUCTION-FIRED SKIP-FOURTH
#      9.958   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#      9.958   PROCEDURAL             MOD-BUFFER-CHUNK WM
#      9.958   PROCEDURAL             CONFLICT-RESOLUTION
#      9.958   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-FIRST
#      9.958   PROCEDURAL             BUFFER-READ-ACTION GOAL
#      9.958   PROCEDURAL             BUFFER-READ-ACTION WM
#     10.008   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     10.008   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     10.008   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     10.008   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#     10.008   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     10.008   DECLARATIVE            start-retrieval
#     10.008   PROCEDURAL             CONFLICT-RESOLUTION
#     10.058   IMAGINAL               CREATE-NEW-BUFFER-CHUNK IMAGINAL
#     10.058   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK9
#     10.058   PROCEDURAL             CONFLICT-RESOLUTION
#     10.212   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     10.212   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     10.212   PROCEDURAL             CONFLICT-RESOLUTION
#     10.212   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-IT
#     10.212   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     10.212   PROCEDURAL             BUFFER-READ-ACTION WM
#     10.212   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#     10.212   PROCEDURAL             QUERY-BUFFER-ACTION IMAGINAL
#     10.512   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral73"
#     10.512   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     10.512   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     10.512   PROCEDURAL             MODULE-REQUEST IMAGINAL
#     10.512   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     10.512   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     10.512   PROCEDURAL             CONFLICT-RESOLUTION
#     10.512   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-SECOND
#     10.512   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     10.512   PROCEDURAL             BUFFER-READ-ACTION WM
#     10.562   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     10.562   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     10.562   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     10.562   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#     10.562   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     10.562   DECLARATIVE            start-retrieval
#     10.562   PROCEDURAL             CONFLICT-RESOLUTION
#     10.646   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     10.646   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     10.646   PROCEDURAL             CONFLICT-RESOLUTION
#     10.712   IMAGINAL               CREATE-NEW-BUFFER-CHUNK IMAGINAL
#     10.712   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK10
#     10.712   PROCEDURAL             CONFLICT-RESOLUTION
#     10.712   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-IT
#     10.712   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     10.712   PROCEDURAL             BUFFER-READ-ACTION WM
#     10.712   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#     10.712   PROCEDURAL             QUERY-BUFFER-ACTION IMAGINAL
#     11.012   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral705"
#     11.012   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     11.012   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     11.012   PROCEDURAL             MODULE-REQUEST IMAGINAL
#     11.012   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     11.012   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     11.012   PROCEDURAL             CONFLICT-RESOLUTION
#     11.012   PROCEDURAL             PRODUCTION-SELECTED SKIP-THIRD
#     11.012   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     11.012   PROCEDURAL             BUFFER-READ-ACTION WM
#     11.062   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#     11.062   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     11.062   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     11.062   PROCEDURAL             CONFLICT-RESOLUTION
#     11.062   PROCEDURAL             PRODUCTION-SELECTED SKIP-FOURTH
#     11.062   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     11.062   PROCEDURAL             BUFFER-READ-ACTION WM
#     11.112   PROCEDURAL             PRODUCTION-FIRED SKIP-FOURTH
#     11.112   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     11.112   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     11.112   PROCEDURAL             CONFLICT-RESOLUTION
#     11.112   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-FIRST
#     11.112   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     11.112   PROCEDURAL             BUFFER-READ-ACTION WM
#     11.162   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     11.162   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     11.162   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     11.162   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#     11.162   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     11.162   DECLARATIVE            start-retrieval
#     11.162   PROCEDURAL             CONFLICT-RESOLUTION
#     11.212   IMAGINAL               CREATE-NEW-BUFFER-CHUNK IMAGINAL
#     11.212   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK11
#     11.212   PROCEDURAL             CONFLICT-RESOLUTION
#     11.302   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     11.302   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     11.302   PROCEDURAL             CONFLICT-RESOLUTION
#     11.302   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-IT
#     11.302   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     11.302   PROCEDURAL             BUFFER-READ-ACTION WM
#     11.302   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#     11.302   PROCEDURAL             QUERY-BUFFER-ACTION IMAGINAL
#     11.602   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral73"
#     11.602   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     11.602   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     11.602   PROCEDURAL             MODULE-REQUEST IMAGINAL
#     11.602   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     11.602   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     11.602   PROCEDURAL             CONFLICT-RESOLUTION
#     11.602   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-SECOND
#     11.602   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     11.602   PROCEDURAL             BUFFER-READ-ACTION WM
#     11.652   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     11.652   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     11.652   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     11.652   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#     11.652   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     11.652   DECLARATIVE            start-retrieval
#     11.652   PROCEDURAL             CONFLICT-RESOLUTION
#     11.707   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     11.707   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     11.707   PROCEDURAL             CONFLICT-RESOLUTION
#     11.802   IMAGINAL               CREATE-NEW-BUFFER-CHUNK IMAGINAL
#     11.802   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK12
#     11.802   PROCEDURAL             CONFLICT-RESOLUTION
#     11.802   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-IT
#     11.802   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     11.802   PROCEDURAL             BUFFER-READ-ACTION WM
#     11.802   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#     11.802   PROCEDURAL             QUERY-BUFFER-ACTION IMAGINAL
#     12.100   ------                 Stopped because time limit reached
#     12.100   VISION                 PROC-DISPLAY
#     12.100   VISION                 visicon-update
#     12.102   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral705"
#     12.102   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     12.102   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     12.102   PROCEDURAL             MODULE-REQUEST IMAGINAL
#     12.102   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     12.102   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     12.102   PROCEDURAL             CONFLICT-RESOLUTION
#     12.102   PROCEDURAL             PRODUCTION-SELECTED SKIP-THIRD
#     12.102   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     12.102   PROCEDURAL             BUFFER-READ-ACTION WM
#     12.152   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#     12.152   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     12.152   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     12.152   PROCEDURAL             CONFLICT-RESOLUTION
#     12.152   PROCEDURAL             PRODUCTION-SELECTED SKIP-FOURTH
#     12.152   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     12.152   PROCEDURAL             BUFFER-READ-ACTION WM
#     12.185   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#     12.185   VISION                 No visual-object found
#     12.200   ------                 Stopped because time limit reached
#     12.200   VISION                 PROC-DISPLAY
#     12.200   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION2 NIL
#     12.200   VISION                 visicon-update
#     12.202   PROCEDURAL             PRODUCTION-FIRED SKIP-FOURTH
#     12.202   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     12.202   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     12.202   PROCEDURAL             CONFLICT-RESOLUTION
#     12.202   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-FIRST
#     12.202   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     12.202   PROCEDURAL             BUFFER-READ-ACTION WM
#     12.252   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     12.252   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     12.252   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     12.252   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#     12.252   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     12.252   DECLARATIVE            start-retrieval
#     12.252   PROCEDURAL             CONFLICT-RESOLUTION
#     12.285   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#     12.285   VISION                 SET-BUFFER-CHUNK VISUAL TEXT2 NIL
#     12.285   PROCEDURAL             CONFLICT-RESOLUTION
#     12.302   IMAGINAL               CREATE-NEW-BUFFER-CHUNK IMAGINAL
#     12.302   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK13
#     12.302   PROCEDURAL             CONFLICT-RESOLUTION
#     12.449   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     12.449   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     12.449   PROCEDURAL             CONFLICT-RESOLUTION
#     12.449   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-IT
#     12.449   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     12.449   PROCEDURAL             BUFFER-READ-ACTION WM
#     12.449   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#     12.449   PROCEDURAL             QUERY-BUFFER-ACTION IMAGINAL
#     12.700   VISION                 ERASE-BUFFER VISUAL-LOCATION
#     12.749   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral73"
#     12.749   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     12.749   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     12.749   PROCEDURAL             MODULE-REQUEST IMAGINAL
#     12.749   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     12.749   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     12.749   PROCEDURAL             CONFLICT-RESOLUTION
#     12.749   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-SECOND
#     12.749   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     12.749   PROCEDURAL             BUFFER-READ-ACTION WM
#     12.799   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     12.799   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     12.799   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     12.799   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#     12.799   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     12.799   DECLARATIVE            start-retrieval
#     12.799   PROCEDURAL             CONFLICT-RESOLUTION
#     12.857   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     12.857   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     12.857   PROCEDURAL             CONFLICT-RESOLUTION
#     12.949   IMAGINAL               CREATE-NEW-BUFFER-CHUNK IMAGINAL
#     12.949   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK14
#     12.949   PROCEDURAL             CONFLICT-RESOLUTION
#     12.949   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-IT
#     12.949   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     12.949   PROCEDURAL             BUFFER-READ-ACTION WM
#     12.949   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#     12.949   PROCEDURAL             QUERY-BUFFER-ACTION IMAGINAL
#     13.249   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral705"
#     13.249   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     13.249   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     13.249   PROCEDURAL             MODULE-REQUEST IMAGINAL
#     13.249   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     13.249   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     13.249   PROCEDURAL             CONFLICT-RESOLUTION
#     13.249   PROCEDURAL             PRODUCTION-SELECTED SKIP-THIRD
#     13.249   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     13.249   PROCEDURAL             BUFFER-READ-ACTION WM
#     13.299   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#     13.299   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     13.299   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     13.299   PROCEDURAL             CONFLICT-RESOLUTION
#     13.299   PROCEDURAL             PRODUCTION-SELECTED SKIP-FOURTH
#     13.299   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     13.299   PROCEDURAL             BUFFER-READ-ACTION WM
#     13.349   PROCEDURAL             PRODUCTION-FIRED SKIP-FOURTH
#     13.349   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     13.349   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     13.349   PROCEDURAL             CONFLICT-RESOLUTION
#     13.349   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-FIRST
#     13.349   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     13.349   PROCEDURAL             BUFFER-READ-ACTION WM
#     13.399   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     13.399   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     13.399   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     13.399   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#     13.399   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     13.399   DECLARATIVE            start-retrieval
#     13.399   PROCEDURAL             CONFLICT-RESOLUTION
#     13.449   IMAGINAL               CREATE-NEW-BUFFER-CHUNK IMAGINAL
#     13.449   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK15
#     13.449   PROCEDURAL             CONFLICT-RESOLUTION
#     13.534   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     13.534   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     13.534   PROCEDURAL             CONFLICT-RESOLUTION
#     13.534   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-IT
#     13.534   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     13.534   PROCEDURAL             BUFFER-READ-ACTION WM
#     13.534   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#     13.534   PROCEDURAL             QUERY-BUFFER-ACTION IMAGINAL
#     13.834   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral73"
#     13.834   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     13.834   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     13.834   PROCEDURAL             MODULE-REQUEST IMAGINAL
#     13.834   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     13.834   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     13.834   PROCEDURAL             CONFLICT-RESOLUTION
#     13.834   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-SECOND
#     13.834   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     13.834   PROCEDURAL             BUFFER-READ-ACTION WM
#     13.884   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     13.884   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     13.884   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     13.884   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#     13.884   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     13.884   DECLARATIVE            start-retrieval
#     13.884   PROCEDURAL             CONFLICT-RESOLUTION
#     13.941   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     13.941   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     13.941   PROCEDURAL             CONFLICT-RESOLUTION
#     14.034   IMAGINAL               CREATE-NEW-BUFFER-CHUNK IMAGINAL
#     14.034   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK16
#     14.034   PROCEDURAL             CONFLICT-RESOLUTION
#     14.034   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-IT
#     14.034   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     14.034   PROCEDURAL             BUFFER-READ-ACTION WM
#     14.034   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#     14.034   PROCEDURAL             QUERY-BUFFER-ACTION IMAGINAL
#     14.334   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral705"
#     14.334   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     14.334   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     14.334   PROCEDURAL             MODULE-REQUEST IMAGINAL
#     14.334   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     14.334   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     14.334   PROCEDURAL             CONFLICT-RESOLUTION
#     14.334   PROCEDURAL             PRODUCTION-SELECTED SKIP-THIRD
#     14.334   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     14.334   PROCEDURAL             BUFFER-READ-ACTION WM
#     14.384   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#     14.384   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     14.384   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     14.384   PROCEDURAL             CONFLICT-RESOLUTION
#     14.384   PROCEDURAL             PRODUCTION-SELECTED SKIP-FOURTH
#     14.384   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     14.384   PROCEDURAL             BUFFER-READ-ACTION WM
#     14.434   PROCEDURAL             PRODUCTION-FIRED SKIP-FOURTH
#     14.434   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     14.434   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     14.434   PROCEDURAL             CONFLICT-RESOLUTION
#     14.434   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-FIRST
#     14.434   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     14.434   PROCEDURAL             BUFFER-READ-ACTION WM
#     14.484   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     14.484   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     14.484   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     14.484   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#     14.484   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     14.484   DECLARATIVE            start-retrieval
#     14.484   PROCEDURAL             CONFLICT-RESOLUTION
#     14.534   IMAGINAL               CREATE-NEW-BUFFER-CHUNK IMAGINAL
#     14.534   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK17
#     14.534   PROCEDURAL             CONFLICT-RESOLUTION
#     14.614   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     14.614   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     14.614   PROCEDURAL             CONFLICT-RESOLUTION
#     14.614   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-IT
#     14.614   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     14.614   PROCEDURAL             BUFFER-READ-ACTION WM
#     14.614   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#     14.614   PROCEDURAL             QUERY-BUFFER-ACTION IMAGINAL
#     14.914   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral73"
#     14.914   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     14.914   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     14.914   PROCEDURAL             MODULE-REQUEST IMAGINAL
#     14.914   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     14.914   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     14.914   PROCEDURAL             CONFLICT-RESOLUTION
#     14.914   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-SECOND
#     14.914   PROCEDURAL             BUFFER-READ-ACTION GOAL
#     14.914   PROCEDURAL             BUFFER-READ-ACTION WM
#     14.964   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     14.964   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#     14.964   PROCEDURAL             MOD-BUFFER-CHUNK WM
#     14.964   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#     14.964   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     14.964   DECLARATIVE            start-retrieval
#     14.964   PROCEDURAL             CONFLICT-RESOLUTION
#     15.026   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     15.026   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     15.026   PROCEDURAL             CONFLICT-RESOLUTION
#     15.114   IMAGINAL               CREATE-NEW-BUFFER-CHUNK IMAGINAL
#     15.114   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK18
#     15.114   PROCEDURAL             CONFLICT-RESOLUTION
#     15.114   PROCEDURAL             PRODUCTION-SELECTED REHEARSE-IT
# ...
#    511.951   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    511.951   PROCEDURAL             CONFLICT-RESOLUTION
#    511.951   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    511.951   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    511.951   PROCEDURAL             BUFFER-READ-ACTION WM
#    511.951   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    512.001   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    512.001   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    512.001   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    512.001   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    512.001   DECLARATIVE            start-retrieval
#    512.001   PROCEDURAL             CONFLICT-RESOLUTION
#    512.304   DECLARATIVE            RETRIEVED-CHUNK ITEM30
#    512.304   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM30
#    512.304   PROCEDURAL             CONFLICT-RESOLUTION
#    512.304   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    512.304   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    512.304   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    512.354   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    512.354   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    512.354   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    512.354   PROCEDURAL             CONFLICT-RESOLUTION
#    512.354   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    512.354   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    512.354   PROCEDURAL             BUFFER-READ-ACTION WM
#    512.354   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    512.404   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    512.404   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    512.404   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    512.404   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    512.404   DECLARATIVE            start-retrieval
#    512.404   PROCEDURAL             CONFLICT-RESOLUTION
#    512.773   DECLARATIVE            RETRIEVED-CHUNK ITEM75
#    512.773   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM75
#    512.773   PROCEDURAL             CONFLICT-RESOLUTION
#    512.773   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    512.773   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    512.773   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    512.823   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    512.823   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    512.823   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    512.823   PROCEDURAL             CONFLICT-RESOLUTION
#    512.823   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    512.823   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    512.823   PROCEDURAL             BUFFER-READ-ACTION WM
#    512.823   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    512.873   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    512.873   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    512.873   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    512.873   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    512.873   DECLARATIVE            start-retrieval
#    512.873   PROCEDURAL             CONFLICT-RESOLUTION
#    513.193   DECLARATIVE            RETRIEVED-CHUNK ITEM16
#    513.193   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM16
#    513.193   PROCEDURAL             CONFLICT-RESOLUTION
#    513.193   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    513.193   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    513.193   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    513.243   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    513.243   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    513.243   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    513.243   PROCEDURAL             CONFLICT-RESOLUTION
#    513.243   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    513.243   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    513.243   PROCEDURAL             BUFFER-READ-ACTION WM
#    513.243   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    513.293   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    513.293   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    513.293   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    513.293   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    513.293   DECLARATIVE            start-retrieval
#    513.293   PROCEDURAL             CONFLICT-RESOLUTION
#    513.616   DECLARATIVE            RETRIEVED-CHUNK ITEM65
#    513.616   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM65
#    513.616   PROCEDURAL             CONFLICT-RESOLUTION
#    513.616   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    513.616   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    513.616   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    513.666   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    513.666   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    513.666   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    513.666   PROCEDURAL             CONFLICT-RESOLUTION
#    513.666   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    513.666   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    513.666   PROCEDURAL             BUFFER-READ-ACTION WM
#    513.666   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    513.716   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    513.716   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    513.716   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    513.716   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    513.716   DECLARATIVE            start-retrieval
#    513.716   PROCEDURAL             CONFLICT-RESOLUTION
#    513.812   DECLARATIVE            RETRIEVED-CHUNK ITEM68
#    513.812   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM68
#    513.812   PROCEDURAL             CONFLICT-RESOLUTION
#    513.812   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    513.812   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    513.812   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    513.862   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    513.862   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    513.862   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    513.862   PROCEDURAL             CONFLICT-RESOLUTION
#    513.862   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    513.862   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    513.862   PROCEDURAL             BUFFER-READ-ACTION WM
#    513.862   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    513.912   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    513.912   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    513.912   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    513.912   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    513.912   DECLARATIVE            start-retrieval
#    513.912   PROCEDURAL             CONFLICT-RESOLUTION
#    514.044   DECLARATIVE            RETRIEVED-CHUNK ITEM78
#    514.044   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM78
#    514.044   PROCEDURAL             CONFLICT-RESOLUTION
#    514.044   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    514.044   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    514.044   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    514.094   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    514.094   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    514.094   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    514.094   PROCEDURAL             CONFLICT-RESOLUTION
#    514.094   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    514.094   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    514.094   PROCEDURAL             BUFFER-READ-ACTION WM
#    514.094   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    514.144   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    514.144   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    514.144   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    514.144   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    514.144   DECLARATIVE            start-retrieval
#    514.144   PROCEDURAL             CONFLICT-RESOLUTION
#    514.537   DECLARATIVE            RETRIEVED-CHUNK ITEM47
#    514.537   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM47
#    514.537   PROCEDURAL             CONFLICT-RESOLUTION
#    514.537   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    514.537   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    514.537   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    514.587   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    514.587   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    514.587   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    514.587   PROCEDURAL             CONFLICT-RESOLUTION
#    514.587   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    514.587   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    514.587   PROCEDURAL             BUFFER-READ-ACTION WM
#    514.587   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    514.637   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    514.637   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    514.637   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    514.637   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    514.637   DECLARATIVE            start-retrieval
#    514.637   PROCEDURAL             CONFLICT-RESOLUTION
#    514.883   DECLARATIVE            RETRIEVED-CHUNK ITEM79
#    514.883   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM79
#    514.883   PROCEDURAL             CONFLICT-RESOLUTION
#    514.883   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    514.883   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    514.883   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    514.933   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    514.933   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    514.933   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    514.933   PROCEDURAL             CONFLICT-RESOLUTION
#    514.933   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    514.933   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    514.933   PROCEDURAL             BUFFER-READ-ACTION WM
#    514.933   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    514.983   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    514.983   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    514.983   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    514.983   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    514.983   DECLARATIVE            start-retrieval
#    514.983   PROCEDURAL             CONFLICT-RESOLUTION
#    515.192   DECLARATIVE            RETRIEVED-CHUNK ITEM33
#    515.192   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM33
#    515.192   PROCEDURAL             CONFLICT-RESOLUTION
#    515.192   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    515.192   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    515.192   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    515.242   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    515.242   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    515.242   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    515.242   PROCEDURAL             CONFLICT-RESOLUTION
#    515.242   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    515.242   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    515.242   PROCEDURAL             BUFFER-READ-ACTION WM
#    515.242   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    515.292   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    515.292   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    515.292   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    515.292   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    515.292   DECLARATIVE            start-retrieval
#    515.292   PROCEDURAL             CONFLICT-RESOLUTION
#    515.496   DECLARATIVE            RETRIEVED-CHUNK ITEM50
#    515.496   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM50
#    515.496   PROCEDURAL             CONFLICT-RESOLUTION
#    515.496   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    515.496   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    515.496   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    515.546   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    515.546   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    515.546   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    515.546   PROCEDURAL             CONFLICT-RESOLUTION
#    515.546   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    515.546   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    515.546   PROCEDURAL             BUFFER-READ-ACTION WM
#    515.546   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    515.596   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    515.596   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    515.596   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    515.596   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    515.596   DECLARATIVE            start-retrieval
#    515.596   PROCEDURAL             CONFLICT-RESOLUTION
#    515.782   DECLARATIVE            RETRIEVED-CHUNK ITEM64
#    515.782   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM64
#    515.782   PROCEDURAL             CONFLICT-RESOLUTION
#    515.782   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    515.782   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    515.782   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    515.832   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    515.832   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    515.832   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    515.832   PROCEDURAL             CONFLICT-RESOLUTION
#    515.832   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    515.832   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    515.832   PROCEDURAL             BUFFER-READ-ACTION WM
#    515.832   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    515.882   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    515.882   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    515.882   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    515.882   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    515.882   DECLARATIVE            start-retrieval
#    515.882   PROCEDURAL             CONFLICT-RESOLUTION
#    516.059   DECLARATIVE            RETRIEVED-CHUNK ITEM39
#    516.059   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM39
#    516.059   PROCEDURAL             CONFLICT-RESOLUTION
#    516.059   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    516.059   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    516.059   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    516.109   PROCEDURAL             PRODUCTION-FIRED HARVEST
#    516.109   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    516.109   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    516.109   PROCEDURAL             CONFLICT-RESOLUTION
#    516.109   PROCEDURAL             PRODUCTION-SELECTED RETRIEVE
#    516.109   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    516.109   PROCEDURAL             BUFFER-READ-ACTION WM
#    516.109   PROCEDURAL             QUERY-BUFFER-ACTION RETRIEVAL
#    516.159   PROCEDURAL             PRODUCTION-FIRED RETRIEVE
#    516.159   PROCEDURAL             MOD-BUFFER-CHUNK GOAL
#    516.159   PROCEDURAL             MODULE-REQUEST RETRIEVAL
#    516.159   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    516.159   DECLARATIVE            start-retrieval
#    516.159   PROCEDURAL             CONFLICT-RESOLUTION
#    516.435   DECLARATIVE            RETRIEVED-CHUNK ITEM67
#    516.435   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM67
#    516.435   PROCEDURAL             CONFLICT-RESOLUTION
#    516.435   PROCEDURAL             PRODUCTION-SELECTED HARVEST
#    516.435   PROCEDURAL             BUFFER-READ-ACTION GOAL
#    516.435   PROCEDURAL             BUFFER-READ-ACTION RETRIEVAL
#    516.457   ------                 Stopped because time limit reached
# Experiment 1/1 completed!
#
# #############################################
#
# [controls] Results!
#
# Avg. Amount of recall transitions = 19
# Avg. Negative Thought train length = 1.4
# Avg. Amount of words recalled = 29
# Avg. Amount of unique words recalled = 22
# pstart = {'negative': 1, 'neutral': 1}
# pstay = {'positive': 5, 'neutral': 12, 'negative': 6}
# pstop = {'positive': 1, 'neutral': 1}

# %% [markdown]
# ## Backup Reminder : DO IT!

# %% [markdown]
# # Here only the positions matter not the word?
