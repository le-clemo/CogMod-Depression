# %%
import actr
import pickle
import random
import os
import fnmatch
import sys
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from itertools import groupby
import json
import re
# Out:
# ACT-R connection has been started.

# %% [markdown]
# ### Observed Issues:
# (see file "current_issues")
#
# - Recency effect still too weak.
#
# - Primacy effect too strong.

# %% [markdown]
# #### Number of words in each list i.e. list_length should be n where (n-2)%3 == 0 because 2 neutral words are added in each list.
#
# #### The adjustable parameters in this experiment code.
#     - number of agents (top of next cell)
#     - experimental conditions (further below) --> multiple conditions can be set in a list of lists [[rehearsal time1, num words per list 1], [rehearsal time 2, num words per list 2], ...]
#     - Number of lists (further below)
# #### Adjustable parameters in ACT-R
#     - :declarative-num-finsts 21 ; number of items that are kept as recently retrieved (Change it to 5)
#     - :declarative-finst-span 21 ; how long items stay in the recently-retrieved state (5,100)

# %%
help(actr)
# Out:
# Help on module actr:
#
# NAME
#     actr
#
# CLASSES
#     builtins.object
#         actr
#         interface
#         request
#
#     class actr(builtins.object)
#      |  actr(host, port)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, host, port)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  add_command(self, name, function, documentation='No documentation provided.', single=True, actr_name=None)
#      |
#      |  evaluate(self, *params)
#      |
#      |  evaluate_single(self, *params)
#      |
#      |  monitor_command(self, original, monitor)
#      |
#      |  remove_command(self, name)
#      |
#      |  remove_command_monitor(self, original, monitor)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class interface(builtins.object)
#      |  interface(host, port)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, host, port)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  add_command(self, name, function)
#      |
#      |  collect_data(self)
#      |
#      |  echo_output(self)
#      |
#      |  no_output(self)
#      |
#      |  output_monitor(self, string)
#      |
#      |  process_message(self, d)
#      |
#      |  run_command(self, command, command_name, model, id, params)
#      |
#      |  send(self, method, *params)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class request(builtins.object)
#      |  request(id)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, id)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  notify_result(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FUNCTIONS
#     act_r_output(output)
#
#     add_button_to_exp_window(window, text='', x=0, y=0, action=None, height=20, width=75, color='gray')
#
#     add_command(name, function=None, documentation='No documentation provided.', single=True, local_name=None)
#
#     add_dm(*chunks)
#
#     add_dm_fct(chunks)
#
#     add_image_to_exp_window(window, text, file, x=0, y=0, width=50, height=50, action=None)
#
#     add_items_to_exp_window(window, *items)
#
#     add_line_to_exp_window(window, start, end, color=False)
#
#     add_text_to_exp_window(window, text, x=0, y=0, color='black', height=20, width=75, font_size=12)
#
#     add_visicon_features(*features)
#
#     all_productions()
#
#     buffer_chunk(*params)
#
#     buffer_read(buffer)
#
#     buffer_status(*params)
#
#     buffers()
#
#     chunk_copied_from(chunk_name)
#
#     chunk_p(chunk_name)
#
#     chunk_slot_value(chunk_name, slot_name)
#
#     chunk_spec_to_chunk_def(spec_id)
#
#     clear_buffer(buffer)
#
#     clear_exp_window(win=None)
#
#     command_output(string)
#
#     connection()
#
#     copy_chunk(chunk_name)
#
#     correlation(results, data, output=True)
#
#     create_image_for_exp_window(window, text, file, x=0, y=0, width=50, height=50, action=None)
#
#     current_model()
#
#     define_chunk_spec(*spec)
#
#     define_chunks(*chunks)
#
#     define_chunks_fct(chunks)
#
#     define_module(name, buffers, params, interface=None)
#
#     delete_all_visicon_features()
#
#     delete_chunk(name)
#
#     delete_visicon_features(*features)
#
#     dm(*params)
#
#     extend_possible_slots(slot_name, warn=True)
#
#     get_history_data(history, *params)
#
#     get_parameter_value(param)
#
#     get_system_parameter_value(param)
#
#     get_time(model_time=True)
#
#     goal_focus(goal=None)
#
#     hide_output()
#
#     history_data_available(history, file=False, *params)
#
#     install_device(device)
#
#     load_act_r_code(path)
#
#     load_act_r_model(path)
#
#     mean_deviation(results, data, output=True)
#
#     mod_chunk(chunk_name, *mods)
#
#     mod_focus(*mods)
#
#     model_output(output_string)
#
#     modify_line_for_exp_window(line, start, end, color=False)
#
#     modify_visicon_features(*features)
#
#     modules_parameters(module)
#
#     modules_with_parameters()
#
#     monitor_command(original, monitor)
#
#     mp_models()
#
#     mp_show_queue(indicate_traced=False)
#
#     mp_time()
#
#     mp_time_ms()
#
#     new_digit_sound(digit, onset=False, time_in_ms=False)
#
#     new_tone_sound(freq, duration, onset=False, time_in_ms=False)
#
#     new_word_sound(word, onset=False, location='external', time_in_ms=False)
#
#     open_exp_window(title, visible=True, width=300, height=300, x=300, y=300)
#
#     pbreak(*params)
#
#     pdisable(*params)
#
#     penable(*params)
#
#     permute_list(l)
#
#     pp(*params)
#
#     pprint_chunks(*chunks)
#
#     predict_bold_response(start=None, end=None, output=None)
#
#     print_activation_trace(time, ms=True)
#
#     print_audicon()
#
#     print_chunk_activation_trace(chunk, time, ms=True)
#
#     print_dm_finsts()
#
#     print_visicon()
#
#     print_warning(warning)
#
#     printed_audicon()
#
#     printed_parameter_details(param)
#
#     printed_visicon()
#
#     process_events()
#
#     process_history_data(processor, file=False, data_params=None, processor_params=None)
#
#     punbreak(*params)
#
#     purge_chunk(name)
#
#     random(value)
#
#     record_history(*params)
#
#     release_chunk_spec(spec_id)
#
#     reload(compile=False)
#
#     remove_command(name)
#
#     remove_command_monitor(original, monitor)
#
#     remove_items_from_exp_window(window, *items)
#
#     reset()
#
#     resume_output()
#
#     run(time, real_time=False)
#
#     run_full_time(time, real_time=False)
#
#     run_n_events(event_count, real_time=False)
#
#     run_until_condition(condition, real_time=False)
#
#     run_until_time(time, real_time=False)
#
#     running()
#
#     save_history_data(history, file, comment='', *params)
#
#     saved_activation_history()
#
#     schedule_break_relative(time_delay, time_in_ms=False, priority=':max', details=None)
#
#     schedule_event(time, action, params=None, module=':NONE', priority=0, maintenance=False, destination=None, details=None, output=True, time_in_ms=False, precondition=None)
#
#     schedule_event_after_module(after_module, action, params=None, module=':NONE', maintenance=False, destination=None, details=None, output=True, precondition=None, dynamic=False, delay=True, include_maintenance=False)
#
#     schedule_event_now(action, params=None, module=':NONE', priority=0, maintenance=False, destination=None, details=None, output=True, precondition=None)
#
#     schedule_event_relative(time_delay, action, params=None, module=':NONE', priority=0, maintenance=False, destination=None, details=None, output=True, time_in_ms=False, precondition=None)
#
#     schedule_mod_buffer_chunk(buffer, mod_list_or_spec, time, module=':NONE', priority=0, output='low', time_in_ms=False)
#
#     schedule_set_buffer_chunk(buffer, chunk, time, module=':NONE', priority=0, output='low', time_in_ms=False, requested=True)
#
#     schedule_simple_mod_buffer_chunk(buffer, mod_list_or_spec, time, module='NONE', priority=0)
#
#     schedule_simple_set_buffer_chunk(buffer, chunk, time, module='NONE', priority=0, requested=True)
#
#     sdm(*params)
#
#     sdp(*params)
#
#     set_buffer_chunk(buffer_name, chunk_name, requested=True)
#
#     set_chunk_slot_value(chunk_name, slot_name, new_value)
#
#     set_current_model(name)
#
#     set_parameter_value(param, value)
#
#     set_system_parameter_value(param, value)
#
#     simulate_retrieval_request(*spec)
#
#     sorted_module_names()
#
#     spp(*params)
#
#     start(host=None, port=None)
#
#     start_hand_at_mouse()
#
#     stop()
#
#     stop_output()
#
#     stop_recording_history(*params)
#
#     trigger_reward(reward, maintenance=False)
#
#     undefine_module(name)
#
#     unhide_output()
#
#     used_production_buffers()
#
#     whynot(*params)
#
#     whynot_dm(*params)
#
# DATA
#     current_connection = <actr.actr object>
#     locals = <_thread._local object>
#
# FILE
#     c:\users\cleme\documents\education\rug\first-year_research\my_project\model\actr.py

# %%
### Experiment part ###

def __init__(iteration, rehearsal_time, list_length, list_amount=3, path="."):
    subject = ''

    current_list = ''
    
    associated_list = ''

    recalled_words = defaultdict(list)

    rehearsed_words =  defaultdict(lambda: defaultdict(int))

    #list_amount = 3   # No of lists (100, 200, 1000, 2000 AND 5000)

    #Set below where function is actually called
    list_length = list_length   # No of words in a list
    rehearsal_time = rehearsal_time  # No of seconds for which rehearsal happens and each word is shown

    delay = 1  #delay between rehearsal and recall

    recall_time = 90
    
    time_between_trials = 5

    word_lists_dict = defaultdict(list)
    
    # Ensure there are enough unique words to create the word lists
    word_dict = {"positive": ["positive" + str(i) for i in range(999)],
                 "negative": ["negative" + str(i) for i in range(999)],
                 "neutral": ["neutral" + str(i) for i in range(999)]}

    filename = f'{path}\words_{list_length}_lists_{list_amount}_rh_time_{rehearsal_time}_rec_time_{recall_time}_delay_{delay}_{iteration}.txt'
    
    results = {}

    results['x'] = {'data': [], # will be appended later in the analytics function
                          'info': "Storing range(len(word_lists_dict[0])) here"}

    results['rehearse_frequency'] = {'data': None,# will be appended later in the analytics function

                                     'info': "Storing list(rehearse_frequency.values()) here"}

    results['recall_probability'] = {'data': None, # will be appended later in the analytics function
                                        'info': "Storing list(recall_probability.values()) here"}

    results['first_recall'] = {'data': None, # will be appended later in the analytics function
                               'info': "Storing list(first_probability.values()) here"}

    with open(filename, 'w') as outfile:
        json.dump(results, outfile)

    with open(filename) as json_file:
        results = json.load(json_file)
#         #print(results)
    
    globals().update(locals())  ## Making everything public, worst code you can ever write!!

# %%
def add_words(i, list_length):
    '''
    Add the words to the word lists, ensures valence categories are balanced
    '''
    global word_lists_dict

    amnt_wanted = list_length #-2)/3 #not needed here because Murdock experiment # Amount of each valence wanted, minus 2 neutrals controlling for primacy
    amt_positive, amt_negative, amt_neutral, count = 0, 0, 0, 0
    while len(word_lists_dict[i]) != list_length:
        count += 1
        #print(f"...................{count,word_lists_dict[i]}")
        if count >= 9999: # IF it takes too long to create a unique list at random, start over
            word_lists_dict[i] = []
            add_words(i, list_length)
        if len(word_lists_dict[i]) == 0: # Place two neutral words at the start to control for primacy effects
            word_to_add1 = word_dict["neutral"][random.randint(0, len(word_dict["neutral"])-1)]
            word_to_add2 = word_dict["neutral"][random.randint(0, len(word_dict["neutral"])-1)]
            if word_to_add1 not in word_lists_dict[i] and word_to_add2 not in word_lists_dict[i] and word_to_add1 != word_to_add2:
                word_lists_dict[i].append(word_to_add1)
                word_lists_dict[i].append(word_to_add2)
            else:
                continue # skip this loop iteration                   
        else: 
            random_valence = random.choice(["positive", "negative", "neutral"])
            word_to_add = word_dict[random_valence][random.randint(0, len(word_dict[random_valence])-1)]
            if word_to_add not in word_lists_dict[i] and word_lists_dict[i][-1] not in word_dict[random_valence] and \
               amt_positive <= amnt_wanted and amt_negative <= amnt_wanted and amt_neutral <= amnt_wanted:
                if random_valence == "positive" and amt_positive < amnt_wanted:
                    amt_positive += 1
                elif random_valence == "negative" and amt_negative < amnt_wanted:
                    amt_negative +=1
                elif random_valence == "neutral" and amt_neutral < amnt_wanted:
                    amt_neutral +=1
                else:
                    continue # skip this loop iteration
                word_lists_dict[i].append(word_to_add)

def create_lists(list_amount=3, list_length=2):
    '''
    Create the wordlists used during the free recall tasks 
    '''  
    global word_lists_dict 

    for i in range(list_amount):
        print(f'List {i+1}/{list_amount} created!', end="\r")
        add_words(i, list_length)

    # Save the dictionary to a .pickle file, so we do not have to create the word lists everytime we run the model                    
    file = open(f"word_lists/word_lists_dict_{list_length}_{list_amount}.pickle","wb")
    pickle.dump(word_lists_dict, file)
    file.close()
    return word_lists_dict

# Check if the word lists already exist, else create new word lists
def check_and_create_lists():
    global word_lists_dict
    try:
        file = open(f"word_lists/word_lists_dict_{list_length}_{list_amount}.pickle","rb")
        #file = open(f"word_lists_dict_100_items_only.pickle","rb")
        word_lists_dict = pickle.load(file)  
        file.close()
        print("\nSuccesfully loaded the word lists!\n")
    except FileNotFoundError:
        print("\nCreating word lists!\n")
        #amount_to_create = list_amount                              
        word_lists_dict = create_lists(list_amount,list_length)

def display_word_lists():
    '''
    Display the word lists loaded/created
    '''
    for key, value in word_lists_dict.items():
        print(f'List {key}:\n {value}\n')

def close_exp_window():
    '''
    Close opened ACT-R window
    '''
    return actr.current_connection.evaluate_single("close-exp-window")


def prepare_for_memorization():
    '''
    Enable rehearsing productions to start the memorization phase 
    '''    
    enable_list = ["rehearse-first", "rehearse-second", "rehearse-third", "rehearse-fourth", 
                    "rehearse-first-default", "rehearse-second-default", "rehearse-third-default",
                    "rehearse-fourth-default", "rehearse-it", "forget-word-1", "forget-word-2",
                    "forget-word-3", "forget-word-4"]
    
    disable_list = ["retrieve-a-word", "recall-a-word"]
    
    for prod in enable_list:
        actr.penable(prod)
        
    for prod in disable_list:
        actr.pdisable(prod)
        
    for buff in ["imaginal", "retrieval", "production"]:
        actr.clear_buffer(buff)     
    
    actr.goal_focus("goal") # set goal to start memorization

    
def prepare_for_recall(): 
    '''
    Disable rehearsing productions, and clearing buffer contents to start the recalling phase 
    '''
    disable_list = ["rehearse-first", "rehearse-second", "rehearse-third", "rehearse-fourth", 
                    "rehearse-first-default", "rehearse-second-default", "rehearse-third-default",
                    "rehearse-fourth-default", "rehearse-it", "forget-word-1", "forget-word-2",
                    "forget-word-3", "forget-word-4"]
    
    enable_list = ["retrieve-a-word", "recall-a-word", "stop-recall"]
    
    for prod in disable_list:
        actr.pdisable(prod)

    for prod in enable_list:
        actr.penable(prod)
        
    actr.run(delay, False) 
    
    for buff in ["imaginal", "retrieval", "production"]:
        actr.clear_buffer(buff) 

def stop_recall(human): 
    '''
     
    '''
    disable_list = ["retrieve-a-word", "recall-a-word", "stop-recall"]
    
    for prod in disable_list:
        actr.pdisable(prod)
        
    actr.run(time_between_trials, human) #time between trials
    
    for buff in ["goal", "imaginal", "retrieval", "production"]:
        actr.clear_buffer(buff) 

def setup_dm(word_lists_dict):
    '''
    Add words to declarative memory, since it can be assumed the test subjects know the English language already
    '''
    #print("\n\n############################################# Inside setup_dm i.e. Declarative Memory")
    
    colour_conversion = {'pos': 'GREEN', 'neg': 'RED', 'neu': 'BLACK'}
    for list_idx, word_list in word_lists_dict.items():
        
        for idx, word in enumerate(word_list):
            valence = ''.join([char for char in word if not char.isdigit()])[:3]
            actr.add_dm(('item'+str(idx)+"-"+str(list_idx), 'isa', 'memory', 'word', "'"+word+"'", 'valence', colour_conversion[valence],
                        'context', 'list'+str(list_idx)))
    #         if idx == 0:
    #             print("\n Emaple of a chunk added in Declarative Memory is \n")
    #             print('item'+str(idx), 'isa', 'memory', 'word', "'"+word+"'", 'valence', colour_conversion[valence],"\n")

        #set creation times and times of prior reference for each chunk  
    actr.sdp(':creation-time', -1000, ':reference-list', list(np.linspace(0, -1000, 500)))
     
    
def setup_experiment(human=True):
    '''
    Load the correct ACT-R model, and create a window to display the words
    '''
#     print("\n\n############################################# Inside setup_experiment")
#     print(f'\nSubject = {subject}\n')  

    loaded = None
    if subject == "controls":
        loaded = actr.load_act_r_model(r"C:\Users\cleme\Documents\Education\RUG\First-Year_Research\My_Project\Model\models\general_free_recall_model_v4.3.lisp")
        #loaded = actr.load_act_r_model(r"C:\Users\cleme\Documents\Education\RUG\First-Year_Research\My_Project\Model\models\csm_free_recall_model.lisp")
    elif subject == "depressed":
        loaded = actr.load_act_r_model(r"")
    
    #print("\n\n############################################# Inside setup_experiment")
    #print(f'\nLoaded Act-r model = {loaded}\n')  

    window = actr.open_exp_window("Free Recall Experiment", width=1024, height=768, visible=human) # 15inch resolution window
    actr.install_device(window) 
    return window    

# def record_associated_list(item):
#     '''
#     Register which list the recalled words belong to (to identify prior-list intruisions)
#     '''
#     associated_list = item

def record_words_recalled(item1, item2):
    '''
    Register which words were recalled during the experiment for a specific wordlist and strip the numbers
    '''
    valence = ''.join(char for char in item1 if not char.isdigit())
    item_idx = ''.join(char for char in item1 if char.isdigit())
    context = str(item2)
    
    recalled_words[current_list].append((valence, item_idx, context))
    
    #print(valence, item_idx, context)

def record_words_rehearsed(item):
    '''
    Register amount of rehearsals per word for each wordlist
    '''
    rehearsed_words[current_list][item] += 1

def create_lplot(idx, xlabel, ylabel, x, y, xticks_len, filename, ytick_range=None, show=False):
    '''
    Create line plot using matplotlib
    '''
    plt.figure(idx)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.plot(x, y)
    plt.xticks(np.arange(0, xticks_len, 1)) 
    plt.yticks(ytick_range)
    #plt.savefig("images/"+subject+"_"+filename, bbox_inches='tight')
    if show:
        plt.show()    

        
def create_result_dict():
    '''
    Use a module-level function, instead of lambda function, to enable pickling it
    '''
    return defaultdict(int)

## Creating different pickle files to store results from multiple hyper-parameter values.


def analysis(wlist_amount, show_plots=False):
    '''
    Review results of the recall experiment
    '''
    global results
    result_dict = defaultdict(create_result_dict) # instead of defaultdict(lambda: defaultdict(int))
    first_recall = defaultdict(int)
    recall_probability = defaultdict(int)
    rehearse_frequency = defaultdict(int)
    transitions_amnt = 0
    thought_train_len = []
    

    for key, val in recalled_words.items():
        thought_train_len.extend([(k, sum(1 for _ in count)) for k, count in groupby([val[0] for val in val[2:]])])
        for idx, (retrieved_word, item_num, _) in enumerate(val[2:]):
            if idx != 0:
                if retrieved_word != val[2:][idx-1][0]:
                    transitions_amnt += 1/wlist_amount # average over word lists

    print(f'Avg. Amount of recall transitions = {int(transitions_amnt)}')
    neg_thought_train_len = 0
    neg_divider = 0.0001
    for x in thought_train_len:
        if x[0] == 'negative':
            neg_divider += 1
            neg_thought_train_len += x[1]
    print(f'Avg. Negative Thought train length = {round(neg_thought_train_len/neg_divider, 3)}')            
    
    for list_num, wlist in word_lists_dict.items():
        if list_num < wlist_amount:
            for key, val in recalled_words.items():
                if key==list_num:
                    first_recall[wlist.index(''.join(val[0][0:2]))] += 1
                    for idx, word in enumerate(wlist):
                        first_recall[idx] += 0
                        if ((''.join(char for char in word if not char.isdigit()), 
                             ''.join(char for char in word if char.isdigit()), val[0][2])) in val:
                            recall_probability[idx] += 1
                        else:
                            recall_probability[idx] += 0
                for retrieved_word, item_num, list_idx in val[2:4]:
                    result_dict["pstart"][retrieved_word] += 1  
                for retrieved_word, item_num, list_idx in val[4:-2]:
                    result_dict["pstay"][retrieved_word] += 1
                for retrieved_word, item_num, list_idx in val[-2:]:
                    result_dict["pstop"][retrieved_word] += 1 
            for key, val in rehearsed_words.items():
                if key==list_num:
                    for idx, word in enumerate(wlist):
                        rehearse_frequency[idx] += rehearsed_words[key][word]
    
    
    for key, val in first_recall.items():
        first_recall[key] = val/wlist_amount

    for key, val in recall_probability.items():
        recall_probability[key] = val/wlist_amount

    for key, val in rehearse_frequency.items():
        rehearse_frequency[key] = val/wlist_amount      
        
    
    #Calculate prior-list intrustions
    #subjects committed an average of 0.61 PLIs per list (Zaromb et al., 2006)
    
    if len(recalled_words) > 1:
        overall_pli = 0
        for key, value in recalled_words.items():
            if key > 0:
                intruding_list = []
                pli = 0
                for word_info in value:
                    associated_list = int(re.findall(r'\d+', word_info[2])[0]) #extract just the number from the context and turn into int
                    if associated_list != key:
                        intruding_list.append(associated_list)
                        pli += 1

                print(f'PLIs on list {key}: {pli}')
                if intruding_list:
                    print(f'The PLIs came from {intruding_list}')
                overall_pli += pli

        print(f'Average number of PLIs: {overall_pli/(len(recalled_words)-1)}') #minus 1 because no PLI possible on LIST0

    

    xticks_len = len(word_lists_dict[0])
    
    
    #results['x']['data'].append(range(len(word_lists_dict[0])))
    #results['xticks_len']['data'].append(len(word_lists_dict[0]) )
    results['rehearse_frequency']['data'] = list(rehearse_frequency.values())
    results['recall_probability']['data'] = list(recall_probability.values())
    results['first_recall']['data'] = list(first_recall.values()) 
    
    with open(filename, 'w') as outfile:
        json.dump(results, outfile)
        
    create_lplot(0, 'Serial input position', 'Rehearse Frequency', range(len(word_lists_dict[0])), list(rehearse_frequency.values()), 
                xticks_len, f'rehearse_frequency_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}_{delay}.png', None, show_plots)

    create_lplot(1, 'Serial input position', 'Starting Recall', range(len(word_lists_dict[0])), list(first_recall.values()), 
                xticks_len, f'starting_recall_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}_{delay}.png', np.arange(0, .5, .1), show_plots)                

    create_lplot(2, 'Serial input position', 'Recall Probability', range(len(word_lists_dict[0])), list(recall_probability.values()), 
                xticks_len, f'recall_probability_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}_{delay}.png', np.arange(0, 1, .1), show_plots)   
    
#     create_lplot(3, 'Serial input position', 'Accuracy', range(len(word_lists_dict[0])), list(recall_accuracy.values()), 
#                 xticks_len, 'recall_accuracy.png', np.arange(0, 1, .1), show_plots) 

    file = open("results_"+subject+".pickle","wb")
    pickle.dump(result_dict, file)
    file.close()

    return result_dict

def do_experiment(subj="depressed", human=False, wlist_amount=2000):
    '''
    Run the experiment
    '''
    check_and_create_lists()
    global subject,word_lists_dict
    
    
    subject = subj
    assert wlist_amount <= len(word_lists_dict), "Chosen too many lists, choose less or create more word lists using function: create_lists()"
    
#     print("###################################################\n")
#     print("The original word list \n")
#     print(display_word_lists())
    
#     print("\n###################################################\n")
#     print("Experiment started, Trying to understand the flow\n")
    
    buffers_to_clear = ['goal', "imaginal", "retrieval", "production"]
    
    actr.reset()
                  
    window = setup_experiment(human)
                  
    setup_dm(word_lists_dict)

    for idx, (key, value) in enumerate(word_lists_dict.items()):
        
        #window = setup_experiment(human)

        global current_list
        current_list = idx # keep track for which list words are recalled

        #setup_dm(key, value)
        
        prepare_for_memorization()
        
        actr.mod_focus('context', 'list'+str(current_list))
        
        #actr.load_act_r_code('~;Users;cleme;Documents;Education;RUG;First-Year_Research;My_Project;Model;modelsset_all_base_levels.lisp')
    
        actr.add_command("retrieved-word", record_words_recalled,"Retrieves recalled words.")
        actr.add_command("rehearsed-word", record_words_rehearsed,"Retrieves rehearsed words.")
        
    
#         print("\n##################  Model started rehearsal ")
        for idx, word in enumerate(value):
            if "neutral" in word:
                color = "black"
            elif "positive" in word:
                color = "green"
            else:
                color = "red"
            actr.add_text_to_exp_window(window, word, x=475-len(word) , y=374, color=color, font_size=20) # change later 
            print(idx, word, f'list{key}')
            
            actr.run(rehearsal_time, human) # True when choosing Human, False when choosing differently
            
            #actr.whynot_dm()
            #actr.print_dm_finsts()
            #print(actr.buffer_chunk('goal'))
#             actr.buffer_status('retrieval')
#             actr.buffer_status('imaginal')
            
            actr.clear_exp_window(window)
            actr.run(0.5, human)  # 500-ms blank screen 
        
        prepare_for_recall()
        
        actr.mod_focus('state', 'beginrecall')
        
        actr.remove_command("rehearsed-word")
#         print("\n##################  Model finished rehearsal, list of rehearsed words is ")
#         print(f'{rehearsed_words}\n')
#         print("\n##################  Model started recall ")
        #actr.goal_focus("startrecall") # set goal to start recalling
    
        actr.run(recall_time, human)  
        
#         for buffer in buffers_to_clear:
#             actr.clear_buffer(buffer)
        stop_recall(human)
    
        actr.remove_command("retrieved-word")
        
#         print("\n##################  Model finished recall, list of recalled words is ")
#         print(f'{recalled_words}\n')
        print(f'Experiment {idx+1}/{wlist_amount} completed!', end="\r")
        if idx == wlist_amount-1: # run for a chosen amount of word lists
            break
    close_exp_window() # close window at end of experiment
    

    avg_recalled, avg_recalled_unique = 0, 0
    for key, val in recalled_words.items():
        print(val)
        print(len(val))
        avg_recalled += len(val)
        avg_recalled_unique += len(set(val))
        print(f'\n\nList {key} (length={len(val)}, unique={len(set(val))})\n')
    
    num_recalled = avg_recalled//wlist_amount
    num_unique_recalled = avg_recalled_unique//wlist_amount
    
    print(f'Avg. Number of words recalled = {num_recalled}')
    print(f'Avg. Number of unique words recalled = {num_unique_recalled}')
    
    #analysis(list_amount, False)
    results = analysis(list_amount, False)        

    for key, val in results.items():
        print(f'{key} = {dict(val)}')
    print()
 

    print("\n\n#############################################")
    print(f'\n[{subj}] Results!\n')
    return num_recalled, num_unique_recalled, results

# %%
num_agents = 3 #set number of agents per condition
num_lists = 3 #number of lists per agent

#experimental conditions [rehearsal time, list length] from Murdock 1962 (and van Vugt 2012 [6,20])
experimental_setup = [[1,40]] #[2,15],[2,20],[1,20], ,[6,20]

#to save files to different directory for different numbers of agents
output_path = f'./murdock/agents_{num_agents}/'
if not os.path.isdir(output_path):
    os.mkdir(f'murdock/agents_{num_agents}/')
path = output_path

total_recalled = 0
total_unique = 0

results_dict = {}
for parameter in experimental_setup:
    rh = parameter[0]
    ll = parameter[1]
    
    print("-------------------------------------------------------------------")
    print("Experimental condition:")
    print(f"Number of lists: {num_lists}")
    print(f"Words per list: {ll}")
    print(f"Rehearsal time: {rh} seconds")
    
    for agent in range(num_agents):
        print("-------------------------------------------------------------------")
        print(f"Started for agent_{agent}")
        print(f"Words per list: {ll}, rehearsal time: {rh} sec")
        __init__(agent, rehearsal_time=rh, list_length=ll, list_amount=num_lists, path=path)

        try:
            num_recalled, num_unique, results = do_experiment('controls',False,list_amount)
            total_recalled += num_recalled
            total_unique += num_unique
        
        except ValueError:
            print("\nAgent recalled 0 items.")

    avg_recall = total_recalled // num_agents
    avg_unique = total_unique / num_agents
    

    results_dict[f'Rate: {rh}, Items: {ll}'] = [avg_recall, avg_unique]
    
    print(f"Experimental Condition\nWords per list: {ll}, rehearsal time: {rh} sec")
    print(f"\nAverage number of recalled words ({num_agents} agents): {avg_recall}")
    print(f"Unique: {avg_unique}")

for key, value in results_dict.items():
    print(key)
    print(f'\nAverage number of recalled words: {value[0]}')
    print(f'\nAverage number of unique words: {value[1]}')
    print('-------------------------------------------------------------\n')
# Out:
# -------------------------------------------------------------------
# Experimental condition:
# Number of lists: 3
# Words per list: 40
# Rehearsal time: 1 seconds
# -------------------------------------------------------------------
# Started for agent_0
# Words per list: 40, rehearsal time: 1 sec
#
# Succesfully loaded the word lists!
#
# #|Warning: Chunk-type RECALL has the same specification as the chunk-type STUDY-WORDS. |#
# #|Warning: Chunk-type RECALL has the same specification as the chunk-type STUDY-WORDS. |#
# 0 neutral315 list0
#      0.000   GOAL                   SET-BUFFER-CHUNK GOAL GOAL NIL
#      0.000   GOAL                   SET-BUFFER-CHUNK GOAL GOAL NIL
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.050   PROCEDURAL             PRODUCTION-FIRED FIND-UNATTENDED-WORD
# LIST0
#      0.050   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0
#      0.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.235   PROCEDURAL             PRODUCTION-FIRED ATTEND-WORD
#      0.285   PROCEDURAL             PRODUCTION-FIRED HIGH-THIRD
#      0.485   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK0
#      0.685   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-3
#      0.735   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-3
#      0.817   DECLARATIVE            RETRIEVAL-FAILURE
#      0.867   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#      0.917   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#      0.967   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#      1.000   ------                 Stopped because time limit reached
#      1.017   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#      1.090   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0-0
#      1.500   ------                 Stopped because time limit reached
# 1 neutral83 list0
#      1.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION1 NIL
#      1.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT1 NIL
#      1.590   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral315"
#      1.640   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      1.790   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK1
#      1.840   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#      2.040   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK2
#      2.240   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#      2.290   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#      2.372   DECLARATIVE            RETRIEVAL-FAILURE
#      2.422   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#      2.472   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#      2.500   ------                 Stopped because time limit reached
#      2.522   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#      2.572   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#      2.654   DECLARATIVE            RETRIEVAL-FAILURE
#      2.704   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-3
#      2.754   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH-DEFAULT
#      2.804   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#      2.854   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#      2.904   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD-DEFAULT
#      2.954   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH-DEFAULT
#      3.000   ------                 Stopped because time limit reached
# 2 positive454 list0
#      3.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION2 NIL
#      3.004   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#      3.054   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#      3.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT2 NIL
#      3.104   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD-DEFAULT
#      3.154   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      3.204   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#      3.404   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK3
#      3.604   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#      3.654   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#      3.687   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM2-0
#      4.000   ------                 Stopped because time limit reached
#      4.187   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive454"
#      4.237   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#      4.287   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#      4.337   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD-DEFAULT
#      4.387   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      4.387   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK4
#      4.399   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM2-0
#      4.500   ------                 Stopped because time limit reached
# 3 negative323 list0
#      4.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION3 NIL
#      4.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT3 NIL
#      4.899   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive454"
#      4.949   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      5.099   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK5
#      5.149   PROCEDURAL             PRODUCTION-FIRED HIGH-THIRD
#      5.349   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK6
#      5.500   ------                 Stopped because time limit reached
#      5.549   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-3
#      5.599   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-3
#      5.636   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM3-0
#      6.000   ------                 Stopped because time limit reached
# 4 positive284 list0
#      6.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION4 NIL
#      6.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT4 NIL
#      6.136   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative323"
#      6.186   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      6.336   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK7
#      6.386   PROCEDURAL             PRODUCTION-FIRED HIGH-SECOND
#      6.586   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK8
#      6.786   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#      6.836   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-2
#      6.889   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM4-0
#      7.000   ------                 Stopped because time limit reached
#      7.389   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive284"
#      7.439   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#      7.489   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#      7.500   ------                 Stopped because time limit reached
# 5 neutral434 list0
#      7.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION5 NIL
#      7.502   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM4-0
#      7.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT5 NIL
#      7.589   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK9
#      8.089   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive284"
#      8.139   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      8.289   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK10
#      8.339   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#      8.500   ------                 Stopped because time limit reached
#      8.539   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK11
#      8.739   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#      8.789   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-1
#      8.831   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM5-0
#      9.000   ------                 Stopped because time limit reached
# 6 negative270 list0
#      9.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION6 NIL
#      9.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT6 NIL
#      9.331   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral434"
#      9.381   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      9.531   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK12
#      9.581   PROCEDURAL             PRODUCTION-FIRED REPLACE-SECOND
#      9.781   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK13
#      9.981   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#     10.000   ------                 Stopped because time limit reached
#     10.031   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-2
#     10.104   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM6-0
#     10.500   ------                 Stopped because time limit reached
# 7 positive343 list0
#     10.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION7 NIL
#     10.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT7 NIL
#     10.604   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative270"
#     10.654   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     10.804   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK14
#     10.854   PROCEDURAL             PRODUCTION-FIRED REPLACE-THIRD
#     11.054   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK15
#     11.254   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-3
#     11.304   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-3
#     11.310   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM7-0
#     11.500   ------                 Stopped because time limit reached
#     11.810   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive343"
#     11.860   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     11.911   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM5-0
#     12.000   ------                 Stopped because time limit reached
# 8 negative295 list0
#     12.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION8 NIL
#     12.010   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK16
#     12.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT8 NIL
#     12.510   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral434"
#     12.560   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     12.710   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK17
#     12.760   PROCEDURAL             PRODUCTION-FIRED REPLACE-FIRST
#     12.960   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK18
#     13.000   ------                 Stopped because time limit reached
#     13.160   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#     13.210   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-1
#     13.247   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM8-0
#     13.500   ------                 Stopped because time limit reached
# 9 positive509 list0
#     13.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION9 NIL
#     13.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT9 NIL
#     13.747   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative295"
#     13.797   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     13.947   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK19
#     13.997   PROCEDURAL             PRODUCTION-FIRED REPLACE-FOURTH
#     14.197   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK20
#     14.397   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     14.447   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     14.500   ------                 Stopped because time limit reached
#     14.529   DECLARATIVE            RETRIEVAL-FAILURE
#     14.579   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     14.629   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     14.711   DECLARATIVE            RETRIEVAL-FAILURE
#     14.761   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-1
#     14.811   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     14.893   DECLARATIVE            RETRIEVAL-FAILURE
#     14.943   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-2
#     14.993   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     15.000   ------                 Stopped because time limit reached
# 10 negative92 list0
#     15.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION10 NIL
#     15.041   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM7-0
#     15.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT10 NIL
#     15.541   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive343"
#     15.591   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     15.741   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK21
#     15.791   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     15.991   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK22
#     16.000   ------                 Stopped because time limit reached
#     16.191   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     16.241   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     16.244   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM10-0
#     16.500   ------                 Stopped because time limit reached
# 11 neutral241 list0
#     16.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION11 NIL
#     16.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT11 NIL
#     16.744   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative92"
#     16.794   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     16.944   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK23
#     16.994   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#     17.194   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK24
#     17.394   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#     17.444   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-1
#     17.495   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM11-0
#     17.500   ------                 Stopped because time limit reached
#     17.995   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral241"
#     18.000   ------                 Stopped because time limit reached
# 12 positive102 list0
#     18.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION12 NIL
#     18.045   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     18.069   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM11-0
#     18.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT12 NIL
#     18.195   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK25
#     18.695   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral241"
#     18.745   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     18.895   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK26
#     18.945   PROCEDURAL             PRODUCTION-FIRED HIGH-SECOND
#     19.000   ------                 Stopped because time limit reached
#     19.145   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK27
#     19.345   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#     19.395   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-2
#     19.477   DECLARATIVE            RETRIEVAL-FAILURE
#     19.500   ------                 Stopped because time limit reached
# 13 negative12 list0
#     19.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION13 NIL
#     19.527   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     19.577   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     19.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT13 NIL
#     19.590   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM11-0
#     20.090   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral241"
#     20.140   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     20.290   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK28
#     20.340   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     20.500   ------                 Stopped because time limit reached
#     20.540   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK29
#     20.740   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     20.790   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     20.838   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM13-0
#     21.000   ------                 Stopped because time limit reached
# 14 positive44 list0
#     21.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION14 NIL
#     21.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT14 NIL
#     21.338   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative12"
#     21.388   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     21.538   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK30
#     21.588   PROCEDURAL             PRODUCTION-FIRED REPLACE-FIRST
#     21.788   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK31
#     21.988   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#     22.000   ------                 Stopped because time limit reached
#     22.038   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-1
#     22.120   DECLARATIVE            RETRIEVAL-FAILURE
#     22.170   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     22.220   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     22.227   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM14-0
#     22.500   ------                 Stopped because time limit reached
# 15 negative200 list0
#     22.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION15 NIL
#     22.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT15 NIL
#     22.727   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive44"
#     22.777   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     22.927   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK32
#     22.977   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     23.177   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK33
#     23.377   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     23.427   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     23.500   ------                 Stopped because time limit reached
#     23.509   DECLARATIVE            RETRIEVAL-FAILURE
#     23.559   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     23.609   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     23.691   DECLARATIVE            RETRIEVAL-FAILURE
#     23.741   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-1
#     23.791   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     23.873   DECLARATIVE            RETRIEVAL-FAILURE
#     23.923   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-2
#     23.973   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD-DEFAULT
#     24.000   ------                 Stopped because time limit reached
# 16 positive226 list0
#     24.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION16 NIL
#     24.023   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH-DEFAULT
#     24.073   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     24.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT16 NIL
#     24.123   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#     24.173   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     24.223   PROCEDURAL             PRODUCTION-FIRED HIGH-SECOND
#     24.423   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK34
#     24.623   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#     24.673   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-2
#     24.755   DECLARATIVE            RETRIEVAL-FAILURE
#     24.805   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     24.855   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     24.905   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     24.987   DECLARATIVE            RETRIEVAL-FAILURE
#     25.000   ------                 Stopped because time limit reached
#     25.037   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-2
#     25.087   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     25.109   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM7-0
#     25.500   ------                 Stopped because time limit reached
# 17 negative300 list0
#     25.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION17 NIL
#     25.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT17 NIL
#     25.609   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive343"
#     25.659   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     25.809   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK35
#     25.859   PROCEDURAL             PRODUCTION-FIRED HIGH-SECOND
#     26.059   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK36
#     26.259   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#     26.309   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-2
#     26.320   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM17-0
#     26.500   ------                 Stopped because time limit reached
#     26.820   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative300"
#     26.870   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     26.920   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     26.944   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM17-0
#     27.000   ------                 Stopped because time limit reached
# 18 positive452 list0
#     27.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION18 NIL
#     27.020   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK37
#     27.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT18 NIL
#     27.520   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative300"
#     27.570   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     27.720   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK38
#     27.770   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     27.970   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK39
#     28.000   ------                 Stopped because time limit reached
#     28.170   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     28.220   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     28.274   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM18-0
#     28.500   ------                 Stopped because time limit reached
# 19 negative467 list0
#     28.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION19 NIL
#     28.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT19 NIL
#     28.774   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive452"
#     28.824   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     28.974   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK40
#     29.024   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#     29.224   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK41
#     29.424   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#     29.474   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-1
#     29.500   ------                 Stopped because time limit reached
#     29.556   DECLARATIVE            RETRIEVAL-FAILURE
#     29.606   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     29.656   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     29.738   DECLARATIVE            RETRIEVAL-FAILURE
#     29.788   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-1
#     29.838   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     29.874   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM17-0
#     30.000   ------                 Stopped because time limit reached
# 20 positive518 list0
#     30.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION20 NIL
#     30.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT20 NIL
#     30.374   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative300"
#     30.424   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     30.574   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK42
#     30.624   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     30.824   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK43
#     31.000   ------                 Stopped because time limit reached
#     31.024   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     31.074   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     31.133   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM20-0
#     31.500   ------                 Stopped because time limit reached
# 21 neutral100 list0
#     31.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION21 NIL
#     31.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT21 NIL
#     31.633   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive518"
#     31.683   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     31.833   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK44
#     31.883   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#     32.083   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK45
#     32.283   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#     32.333   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-1
#     32.415   DECLARATIVE            RETRIEVAL-FAILURE
#     32.465   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     32.500   ------                 Stopped because time limit reached
#     32.515   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     32.557   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM21-0
#     33.000   ------                 Stopped because time limit reached
# 22 negative290 list0
#     33.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION22 NIL
#     33.057   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral100"
#     33.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT22 NIL
#     33.107   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     33.133   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM17-0
#     33.257   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK46
#     33.757   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative300"
#     33.807   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     33.957   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK47
#     34.000   ------                 Stopped because time limit reached
#     34.007   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     34.207   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK48
#     34.407   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     34.457   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     34.464   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM24-0
#     34.500   ------                 Stopped because time limit reached
# 23 neutral421 list0
#     34.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION23 NIL
#     34.514   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT-WRONG-WORD
# "negative71"
#     34.564   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     34.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT23 NIL
#     34.614   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     34.696   DECLARATIVE            RETRIEVAL-FAILURE
#     34.714   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK49
#     34.746   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-2
#     34.796   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     34.846   PROCEDURAL             PRODUCTION-FIRED HIGH-SECOND
#     35.046   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK50
#     35.246   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#     35.296   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-2
#     35.314   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM23-0
#     35.500   ------                 Stopped because time limit reached
#     35.814   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral421"
#     35.864   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     35.910   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM21-0
#     36.000   ------                 Stopped because time limit reached
# 24 negative71 list0
#     36.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION24 NIL
#     36.014   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK51
#     36.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT24 NIL
#     36.514   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral100"
#     36.564   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     36.714   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK52
#     36.764   PROCEDURAL             PRODUCTION-FIRED REPLACE-FOURTH
#     36.964   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK53
#     37.000   ------                 Stopped because time limit reached
#     37.164   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     37.214   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     37.231   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM24-0
#     37.500   ------                 Stopped because time limit reached
# 25 neutral245 list0
#     37.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION25 NIL
#     37.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT25 NIL
#     37.731   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative71"
#     37.781   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     37.931   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK54
#     37.981   PROCEDURAL             PRODUCTION-FIRED REPLACE-THIRD
#     38.181   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK55
#     38.381   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-3
#     38.431   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-3
#     38.446   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM25-0
#     38.500   ------                 Stopped because time limit reached
#     38.946   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral245"
#     38.996   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     39.000   ------                 Stopped because time limit reached
# 26 positive480 list0
#     39.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION26 NIL
#     39.078   DECLARATIVE            RETRIEVAL-FAILURE
#     39.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT26 NIL
#     39.128   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-1
#     39.146   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK56
#     39.178   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     39.228   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#     39.428   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK57
#     39.628   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#     39.678   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-1
#     39.735   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM26-0
#     40.000   ------                 Stopped because time limit reached
#     40.235   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive480"
#     40.285   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     40.367   DECLARATIVE            RETRIEVAL-FAILURE
#     40.417   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-1
#     40.435   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK58
#     40.467   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     40.500   ------                 Stopped because time limit reached
# 27 negative400 list0
#     40.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION27 NIL
#     40.509   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM23-0
#     40.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT27 NIL
#     41.009   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral421"
#     41.059   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     41.209   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK59
#     41.259   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#     41.459   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK60
#     41.500   ------                 Stopped because time limit reached
#     41.659   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#     41.709   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-1
#     41.791   DECLARATIVE            RETRIEVAL-FAILURE
#     41.841   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     41.891   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     41.973   DECLARATIVE            RETRIEVAL-FAILURE
#     42.000   ------                 Stopped because time limit reached
# 28 neutral972 list0
#     42.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION28 NIL
#     42.023   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-1
#     42.073   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     42.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT28 NIL
#     42.155   DECLARATIVE            RETRIEVAL-FAILURE
#     42.205   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-2
#     42.255   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     42.305   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     42.505   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK61
#     42.705   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     42.755   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     42.831   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM28-0
#     43.000   ------                 Stopped because time limit reached
#     43.331   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral972"
#     43.381   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     43.431   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#     43.481   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     43.500   ------                 Stopped because time limit reached
# 29 positive954 list0
#     43.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION29 NIL
#     43.531   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK62
#     43.563   DECLARATIVE            RETRIEVAL-FAILURE
#     43.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT29 NIL
#     43.613   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-3
#     43.663   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     43.713   PROCEDURAL             PRODUCTION-FIRED HIGH-THIRD
#     43.913   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK63
#     44.113   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-3
#     44.163   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-3
#     44.245   DECLARATIVE            RETRIEVAL-FAILURE
#     44.295   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     44.345   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     44.395   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#     44.445   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD-DEFAULT
#     44.495   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH-DEFAULT
#     44.500   ------                 Stopped because time limit reached
#     44.545   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     44.595   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#     44.645   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     44.683   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM29-0
#     45.000   ------                 Stopped because time limit reached
# 30 neutral872 list0
#     45.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION30 NIL
#     45.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT30 NIL
#     45.183   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive954"
#     45.233   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     45.383   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK64
#     45.433   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     45.633   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK65
#     45.833   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     45.883   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     45.925   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM30-0
#     46.000   ------                 Stopped because time limit reached
#     46.425   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral872"
#     46.475   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     46.500   ------                 Stopped because time limit reached
# 31 negative398 list0
#     46.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION31 NIL
#     46.525   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#     46.575   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     46.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT31 NIL
#     46.625   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK66
#     46.657   DECLARATIVE            RETRIEVAL-FAILURE
#     46.707   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-3
#     46.757   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     46.807   PROCEDURAL             PRODUCTION-FIRED HIGH-SECOND
#     47.007   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK67
#     47.207   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#     47.257   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-2
#     47.339   DECLARATIVE            RETRIEVAL-FAILURE
#     47.389   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     47.439   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     47.489   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     47.500   ------                 Stopped because time limit reached
#     47.526   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM31-0
#     48.000   ------                 Stopped because time limit reached
# 32 neutral889 list0
#     48.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION32 NIL
#     48.026   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "negative398"
#     48.076   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD-DEFAULT
#     48.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT32 NIL
#     48.126   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH-DEFAULT
#     48.176   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     48.226   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK68
#     48.276   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#     48.476   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK69
#     48.676   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#     48.726   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-1
#     48.767   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM32-0
#     49.000   ------                 Stopped because time limit reached
#     49.267   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral889"
#     49.317   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     49.342   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM32-0
#     49.467   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK70
#     49.500   ------                 Stopped because time limit reached
# 33 positive248 list0
#     49.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION33 NIL
#     49.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT33 NIL
#     49.967   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral889"
#     50.017   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     50.167   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK71
#     50.217   PROCEDURAL             PRODUCTION-FIRED HIGH-THIRD
#     50.417   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK72
#     50.500   ------                 Stopped because time limit reached
#     50.617   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-3
#     50.667   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-3
#     50.749   DECLARATIVE            RETRIEVAL-FAILURE
#     50.799   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     50.849   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     50.871   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM32-0
#     51.000   ------                 Stopped because time limit reached
# 34 neutral552 list0
#     51.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION34 NIL
#     51.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT34 NIL
#     51.371   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral889"
#     51.421   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     51.571   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK73
#     51.621   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     51.821   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK74
#     52.000   ------                 Stopped because time limit reached
#     52.021   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     52.071   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     52.153   DECLARATIVE            RETRIEVAL-FAILURE
#     52.203   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     52.253   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     52.309   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM32-0
#     52.500   ------                 Stopped because time limit reached
# 35 negative632 list0
#     52.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION35 NIL
#     52.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT35 NIL
#     52.809   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral889"
#     52.859   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     53.009   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK75
#     53.059   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     53.259   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK76
#     53.459   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     53.500   ------                 Stopped because time limit reached
#     53.509   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     53.591   DECLARATIVE            RETRIEVAL-FAILURE
#     53.641   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     53.691   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     53.720   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM32-0
#     54.000   ------                 Stopped because time limit reached
# 36 neutral789 list0
#     54.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION36 NIL
#     54.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT36 NIL
#     54.220   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral889"
#     54.270   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     54.420   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK77
#     54.470   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     54.670   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK78
#     54.870   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     54.920   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     54.944   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM36-0
#     55.000   ------                 Stopped because time limit reached
#     55.444   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral789"
#     55.494   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     55.500   ------                 Stopped because time limit reached
# 37 positive453 list0
#     55.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION37 NIL
#     55.576   DECLARATIVE            RETRIEVAL-FAILURE
#     55.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT37 NIL
#     55.626   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-1
#     55.644   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK79
#     55.676   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     55.726   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#     55.926   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK80
#     56.126   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#     56.176   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-1
#     56.258   DECLARATIVE            RETRIEVAL-FAILURE
#     56.308   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     56.358   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     56.380   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM37-0
#     56.500   ------                 Stopped because time limit reached
#     56.880   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "positive453"
#     56.930   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     57.000   ------                 Stopped because time limit reached
# 38 negative805 list0
#     57.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION38 NIL
#     57.012   DECLARATIVE            RETRIEVAL-FAILURE
#     57.062   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-2
#     57.080   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK81
#     57.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT38 NIL
#     57.112   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     57.194   DECLARATIVE            RETRIEVAL-FAILURE
#     57.244   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-3
#     57.294   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     57.344   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     57.544   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK82
#     57.744   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     57.794   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     57.876   DECLARATIVE            RETRIEVAL-FAILURE
#     57.926   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-4
#     57.976   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     58.000   ------                 Stopped because time limit reached
#     58.026   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#     58.076   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD-DEFAULT
#     58.126   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH-DEFAULT
#     58.176   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     58.258   DECLARATIVE            RETRIEVAL-FAILURE
#     58.308   PROCEDURAL             PRODUCTION-FIRED FORGET-WORD-1
#     58.358   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#     58.408   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD-DEFAULT
#     58.458   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH-DEFAULT
#     58.500   ------                 Stopped because time limit reached
# 39 neutral834 list0
#     58.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION39 NIL
#     58.508   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
#     58.558   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND-DEFAULT
#     58.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT39 NIL
#     58.608   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD-DEFAULT
#     58.658   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     58.708   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#     58.908   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK83
#     59.108   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     59.158   PROCEDURAL             PRODUCTION-FIRED REINFORCE-NEW-WORD-4
#     59.220   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM39-0
#     59.500   ------                 Stopped because time limit reached
#     59.720   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
# "neutral834"
#     59.770   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST-DEFAULT
# ...
# "neutral737" LIST2
#    245.355   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    245.361   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM2-2
#    245.861   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative776" LIST2
#    245.911   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    245.918   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM32-2
#    246.418   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative893" LIST2
#    246.468   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    246.498   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM35-2
#    246.998   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral233" LIST2
#    247.048   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    247.049   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM34-2
#    247.549   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative506" LIST2
#    247.599   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    247.604   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM31-2
#    248.104   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral320" LIST2
#    248.154   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    248.172   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM6-2
#    248.672   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral162" LIST2
#    248.722   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    248.726   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM18-2
#    249.226   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative947" LIST2
#    249.276   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    249.297   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM16-2
#    249.797   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative474" LIST2
#    249.847   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    249.856   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1-2
#    250.356   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral739" LIST2
#    250.406   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    250.412   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM17-2
#    250.912   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "positive309" LIST2
#    250.962   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    250.966   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM24-2
#    251.466   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral473" LIST2
#    251.516   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    251.522   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM33-2
#    252.022   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "positive201" LIST2
#    252.072   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    252.081   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM3-2
#    252.581   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "positive274" LIST2
#    252.631   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    252.637   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM29-2
#    253.137   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral559" LIST2
#    253.187   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    253.198   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM10-2
#    253.698   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral360" LIST2
#    253.748   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    253.754   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM15-2
#    254.254   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "positive721" LIST2
#    254.304   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    254.304   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM25-2
#    254.804   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "positive363" LIST2
#    254.854   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    254.863   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM26-2
#    255.363   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative530" LIST2
#    255.413   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    255.430   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM28-2
#    255.930   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative573" LIST2
#    255.980   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    255.983   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM14-2
#    256.483   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral240" LIST2
#    256.533   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    256.536   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM38-2
#    257.036   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral132" LIST2
#    257.086   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    257.098   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM37-2
#    257.598   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative172" LIST2
#    257.648   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    257.656   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM30-2
#    258.156   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative262" LIST2
#    258.206   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    258.217   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM32-2
#    258.717   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative893" LIST2
#    258.767   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    258.769   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM36-2
#    259.269   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "positive408" LIST2
#    259.319   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    259.328   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM27-2
#    259.828   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral47" LIST2
#    259.878   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    259.886   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM20-2
#    260.386   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative640" LIST2
#    260.436   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    260.487   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM34-2
#    260.987   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative506" LIST2
#    261.037   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    261.049   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM9-2
#    261.549   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative798" LIST2
#    261.599   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    261.602   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM7-2
#    262.102   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "positive552" LIST2
#    262.152   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    262.164   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM6-2
#    262.664   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral162" LIST2
#    262.714   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    262.746   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM22-2
#    263.246   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative66" LIST2
#    263.296   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    263.336   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM24-2
#    263.836   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral473" LIST2
#    263.886   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    263.890   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0-2
#    264.390   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral858" LIST2
#    264.440   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    264.451   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM8-2
#    264.951   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral25" LIST2
#    265.001   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    265.007   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM18-2
#    265.507   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative947" LIST2
#    265.557   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    265.589   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM4-2
#    266.089   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral955" LIST2
#    266.139   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    266.159   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM21-2
#    266.659   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral901" LIST2
#    266.709   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    266.717   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM23-2
#    267.217   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "positive21" LIST2
#    267.267   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    267.279   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM26-2
#    267.779   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative530" LIST2
#    267.829   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    267.844   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM12-2
#    268.344   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral737" LIST2
#    268.394   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    268.398   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM5-2
#    268.898   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative62" LIST2
#    268.948   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    268.967   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM35-2
#    269.467   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral233" LIST2
#    269.517   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    269.534   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM2-2
#    270.034   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative776" LIST2
#    270.084   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    270.085   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM19-2
#    270.585   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "positive334" LIST2
#    270.635   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    270.655   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM31-2
#    271.155   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "neutral320" LIST2
#    271.205   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    271.219   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM28-2
#    271.719   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "negative573" LIST2
#    271.769   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#    271.781   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM15-2
#    272.047   ------                 Stopped because time limit reached
#    272.281   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
# "positive721" LIST2
#    272.281   ------                 Stopped because no events left to process
# [('neutral', '834', 'LIST0')]
# 1
#
#
# List 0 (length=1, unique=1)
#
# [('neutral', '233', 'LIST2'), ('negative', '706', 'LIST2'), ('negative', '530', 'LIST2'), ('neutral', '955', 'LIST2'), ('negative', '640', 'LIST2'), ('neutral', '25', 'LIST2'), ('negative', '262', 'LIST2'), ('positive', '363', 'LIST2'), ('negative', '66', 'LIST2'), ('negative', '947', 'LIST2'), ('neutral', '162', 'LIST2'), ('negative', '172', 'LIST2'), ('neutral', '901', 'LIST2'), ('positive', '721', 'LIST2'), ('neutral', '473', 'LIST2'), ('positive', '637', 'LIST2'), ('positive', '309', 'LIST2'), ('neutral', '858', 'LIST2'), ('neutral', '240', 'LIST2'), ('positive', '201', 'LIST2'), ('positive', '334', 'LIST2'), ('neutral', '737', 'LIST2'), ('negative', '798', 'LIST2'), ('negative', '776', 'LIST2'), ('positive', '552', 'LIST2'), ('neutral', '559', 'LIST2'), ('negative', '640', 'LIST2'), ('negative', '573', 'LIST2'), ('positive', '21', 'LIST2'), ('neutral', '132', 'LIST2'), ('neutral', '955', 'LIST2'), ('negative', '706', 'LIST2'), ('negative', '805', 'LIST0'), ('negative', '474', 'LIST2'), ('negative', '506', 'LIST2'), ('positive', '274', 'LIST2'), ('neutral', '233', 'LIST2'), ('neutral', '360', 'LIST2'), ('neutral', '25', 'LIST2'), ('negative', '62', 'LIST2'), ('negative', '172', 'LIST2'), ('negative', '530', 'LIST2'), ('neutral', '240', 'LIST2'), ('positive', '201', 'LIST2'), ('negative', '776', 'LIST2'), ('positive', '334', 'LIST2'), ('negative', '798', 'LIST2'), ('positive', '552', 'LIST2'), ('neutral', '320', 'LIST2'), ('positive', '637', 'LIST2'), ('neutral', '47', 'LIST2'), ('negative', '947', 'LIST2'), ('neutral', '473', 'LIST2'), ('negative', '893', 'LIST2'), ('neutral', '955', 'LIST2'), ('neutral', '739', 'LIST2'), ('positive', '721', 'LIST2'), ('neutral', '858', 'LIST2'), ('positive', '408', 'LIST2'), ('positive', '21', 'LIST2'), ('negative', '506', 'LIST2'), ('neutral', '737', 'LIST2'), ('negative', '172', 'LIST2'), ('positive', '274', 'LIST2'), ('neutral', '559', 'LIST2'), ('negative', '530', 'LIST2'), ('negative', '262', 'LIST2'), ('negative', '776', 'LIST2'), ('positive', '363', 'LIST2'), ('positive', '334', 'LIST2'), ('negative', '66', 'LIST2'), ('neutral', '25', 'LIST2'), ('negative', '640', 'LIST2'), ('positive', '309', 'LIST2'), ('neutral', '320', 'LIST2'), ('neutral', '360', 'LIST2'), ('neutral', '473', 'LIST2'), ('negative', '893', 'LIST2'), ('neutral', '858', 'LIST2'), ('neutral', '955', 'LIST2'), ('positive', '201', 'LIST2'), ('negative', '706', 'LIST2'), ('neutral', '47', 'LIST2'), ('positive', '721', 'LIST2'), ('negative', '172', 'LIST2'), ('neutral', '233', 'LIST2'), ('positive', '408', 'LIST2'), ('neutral', '559', 'LIST2'), ('positive', '552', 'LIST2'), ('neutral', '739', 'LIST2'), ('positive', '21', 'LIST2'), ('neutral', '162', 'LIST2'), ('negative', '262', 'LIST2'), ('negative', '573', 'LIST2'), ('negative', '290', 'LIST0'), ('positive', '637', 'LIST2'), ('positive', '274', 'LIST2'), ('positive', '309', 'LIST2'), ('neutral', '473', 'LIST2'), ('positive', '547', 'LIST2'), ('neutral', '240', 'LIST2'), ('positive', '201', 'LIST2'), ('neutral', '360', 'LIST2'), ('neutral', '955', 'LIST2'), ('negative', '805', 'LIST0'), ('positive', '334', 'LIST2'), ('neutral', '47', 'LIST2'), ('negative', '172', 'LIST2'), ('negative', '66', 'LIST2'), ('negative', '62', 'LIST2'), ('positive', '552', 'LIST2'), ('neutral', '737', 'LIST2'), ('negative', '776', 'LIST2'), ('negative', '893', 'LIST2'), ('neutral', '233', 'LIST2'), ('negative', '506', 'LIST2'), ('neutral', '320', 'LIST2'), ('neutral', '162', 'LIST2'), ('negative', '947', 'LIST2'), ('negative', '474', 'LIST2'), ('neutral', '739', 'LIST2'), ('positive', '309', 'LIST2'), ('neutral', '473', 'LIST2'), ('positive', '201', 'LIST2'), ('positive', '274', 'LIST2'), ('neutral', '559', 'LIST2'), ('neutral', '360', 'LIST2'), ('positive', '721', 'LIST2'), ('positive', '363', 'LIST2'), ('negative', '530', 'LIST2'), ('negative', '573', 'LIST2'), ('neutral', '240', 'LIST2'), ('neutral', '132', 'LIST2'), ('negative', '172', 'LIST2'), ('negative', '262', 'LIST2'), ('negative',  ...
# 160
#
#
# List 2 (length=160, unique=42)
#
# Avg. Number of words recalled = 53
# Avg. Number of unique words recalled = 14
# Avg. Amount of recall transitions = 37
# Avg. Negative Thought train length = 1.583
# PLIs on list 2: 3
# The PLIs came from [0, 0, 0]
# Average number of PLIs: 3.0
# pstop = {'neutral': 3, 'negative': 3, 'positive': 3}
# pstart = {'negative': 3, 'neutral': 3}
# pstay = {'negative': 165, 'neutral': 174, 'positive': 123}
#
#
#
# #############################################
#
# [controls] Results!
#
# Experimental Condition
# Words per list: 40, rehearsal time: 1 sec
#
# Average number of recalled words (3 agents): 17
# Unique: 4.666666666666667
# Rate: 1, Items: 40
#
# Average number of recalled words: 17
#
# Average number of unique words: 4.666666666666667
# -------------------------------------------------------------

# %%
max_list_length = 40
f, ax = plt.subplots(1) #set up plot

for parameter in experimental_setup:
    rh = parameter[0] #rehearsal time
    ll = parameter[1] #words per list

    files = [] #Storing all the relevant files to work on them later
    pattern = f"words_{ll}_lists_{num_lists}_rh_time_{rh}*.txt" # Pattern for matching the filename for data retrieval
    for file in os.listdir(path): #Lists all the files and directories within the folder
        if fnmatch.fnmatch(file, pattern): #matches the above declared patter with the filenames from listdir()
            files.append(file) #Appends the file to make it available for later use.
    
    # Initializing all the parameters needed for the plots
    idx = [0,1,2]
    xlabel = 'Serial Input Position'
    ylabel = ['Rehearse Frequency','Starting Probability','Recall Probability']
    xticks_len = max_list_length+10
    rehearse_frequency = []
    recall_probability = []
    first_recall = []
    
    for file in files: #load the result files
        with open(f"{path}/{file}") as f:
            results = json.load(f)
            if results['recall_probability']['data']:
                recall_probability.append(results['recall_probability']['data'])
            else: #if an agent failed to recall anything...
                recall_probability.append([0]*ll)
                
    #calculating avg recall probability per input position across agents            
    avg_recall_probs = [sum(x)/num_agents for x in zip(*recall_probability)]
     
    #plot results
    x = range(ll)
    ax.plot(x, avg_recall_probs, label = f"{ll} items, {rh} sec")
    #ax.set_xlim([0,ll])
    #ax.set_ylim([-.1,1])
    
ax.legend()
ax.legend(title='Condition', bbox_to_anchor=(1.05, 1), loc='upper left') #fontsize='xx-small')

#("murdock/images/"+subject+"_"+filename, bbox_inches='tight')

# %% [markdown]
# ##### do_experiment flow:
#
# 1. check_and_create_lists
# 	a. create_lists
# 	   return word_lists_dict
# 		i. add_words
#             adds to word_lists_dict
#
# 2. setup_experiment
#     returns window
#       model is loaded
#
#
# 3. setup_dm
#
#
# 4. prepare_for_recall
#
#
# 5. close_exp_window
#
#
# 6. analysis
#     return result_dict
#         contains pstart, pstay, pstop
#     prints Avg recall transitions
#
#     prints Avg negative thought train length

# %%
objects = []
with (open(r"word_lists\word_lists_dict_20_3.pickle", "rb")) as openfile:
    while True:
        try:
            objects.append(pickle.load(openfile))
        except EOFError:
            break

# %%
recalled_words
# Out:
# defaultdict(list,
#             {0: [('neutral', '834', 'LIST0')],
#              2: [('neutral', '233', 'LIST2'),
#               ('negative', '706', 'LIST2'),
#               ('negative', '530', 'LIST2'),
#               ('neutral', '955', 'LIST2'),
#               ('negative', '640', 'LIST2'),
#               ('neutral', '25', 'LIST2'),
#               ('negative', '262', 'LIST2'),
#               ('positive', '363', 'LIST2'),
#               ('negative', '66', 'LIST2'),
#               ('negative', '947', 'LIST2'),
#               ('neutral', '162', 'LIST2'),
#               ('negative', '172', 'LIST2'),
#               ('neutral', '901', 'LIST2'),
#               ('positive', '721', 'LIST2'),
#               ('neutral', '473', 'LIST2'),
#               ('positive', '637', 'LIST2'),
#               ('positive', '309', 'LIST2'),
#               ('neutral', '858', 'LIST2'),
#               ('neutral', '240', 'LIST2'),
#               ('positive', '201', 'LIST2'),
#               ('positive', '334', 'LIST2'),
#               ('neutral', '737', 'LIST2'),
#               ('negative', '798', 'LIST2'),
#               ('negative', '776', 'LIST2'),
#               ('positive', '552', 'LIST2'),
#               ('neutral', '559', 'LIST2'),
#               ('negative', '640', 'LIST2'),
#               ('negative', '573', 'LIST2'),
#               ('positive', '21', 'LIST2'),
#               ('neutral', '132', 'LIST2'),
#               ('neutral', '955', 'LIST2'),
#               ('negative', '706', 'LIST2'),
#               ('negative', '805', 'LIST0'),
#               ('negative', '474', 'LIST2'),
#               ('negative', '506', 'LIST2'),
#               ('positive', '274', 'LIST2'),
#               ('neutral', '233', 'LIST2'),
#               ('neutral', '360', 'LIST2'),
#               ('neutral', '25', 'LIST2'),
#               ('negative', '62', 'LIST2'),
#               ('negative', '172', 'LIST2'),
#               ('negative', '530', 'LIST2'),
#               ('neutral', '240', 'LIST2'),
#               ('positive', '201', 'LIST2'),
#               ('negative', '776', 'LIST2'),
#               ('positive', '334', 'LIST2'),
#               ('negative', '798', 'LIST2'),
#               ('positive', '552', 'LIST2'),
#               ('neutral', '320', 'LIST2'),
#               ('positive', '637', 'LIST2'),
#               ('neutral', '47', 'LIST2'),
#               ('negative', '947', 'LIST2'),
#               ('neutral', '473', 'LIST2'),
#               ('negative', '893', 'LIST2'),
#               ('neutral', '955', 'LIST2'),
#               ('neutral', '739', 'LIST2'),
#               ('positive', '721', 'LIST2'),
#               ('neutral', '858', 'LIST2'),
#               ('positive', '408', 'LIST2'),
#               ('positive', '21', 'LIST2'),
#               ('negative', '506', 'LIST2'),
#               ('neutral', '737', 'LIST2'),
#               ('negative', '172', 'LIST2'),
#               ('positive', '274', 'LIST2'),
#               ('neutral', '559', 'LIST2'),
#               ('negative', '530', 'LIST2'),
#               ('negative', '262', 'LIST2'),
#               ('negative', '776', 'LIST2'),
#               ('positive', '363', 'LIST2'),
#               ('positive', '334', 'LIST2'),
#               ('negative', '66', 'LIST2'),
#               ('neutral', '25', 'LIST2'),
#               ('negative', '640', 'LIST2'),
#               ('positive', '309', 'LIST2'),
#               ('neutral', '320', 'LIST2'),
#               ('neutral', '360', 'LIST2'),
#               ('neutral', '473', 'LIST2'),
#               ('negative', '893', 'LIST2'),
#               ('neutral', '858', 'LIST2'),
#               ('neutral', '955', 'LIST2'),
#               ('positive', '201', 'LIST2'),
#               ('negative', '706', 'LIST2'),
#               ('neutral', '47', 'LIST2'),
#               ('positive', '721', 'LIST2'),
#               ('negative', '172', 'LIST2'),
#               ('neutral', '233', 'LIST2'),
#               ('positive', '408', 'LIST2'),
#               ('neutral', '559', 'LIST2'),
#               ('positive', '552', 'LIST2'),
#               ('neutral', '739', 'LIST2'),
#               ('positive', '21', 'LIST2'),
#               ('neutral', '162', 'LIST2'),
#               ('negative', '262', 'LIST2'),
#               ('negative', '573', 'LIST2'),
#               ('negative', '290', 'LIST0'),
#               ('positive', '637', 'LIST2'),
#               ('positive', '274', 'LIST2'),
#               ('positive', '309', 'LIST2'),
#               ('neutral', '473', 'LIST2'),
#               ('positive', '547', 'LIST2'),
#               ('neutral', '240', 'LIST2'),
#               ('positive', '201', 'LIST2'),
#               ('neutral', '360', 'LIST2'),
#               ('neutral', '955', 'LIST2'),
#               ('negative', '805', 'LIST0'),
#               ('positive', '334', 'LIST2'),
#               ('neutral', '47', 'LIST2'),
#               ('negative', '172', 'LIST2'),
#               ('negative', '66', 'LIST2'),
#               ('negative', '62', 'LIST2'),
#               ('positive', '552', 'LIST2'),
#               ('neutral', '737', 'LIST2'),
#               ('negative', '776', 'LIST2'),
#               ('negative', '893', 'LIST2'),
#               ('neutral', '233', 'LIST2'),
#               ('negative', '506', 'LIST2'),
#               ('neutral', '320', 'LIST2'),
#               ('neutral', '162', 'LIST2'),
#               ('negative', '947', 'LIST2'),
#               ('negative', '474', 'LIST2'),
#               ('neutral', '739', 'LIST2'),
#               ('positive', '309', 'LIST2'),
#               ('neutral', '473', 'LIST2'),
#               ('positive', '201', 'LIST2'),
#               ('positive', '274', 'LIST2'),
#               ('neutral', '559', 'LIST2'),
#               ('neutral', '360', 'LIST2'),
#               ('positive', '721', 'LIST2'),
#               ('positive', '363', 'LIST2'),
#               ('negative', '530', 'LIST2'),
#               ('negative', '573', 'LIST2'),
#               ('neutral', '240', 'LIST2'),
#               ('neutral', '132', 'LIST2'),
#               ('negative', '172', 'LIST2'),
#               ('negative', '262', 'LIST2'),
#               ('negative', '893', 'LIST2'),
#               ('positive', '408', 'LIST2'),
#               ('neutral', '47', 'LIST2'),
#               ('negative', '640', 'LIST2'),
#               ('negative', '506', 'LIST2'),
#               ('negative', '798', 'LIST2'),
#               ('positive', '552', 'LIST2'),
#               ('neutral', '162', 'LIST2'),
#               ('negative', '66', 'LIST2'),
#               ('neutral', '473', 'LIST2'),
#               ('neutral', '858', 'LIST2'),
#               ('neutral', '25', 'LIST2'),
#               ('negative', '947', 'LIST2'),
#               ('neutral', '955', 'LIST2'),
#               ('neutral', '901', 'LIST2'),
#               ('positive', '21', 'LIST2'),
#               ('negative', '530', 'LIST2'),
#               ('neutral', '737', 'LIST2'),
#               ('negative', '62', 'LIST2'),
#               ('neutral', '233', 'LIST2'),
#               ('negative', '776', 'LIST2'),
#               ('positive', '334', 'LIST2'),
#               ('neutral', '320', 'LIST2'),
#               ('negative', '573', 'LIST2'),
#               ('positive', '721', 'LIST2')]})

# %%
for idx, (key, val) in enumerate(word_lists_dict.items()):
    print(idx, (key, val))
# Out:
# 0 (0, ['neutral315', 'neutral83', 'positive454', 'negative323', 'positive284', 'neutral434', 'negative270', 'positive343', 'negative295', 'positive509', 'negative92', 'neutral241', 'positive102', 'negative12', 'positive44', 'negative200', 'positive226', 'negative300', 'positive452', 'negative467', 'positive518', 'neutral100', 'negative290', 'neutral421', 'negative71', 'neutral245', 'positive480', 'negative400', 'neutral972', 'positive954', 'neutral872', 'negative398', 'neutral889', 'positive248', 'neutral552', 'negative632', 'neutral789', 'positive453', 'negative805', 'neutral834'])
# 1 (1, ['neutral967', 'neutral589', 'negative589', 'neutral856', 'negative754', 'neutral462', 'negative24', 'positive659', 'neutral379', 'positive428', 'negative472', 'positive344', 'negative86', 'neutral185', 'negative405', 'neutral399', 'negative201', 'positive758', 'neutral94', 'negative325', 'neutral659', 'negative238', 'positive173', 'negative687', 'neutral433', 'negative645', 'neutral109', 'positive859', 'neutral417', 'negative253', 'neutral169', 'negative248', 'positive425', 'neutral903', 'positive430', 'negative291', 'positive577', 'neutral495', 'negative22', 'positive263'])
# 2 (2, ['neutral858', 'neutral739', 'negative776', 'positive274', 'neutral955', 'negative62', 'neutral162', 'positive552', 'neutral25', 'negative798', 'neutral360', 'positive637', 'neutral737', 'positive547', 'neutral240', 'positive721', 'negative474', 'positive309', 'negative947', 'positive334', 'negative640', 'neutral901', 'negative66', 'positive21', 'neutral473', 'positive363', 'negative530', 'neutral47', 'negative573', 'neutral559', 'negative262', 'neutral320', 'negative893', 'positive201', 'negative506', 'neutral233', 'positive408', 'negative172', 'neutral132', 'negative706'])

# %%
file = open(f"word_lists/word_lists_dict_20_3.pickle","rb")
#file = open(f"word_lists_dict_100_items_only.pickle","rb")
word_lists_dict = pickle.load(file)  
file.close()

word_lists_dict
# Out:
# defaultdict(list,
#             {0: ['neutral748',
#               'neutral990',
#               'positive164',
#               'neutral695',
#               'negative341',
#               'neutral616',
#               'positive886',
#               'neutral834',
#               'positive338',
#               'negative151',
#               'positive364',
#               'neutral430',
#               'negative741',
#               'neutral262',
#               'negative606',
#               'neutral520',
#               'positive623',
#               'negative851',
#               'positive345',
#               'neutral580'],
#              1: ['neutral164',
#               'neutral195',
#               'negative123',
#               'positive793',
#               'neutral814',
#               'negative838',
#               'neutral808',
#               'negative326',
#               'positive422',
#               'neutral176',
#               'positive709',
#               'neutral867',
#               'negative675',
#               'positive459',
#               'neutral518',
#               'positive518',
#               'neutral383',
#               'positive573',
#               'negative464',
#               'neutral711'],
#              2: ['neutral611',
#               'neutral552',
#               'negative142',
#               'positive699',
#               'negative882',
#               'neutral260',
#               'negative178',
#               'neutral60',
#               'positive159',
#               'negative889',
#               'neutral945',
#               'positive510',
#               'negative307',
#               'neutral186',
#               'negative539',
#               'positive685',
#               'neutral966',
#               'negative605',
#               'positive858',
#               'neutral633']})

# %%
#actr.reset()
#setup_dm(word_lists_dict)
#actr.sdp(':creation-time', -1000, ':reference-list', list(np.linspace(0, -1000, 500)))

# %%
word_lists_dict
# Out:
# defaultdict(list,
#             {0: ['neutral748',
#               'neutral990',
#               'positive164',
#               'neutral695',
#               'negative341',
#               'neutral616',
#               'positive886',
#               'neutral834',
#               'positive338',
#               'negative151',
#               'positive364',
#               'neutral430',
#               'negative741',
#               'neutral262',
#               'negative606',
#               'neutral520',
#               'positive623',
#               'negative851',
#               'positive345',
#               'neutral580'],
#              1: ['neutral164',
#               'neutral195',
#               'negative123',
#               'positive793',
#               'neutral814',
#               'negative838',
#               'neutral808',
#               'negative326',
#               'positive422',
#               'neutral176',
#               'positive709',
#               'neutral867',
#               'negative675',
#               'positive459',
#               'neutral518',
#               'positive518',
#               'neutral383',
#               'positive573',
#               'negative464',
#               'neutral711'],
#              2: ['neutral611',
#               'neutral552',
#               'negative142',
#               'positive699',
#               'negative882',
#               'neutral260',
#               'negative178',
#               'neutral60',
#               'positive159',
#               'negative889',
#               'neutral945',
#               'positive510',
#               'negative307',
#               'neutral186',
#               'negative539',
#               'positive685',
#               'neutral966',
#               'negative605',
#               'positive858',
#               'neutral633']})
