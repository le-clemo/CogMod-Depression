# %% [markdown]
# ## Backup Reminder : DO IT!

# %%
# All the necessary imports
import actr
import pickle
import random
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from itertools import groupby

# %%
help(actr)

# %% [markdown]
# ## Experiment Logs
#     - 10th June 2020: 06:50am
#         - Testing the plotting function.
#         - Backing up the code to github: Done

# %% [markdown]
# ## Control Flow Logs
#     - Flow of the program in simple words
#         -Need to understand the ACT-R Model first
#     - Data Structures, their shapes and the purpose of their existence

# %% [markdown]
# #### Word lists do not contain actual words?
#     No they don't, we will do this in later experiment
# #### Number of words in each list i.e. list_length should be n where (n-2)%3 == 0 because 2 neutral words are added in each list.
#
# #### The adjustable parameters in this experiment code.
#     - Number of lists
#     - Number of words in each list
#     - The time taken for rehearsal (6 + delay of .5 seconds) and recall(10)
# #### Adjustable parameters in ACT-R
#     - :declarative-num-finsts 21 ; number of items that are kept as recently retrieved (Change it to 5)
#     - :declarative-finst-span 21 ; how long items stay in the recently-retrieved state (5,100)

# %%
### Experiment part ###

subject = ''

current_list = ''

recalled_words = defaultdict(list)

rehearsed_words =  defaultdict(lambda: defaultdict(int))

list_amount = 50    # No of lists

list_length = 83    # No of words in a list

rehearsal_time = 6  # No of seconds for which rehearsal happens and each word is shown

delay = 0.1  #delay between rehearsal and recall

recall_time = 10

# %%
word_lists_dict = defaultdict(list)

# Ensure there are enough unique words to create the word lists
word_dict = {"positive": ["positive" + str(i) for i in range(999)],
             "negative": ["negative" + str(i) for i in range(999)],
             "neutral": ["neutral" + str(i) for i in range(999)]}

# %%
def add_words(i, list_length):
    '''
    Add the words to the word lists, ensures valence categories are balanced
    '''
    global word_lists_dict

    amnt_wanted = (list_length -2)/3   # Amount of each valence wanted, minus 2 neutrals controlling for primacy
    amt_positive, amt_negative, amt_neutral, count = 0, 0, 0, 0
    while len(word_lists_dict[i]) != list_length:
        count += 1
        #print(f"...................{count,word_lists_dict[i]}")
        if count >= 9999: # IF it takes too long to create a unique list at random, start over
            word_lists_dict[i] = []
            add_words(i, list_length)
        if len(word_lists_dict[i]) == 0: # Place two neutral words at the start to control for primacy effects
            word_to_add1 = word_dict["neutral"][random.randint(0, len(word_dict["neutral"])-1)]
            word_to_add2 = word_dict["neutral"][random.randint(0, len(word_dict["neutral"])-1)]
            if word_to_add1 not in word_lists_dict[i] and word_to_add2 not in word_lists_dict[i] and word_to_add1 != word_to_add2:
                word_lists_dict[i].append(word_to_add1)
                word_lists_dict[i].append(word_to_add2)
            else:
                continue # skip this loop iteration                   
        else: 
            random_valence = random.choice(["positive", "negative", "neutral"])
            word_to_add = word_dict[random_valence][random.randint(0, len(word_dict[random_valence])-1)]
            if word_to_add not in word_lists_dict[i] and word_lists_dict[i][-1] not in word_dict[random_valence] and \
               amt_positive <= amnt_wanted and amt_negative <= amnt_wanted and amt_neutral <= amnt_wanted:
                if random_valence == "positive" and amt_positive < amnt_wanted:
                    amt_positive += 1
                elif random_valence == "negative" and amt_negative < amnt_wanted:
                    amt_negative +=1
                elif random_valence == "neutral" and amt_neutral < amnt_wanted:
                    amt_neutral +=1
                else:
                    continue # skip this loop iteration
                word_lists_dict[i].append(word_to_add)

# %%
def create_lists(list_amount=3, list_length=2):
    '''
    Create the wordlists used during the free recall tasks 
    '''  
    global word_lists_dict 

    for i in range(list_amount):
        print(f'List {i+1}/{list_amount} created!', end="\r")
        add_words(i, list_length)

    # Save the dictionary to a .pickle file, so we do not have to create the word lists everytime we run the model                    
    file = open(f"word_lists\word_lists_dict_{list_length}_{list_amount}.pickle","wb")
    pickle.dump(word_lists_dict, file)
    file.close()
    return word_lists_dict

# %%
# Check if the word lists already exist, else create new word lists
try:
    file = open(f"word_lists\word_lists_dict_{list_length}_{list_amount}.pickle","rb")
    #file = open(f"word_lists_dict_100_items_only.pickle","rb")
    word_lists_dict = pickle.load(file)  
    file.close()
    print("\nSuccesfully loaded the word lists!\n")
except FileNotFoundError:
    print("\nCreating word lists!\n")
    #amount_to_create = list_amount                              
    word_lists_dict = create_lists(list_amount,list_length)
# Out:
# Succesfully loaded the word lists!

# %%
def display_word_lists():
    '''
    Display the word lists loaded/created
    '''
    for key, value in word_lists_dict.items():
        print(f'List {key}:\n {value}\n')

def close_exp_window():
    '''
    Close opened ACT-R window
    '''
    return actr.current_connection.evaluate_single("close-exp-window")

# %%
def prepare_for_recall(): 
    '''
    Disable rehearsing productions, and clearing buffer contents to start the recalling phase 
    '''
    disable_list = ["rehearse-first", "rehearse-second", "rehearse-third", "rehearse-fourth", 
                    "rehearse-it", "skip-first", "skip-second", "skip-third", "skip-fourth"]
    for prod in disable_list:
        actr.pdisable(prod)
    actr.run(1, False) 
    for buff in ["imaginal", "retrieval", "production"]:
        actr.clear_buffer(buff)

# %%
def setup_dm(word_list):
    '''
    Add words to declarative memory, since it can be assumed the test subjects know the English language already
    '''
    #print("\n\n############################################# Inside setup_dm i.e. Declarative Memory")
     
    colour_conversion = {'pos': 'GREEN', 'neg': 'RED', 'neu': 'BLACK'}
    for idx, word in enumerate(word_list):
        valence = ''.join([char for char in word if not char.isdigit()])[:3]
        actr.add_dm(('item'+str(idx), 'isa', 'memory', 'word', "'"+word+"'", 'valence', colour_conversion[valence]))
#         if idx == 0:
#             print("\n Emaple of a chunk added in Declarative Memory is \n")
#             print('item'+str(idx), 'isa', 'memory', 'word', "'"+word+"'", 'valence', colour_conversion[valence],"\n")

# %%
def setup_experiment(human=True):
    '''
    Load the correct ACT-R model, and create a window to display the words
    '''
#     print("\n\n############################################# Inside setup_experiment")
#     print(f'\nSubject = {subject}\n')  

    loaded = None
    if subject == "controls":
        #loaded = actr.load_act_r_model(r"C:\Users\cleme\Documents\Education\RUG\First-Year_Research\My_Project\Model\models\free_recall_regular_v1.lisp")
        loaded = actr.load_act_r_model(r"C:\Users\cleme\Documents\Education\RUG\First-Year_Research\My_Project\Model\models\csm_free_recall_model.lisp")
    elif subject == "depressed":
        loaded = actr.load_act_r_model(r"C:\Users\cleme\Documents\Education\RUG\First-Year_Research\My_Project\Model\models\csm_free_recall_model_depressed.lisp")
    
    #print("\n\n############################################# Inside setup_experiment")
    #print(f'\nLoaded Act-r model = {loaded}\n')  



    window = actr.open_exp_window("Free Recall Experiment", width=1024, height=768, visible=human) # 15inch resolution window
    actr.install_device(window) 
    return window

# %%
def record_words_recalled(item):
    '''
    Register which words were recalled during the experiment for a specific wordlist and strip the numbers
    '''
    valence = ''.join(char for char in item if not char.isdigit())
    item_idx = ''.join(char for char in item if char.isdigit())
    recalled_words[current_list].append((valence, item_idx))

# %%
def create_result_dict():
    '''
    Use a module-level function, instead of lambda function, to enable pickling it
    '''
    return defaultdict(int)

# %%
def record_words_rehearsed(item):
    '''
    Register amount of rehearsals per word for each wordlist
    '''
    rehearsed_words[current_list][item] += 1

# %% [markdown]
# # Testing Creation of Plots which involves testing
#     - create_lplot(idx, xlabel, ylabel, x, y, xticks_len, filename, ytick_range=None, show=False)
#     - analysis(wlist_amount, show_plots=False)

# %%
def create_lplot(idx, xlabel, ylabel, x, y, xticks_len, filename, ytick_range=None, show=False):
    '''
    Create line plot using matplotlib
    Args:
        Input:
            -idx: The id of the type of plot to be made.
                  0: Rehearse Freuency
                  1: Starting Recall
                  2: Recall Probability
            -xlabel: Label for x-axis of the plot (Serial Input Position for this experiment).
            -ylabel: Label for y-axis of the plot (One of idx 0,1 or 2).
            -x: Serial Input Positions which depends on the length of the words list ex: range(1,20).
                shape: (1, list_length)
            -y: Values for the idx 0,1 or 2.
                shape: (list_length,)
            -xticks_len: length for ticks on x-axis, same as len(x)
            -filename: name for saving the file
            -ytick_range: length for ticks on y-axis, 0-1 for probabilities, None for rehearse frequency
            -show: To show the plot here or not.
        Output:
            Saved plots of rehearse frequency, starting recall and recall probability.
    '''
    plt.figure(idx)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.plot(x, y)
    plt.xticks(np.arange(0, xticks_len, 1)) 
    plt.yticks(ytick_range)
    plt.savefig("images/"+subject+"_"+filename, bbox_inches='tight')
    if show:
        plt.show()

# %%
def analysis(wlist_amount, show_plots=False):
    '''
    Review results of the recall experiment
    Args:
        Input:
            -wlist_amount: No of words inside each list
            -show_plots: Boolean to control the display of plots after experiment
        Output:
            -Saved plots for rehearse frequency, starting recall and recall probability after complete analysis.
    
    '''
    result_dict = defaultdict(create_result_dict) # instead of defaultdict(lambda: defaultdict(int))
    first_recall = defaultdict(int)
    recall_probability = defaultdict(int)
    rehearse_frequency = defaultdict(int)
    transitions_amnt = 0
    thought_train_len = []

    for key, val in recalled_words.items():
        thought_train_len.extend([(k, sum(1 for _ in count)) for k, count in groupby([val[0] for val in val[2:]])])
        for idx, (retrieved_word, item_num) in enumerate(val[2:]):
            if idx != 0:
                if retrieved_word != val[2:][idx-1][0]:
                    transitions_amnt += 1/wlist_amount # average over word lists

    print(f'Avg. Amount of recall transitions = {int(transitions_amnt)}')
    neg_thought_train_len = 0
    neg_divider = 0.0001
    for x in thought_train_len:
        if x[0] == 'negative':
            neg_divider += 1
            neg_thought_train_len += x[1]
    print(f'Avg. Negative Thought train length = {round(neg_thought_train_len/neg_divider, 3)}')            

    for list_num, wlist in word_lists_dict.items():
        if list_num < wlist_amount:
            for key, val in recalled_words.items():
                if key==list_num:
                    first_recall[wlist.index(''.join(val[0]))] += 1   
                    for idx, word in enumerate(wlist):
                        first_recall[idx] += 0
                        if ((''.join(char for char in word if not char.isdigit()), 
                             ''.join(char for char in word if char.isdigit()))) in val:
                            recall_probability[idx] += 1
                        else:
                            recall_probability[idx] += 0                            
                for retrieved_word, item_num in val[2:4]:
                    result_dict["pstart"][retrieved_word] += 1  
                for retrieved_word, item_num in val[4:-2]:
                    result_dict["pstay"][retrieved_word] += 1
                for retrieved_word, item_num in val[-2:]:
                    result_dict["pstop"][retrieved_word] += 1                                                        
            for key, val in rehearsed_words.items():
                if key==list_num:
                    for idx, word in enumerate(wlist):
                        rehearse_frequency[idx] += rehearsed_words[key][word]
    
    for key, val in first_recall.items():
        first_recall[key] = val/wlist_amount

    for key, val in recall_probability.items():
        recall_probability[key] = val/wlist_amount

    for key, val in rehearse_frequency.items():
        rehearse_frequency[key] = val/wlist_amount      

    xticks_len = len(word_lists_dict[0])
  
    create_lplot(0, 'Serial input position', 'Rehearse Frequency', range(len(word_lists_dict[0])), list(rehearse_frequency.values()), 
                xticks_len, f'v1_rehearse_frequency_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}.png', None, show_plots)

    create_lplot(1, 'Serial input position', 'Starting Recall', range(len(word_lists_dict[0])), list(first_recall.values()), 
                xticks_len, f'v1_starting_recall_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}.png', np.arange(0, .5, .1), show_plots)                

    create_lplot(2, 'Serial input position', 'Recall Probability', range(len(word_lists_dict[0])), list(recall_probability.values()), 
                xticks_len, f'v1_recall_probability_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}.png', np.arange(0, 1, .1), show_plots)   
    
#     create_lplot(3, 'Serial input position', 'Accuracy', range(len(word_lists_dict[0])), list(recall_accuracy.values()), 
#                 xticks_len, 'recall_accuracy.png', np.arange(0, 1, .1), show_plots) 

    file = open("results_"+subject+".pickle","wb")
    pickle.dump(result_dict, file)
    file.close()

    return result_dict

# %%
def do_experiment(subj="depressed", human=False, wlist_amount=2000):
    '''
    Run the experiment
    '''
    global subject
    subject = subj
    assert wlist_amount <= len(word_lists_dict), "Chosen too many lists, choose less or create more word lists using function: create_lists()"
    
#     print("###################################################\n")
#     print("The original word list \n")
#     print(display_word_lists())
    
    print("\n###################################################\n")
    print("Experiment started, Trying to understand the flow\n")
  
    for idx, (key, value) in enumerate(word_lists_dict.items()):
        actr.reset()
        print("ACT-R has been reset")
        print(actr.buffers())
        window = setup_experiment(human)
        
        print("Experiment has been set up!")
        
        global current_list
        current_list = idx # keep track for which list words are recalled
        setup_dm(value)
        
        actr.add_command("retrieved-word", record_words_recalled,"Retrieves recalled words.")
        actr.add_command("rehearsed-word", record_words_rehearsed,"Retrieves rehearsed words.")
        print("ACT-R.add_command has run")
#         print("\n##################  Model started rehearsal ")
        for word in value:
            if "neutral" in word:
                color = "black"
            elif "positive" in word:
                color = "green"
            else:
                color = "red"
            actr.add_text_to_exp_window(window, word, x=475-len(word) , y=374, color=color, font_size=20) # change later 
            actr.run(rehearsal_time, human) # True when choosing Human, False when choosing differently
            actr.clear_exp_window(window)
            actr.run(delay, human)  # 500-ms blank screen  
        
        print(actr.dm())
        prepare_for_recall()       
        actr.remove_command("rehearsed-word")
#         print("\n##################  Model finished rehearsal, list of rehearsed words is ")
#         print(f'{rehearsed_words}\n')
#         print("\n##################  Model started recall ")
        actr.goal_focus("startrecall") # set goal to start recalling
        actr.run(recall_time, human)  
        actr.remove_command("retrieved-word")
#         print("\n##################  Model finished recall, list of recalled words is ")
#         print(f'{recalled_words}\n')
        print(f'Experiment {idx+1}/{wlist_amount} completed!', end="\r")
        if idx == wlist_amount-1: # run for a chosen number of word lists
            break
    close_exp_window() # close window at end of experiment 

    avg_recalled, avg_recalled_unique = 0, 0
    for key, val in recalled_words.items():
        avg_recalled += len(val)
        avg_recalled_unique += len(set(val))
    #    print(f'\nList {key} (length={len(val)}, unique={len(set(val))})')

    print("\n\n#############################################")
    print(f'\n[{subj}] Results!\n')  

    result = analysis(wlist_amount, False)        
    print(f'Avg. Amount of words recalled = {avg_recalled//wlist_amount}')
    print(f'Avg. Amount of unique words recalled = {avg_recalled_unique//wlist_amount}')

    for key, val in result.items():
        print(f'{key} = {dict(val)}')
    print()

# %%
# word_lists_dict[2],len(word_lists_dict)

# %%
do_experiment('controls',False,list_amount)
# Out:
# ###################################################
#
# Experiment started, Trying to understand the flow
#
# ACT-R has been reset
# ['GOAL', 'TEMPORAL', 'AURAL', 'AURAL-LOCATION', 'MANUAL', 'VOCAL', 'RETRIEVAL', 'PRODUCTION', 'IMAGINAL', 'VISUAL', 'VISUAL-LOCATION', 'IMAGINAL-ACTION']
# Experiment has been set up!
# ACT-R.add_command has run
#      0.000   GOAL                   SET-BUFFER-CHUNK GOAL GOAL NIL
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.000   VISION                 visicon-update
#      0.000   PROCEDURAL             CONFLICT-RESOLUTION
#      0.050   PROCEDURAL             PRODUCTION-FIRED FIND-UNATTENDED-WORD
#      0.050   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.050   VISION                 Find-location
#      0.050   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0
#      0.050   PROCEDURAL             CONFLICT-RESOLUTION
#      0.100   VISION                 Move-attention VISUAL-LOCATION0-1
#      0.100   PROCEDURAL             CONFLICT-RESOLUTION
#      0.185   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#      0.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.185   PROCEDURAL             CONFLICT-RESOLUTION
#      0.235   PROCEDURAL             PRODUCTION-FIRED ATTEND-WORD
#      0.235   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      0.235   PROCEDURAL             CONFLICT-RESOLUTION
#      0.735   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#      0.735   PROCEDURAL             CLEAR-BUFFER VISUAL
#      0.735   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      0.735   PROCEDURAL             CONFLICT-RESOLUTION
#      0.935   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK0
#      0.935   PROCEDURAL             CONFLICT-RESOLUTION
#      0.985   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#      0.985   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      0.985   PROCEDURAL             CONFLICT-RESOLUTION
#      1.035   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      1.035   PROCEDURAL             CONFLICT-RESOLUTION
#      1.085   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      1.085   PROCEDURAL             CONFLICT-RESOLUTION
#      1.135   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      1.135   PROCEDURAL             CONFLICT-RESOLUTION
#      1.185   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      1.185   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      1.185   DECLARATIVE            start-retrieval
#      1.185   PROCEDURAL             CONFLICT-RESOLUTION
#      1.607   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#      1.607   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#      1.607   PROCEDURAL             CONFLICT-RESOLUTION
#      1.907   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#      1.907   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      1.907   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      1.907   PROCEDURAL             CONFLICT-RESOLUTION
#      1.957   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      1.957   PROCEDURAL             CONFLICT-RESOLUTION
#      2.007   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      2.007   PROCEDURAL             CONFLICT-RESOLUTION
#      2.057   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      2.057   PROCEDURAL             CONFLICT-RESOLUTION
#      2.107   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      2.107   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      2.107   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK1
#      2.107   DECLARATIVE            start-retrieval
#      2.107   PROCEDURAL             CONFLICT-RESOLUTION
#      2.435   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#      2.435   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#      2.435   PROCEDURAL             CONFLICT-RESOLUTION
#      2.735   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#      2.735   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      2.735   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      2.735   PROCEDURAL             CONFLICT-RESOLUTION
#      2.785   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      2.785   PROCEDURAL             CONFLICT-RESOLUTION
#      2.835   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      2.835   PROCEDURAL             CONFLICT-RESOLUTION
#      2.885   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      2.885   PROCEDURAL             CONFLICT-RESOLUTION
#      2.935   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      2.935   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      2.935   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK2
#      2.935   DECLARATIVE            start-retrieval
#      2.935   PROCEDURAL             CONFLICT-RESOLUTION
#      3.045   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#      3.045   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#      3.045   PROCEDURAL             CONFLICT-RESOLUTION
#      3.345   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#      3.345   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      3.345   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      3.345   PROCEDURAL             CONFLICT-RESOLUTION
#      3.395   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      3.395   PROCEDURAL             CONFLICT-RESOLUTION
#      3.445   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      3.445   PROCEDURAL             CONFLICT-RESOLUTION
#      3.495   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      3.495   PROCEDURAL             CONFLICT-RESOLUTION
#      3.545   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      3.545   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      3.545   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK3
#      3.545   DECLARATIVE            start-retrieval
#      3.545   PROCEDURAL             CONFLICT-RESOLUTION
#      3.658   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#      3.658   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#      3.658   PROCEDURAL             CONFLICT-RESOLUTION
#      3.958   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#      3.958   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      3.958   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      3.958   PROCEDURAL             CONFLICT-RESOLUTION
#      4.008   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      4.008   PROCEDURAL             CONFLICT-RESOLUTION
#      4.058   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      4.058   PROCEDURAL             CONFLICT-RESOLUTION
#      4.108   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      4.108   PROCEDURAL             CONFLICT-RESOLUTION
#      4.158   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      4.158   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      4.158   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK4
#      4.158   DECLARATIVE            start-retrieval
#      4.158   PROCEDURAL             CONFLICT-RESOLUTION
#      4.277   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#      4.277   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#      4.277   PROCEDURAL             CONFLICT-RESOLUTION
#      4.577   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#      4.577   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      4.577   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      4.577   PROCEDURAL             CONFLICT-RESOLUTION
#      4.627   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      4.627   PROCEDURAL             CONFLICT-RESOLUTION
#      4.677   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      4.677   PROCEDURAL             CONFLICT-RESOLUTION
#      4.727   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      4.727   PROCEDURAL             CONFLICT-RESOLUTION
#      4.777   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      4.777   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      4.777   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK5
#      4.777   DECLARATIVE            start-retrieval
#      4.777   PROCEDURAL             CONFLICT-RESOLUTION
#      4.843   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#      4.843   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#      4.843   PROCEDURAL             CONFLICT-RESOLUTION
#      5.143   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#      5.143   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      5.143   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      5.143   PROCEDURAL             CONFLICT-RESOLUTION
#      5.193   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      5.193   PROCEDURAL             CONFLICT-RESOLUTION
#      5.243   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      5.243   PROCEDURAL             CONFLICT-RESOLUTION
#      5.293   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      5.293   PROCEDURAL             CONFLICT-RESOLUTION
#      5.343   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      5.343   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      5.343   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK6
#      5.343   DECLARATIVE            start-retrieval
#      5.343   PROCEDURAL             CONFLICT-RESOLUTION
#      5.421   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#      5.421   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#      5.421   PROCEDURAL             CONFLICT-RESOLUTION
#      5.721   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#      5.721   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      5.721   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      5.721   PROCEDURAL             CONFLICT-RESOLUTION
#      5.771   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      5.771   PROCEDURAL             CONFLICT-RESOLUTION
#      5.821   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      5.821   PROCEDURAL             CONFLICT-RESOLUTION
#      5.871   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      5.871   PROCEDURAL             CONFLICT-RESOLUTION
#      5.921   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      5.921   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      5.921   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK7
#      5.921   DECLARATIVE            start-retrieval
#      5.921   PROCEDURAL             CONFLICT-RESOLUTION
#      5.995   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#      5.995   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#      5.995   PROCEDURAL             CONFLICT-RESOLUTION
#      6.000   ------                 Stopped because time limit reached
#      6.000   VISION                 visicon-update
#      6.085   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#      6.085   VISION                 No visual-object found
#      6.100   ------                 Stopped because time limit reached
#      6.100   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION1 NIL
#      6.100   VISION                 visicon-update
#      6.185   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#      6.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT1 NIL
#      6.295   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#      6.295   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      6.295   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      6.295   PROCEDURAL             CONFLICT-RESOLUTION
#      6.345   PROCEDURAL             PRODUCTION-FIRED ELSE_NEW
#      6.345   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#      6.345   PROCEDURAL             CONFLICT-RESOLUTION
#      6.495   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK8
#      6.495   PROCEDURAL             CONFLICT-RESOLUTION
#      8.495   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#      8.495   PROCEDURAL             CLEAR-BUFFER VISUAL
#      8.495   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      8.495   PROCEDURAL             CONFLICT-RESOLUTION
#      8.695   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK9
#      8.695   PROCEDURAL             CONFLICT-RESOLUTION
#      8.745   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#      8.745   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      8.745   PROCEDURAL             CONFLICT-RESOLUTION
#      8.795   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#      8.795   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      8.795   DECLARATIVE            start-retrieval
#      8.795   PROCEDURAL             CONFLICT-RESOLUTION
#      8.992   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#      8.992   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#      8.992   PROCEDURAL             CONFLICT-RESOLUTION
#      9.292   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#      9.292   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      9.292   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      9.292   PROCEDURAL             CONFLICT-RESOLUTION
#      9.342   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      9.342   PROCEDURAL             CONFLICT-RESOLUTION
#      9.392   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      9.392   PROCEDURAL             CONFLICT-RESOLUTION
#      9.442   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      9.442   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      9.442   DECLARATIVE            start-retrieval
#      9.442   PROCEDURAL             CONFLICT-RESOLUTION
#      9.492   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK10
#      9.492   PROCEDURAL             CONFLICT-RESOLUTION
#      9.568   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#      9.568   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#      9.568   PROCEDURAL             CONFLICT-RESOLUTION
#      9.868   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#      9.868   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      9.868   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#      9.868   PROCEDURAL             CONFLICT-RESOLUTION
#      9.918   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#      9.918   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#      9.918   DECLARATIVE            start-retrieval
#      9.918   PROCEDURAL             CONFLICT-RESOLUTION
#     10.041   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     10.041   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     10.041   PROCEDURAL             CONFLICT-RESOLUTION
#     10.068   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK11
#     10.068   PROCEDURAL             CONFLICT-RESOLUTION
#     10.368   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     10.368   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     10.368   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     10.368   PROCEDURAL             CONFLICT-RESOLUTION
#     10.418   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#     10.418   PROCEDURAL             CONFLICT-RESOLUTION
#     10.468   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#     10.468   PROCEDURAL             CONFLICT-RESOLUTION
#     10.518   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     10.518   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     10.518   DECLARATIVE            start-retrieval
#     10.518   PROCEDURAL             CONFLICT-RESOLUTION
#     10.568   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK12
#     10.568   PROCEDURAL             CONFLICT-RESOLUTION
#     10.634   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     10.634   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     10.634   PROCEDURAL             CONFLICT-RESOLUTION
#     10.934   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     10.934   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     10.934   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     10.934   PROCEDURAL             CONFLICT-RESOLUTION
#     10.984   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     10.984   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     10.984   DECLARATIVE            start-retrieval
#     10.984   PROCEDURAL             CONFLICT-RESOLUTION
#     11.124   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     11.124   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     11.124   PROCEDURAL             CONFLICT-RESOLUTION
#     11.134   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK13
#     11.134   PROCEDURAL             CONFLICT-RESOLUTION
#     11.434   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     11.434   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     11.434   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     11.434   PROCEDURAL             CONFLICT-RESOLUTION
#     11.484   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#     11.484   PROCEDURAL             CONFLICT-RESOLUTION
#     11.534   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#     11.534   PROCEDURAL             CONFLICT-RESOLUTION
#     11.584   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     11.584   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     11.584   DECLARATIVE            start-retrieval
#     11.584   PROCEDURAL             CONFLICT-RESOLUTION
#     11.634   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK14
#     11.634   PROCEDURAL             CONFLICT-RESOLUTION
#     11.672   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     11.672   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     11.672   PROCEDURAL             CONFLICT-RESOLUTION
#     11.972   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     11.972   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     11.972   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     11.972   PROCEDURAL             CONFLICT-RESOLUTION
#     12.022   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     12.022   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     12.022   DECLARATIVE            start-retrieval
#     12.022   PROCEDURAL             CONFLICT-RESOLUTION
#     12.100   ------                 Stopped because time limit reached
#     12.100   VISION                 visicon-update
#     12.100   PROCEDURAL             CONFLICT-RESOLUTION
#     12.115   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     12.115   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     12.115   PROCEDURAL             CONFLICT-RESOLUTION
#     12.172   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK15
#     12.172   PROCEDURAL             CONFLICT-RESOLUTION
#     12.185   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#     12.185   VISION                 No visual-object found
#     12.200   ------                 Stopped because time limit reached
#     12.200   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION2 NIL
#     12.200   VISION                 visicon-update
#     12.285   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#     12.285   VISION                 SET-BUFFER-CHUNK VISUAL TEXT2 NIL
#     12.472   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     12.472   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     12.472   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     12.472   PROCEDURAL             CONFLICT-RESOLUTION
#     12.522   PROCEDURAL             PRODUCTION-FIRED ELSE_NEW
#     12.522   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#     12.522   PROCEDURAL             CONFLICT-RESOLUTION
#     12.672   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK16
#     12.672   PROCEDURAL             CONFLICT-RESOLUTION
#     13.172   PROCEDURAL             PRODUCTION-FIRED HIGH-THIRD
#     13.172   PROCEDURAL             CLEAR-BUFFER VISUAL
#     13.172   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     13.172   PROCEDURAL             CONFLICT-RESOLUTION
#     13.372   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK17
#     13.372   PROCEDURAL             CONFLICT-RESOLUTION
#     13.422   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-3
#     13.422   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     13.422   PROCEDURAL             CONFLICT-RESOLUTION
#     13.472   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     13.472   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     13.472   DECLARATIVE            start-retrieval
#     13.472   PROCEDURAL             CONFLICT-RESOLUTION
#     13.593   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     13.593   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     13.593   PROCEDURAL             CONFLICT-RESOLUTION
#     13.893   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     13.893   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     13.893   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     13.893   PROCEDURAL             CONFLICT-RESOLUTION
#     13.943   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#     13.943   PROCEDURAL             CONFLICT-RESOLUTION
#     13.993   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     13.993   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     13.993   DECLARATIVE            start-retrieval
#     13.993   PROCEDURAL             CONFLICT-RESOLUTION
#     14.093   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK18
#     14.093   PROCEDURAL             CONFLICT-RESOLUTION
#     14.759   DECLARATIVE            RETRIEVED-CHUNK ITEM2
#     14.759   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM2
#     14.759   PROCEDURAL             CONFLICT-RESOLUTION
#     15.059   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     15.059   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     15.059   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     15.059   PROCEDURAL             CONFLICT-RESOLUTION
#     15.109   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     15.109   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     15.109   DECLARATIVE            start-retrieval
#     15.109   PROCEDURAL             CONFLICT-RESOLUTION
#     15.227   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     15.227   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     15.227   PROCEDURAL             CONFLICT-RESOLUTION
#     15.259   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK19
#     15.259   PROCEDURAL             CONFLICT-RESOLUTION
#     15.559   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     15.559   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     15.559   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     15.559   PROCEDURAL             CONFLICT-RESOLUTION
#     15.609   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     15.609   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     15.609   DECLARATIVE            start-retrieval
#     15.609   PROCEDURAL             CONFLICT-RESOLUTION
#     15.759   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK20
#     15.759   PROCEDURAL             CONFLICT-RESOLUTION
#     15.775   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     15.775   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     15.775   PROCEDURAL             CONFLICT-RESOLUTION
#     16.075   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     16.075   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     16.075   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     16.075   PROCEDURAL             CONFLICT-RESOLUTION
#     16.125   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#     16.125   PROCEDURAL             CONFLICT-RESOLUTION
#     16.175   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     16.175   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     16.175   DECLARATIVE            start-retrieval
#     16.175   PROCEDURAL             CONFLICT-RESOLUTION
#     16.275   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK21
#     16.275   PROCEDURAL             CONFLICT-RESOLUTION
#     16.515   DECLARATIVE            RETRIEVED-CHUNK ITEM2
#     16.515   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM2
#     16.515   PROCEDURAL             CONFLICT-RESOLUTION
#     16.815   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     16.815   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     16.815   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     16.815   PROCEDURAL             CONFLICT-RESOLUTION
#     16.865   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     16.865   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     16.865   DECLARATIVE            start-retrieval
#     16.865   PROCEDURAL             CONFLICT-RESOLUTION
#     16.986   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     16.986   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     16.986   PROCEDURAL             CONFLICT-RESOLUTION
#     17.015   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK22
#     17.015   PROCEDURAL             CONFLICT-RESOLUTION
#     17.315   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     17.315   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     17.315   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     17.315   PROCEDURAL             CONFLICT-RESOLUTION
#     17.365   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     17.365   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     17.365   DECLARATIVE            start-retrieval
#     17.365   PROCEDURAL             CONFLICT-RESOLUTION
#     17.492   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     17.492   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     17.492   PROCEDURAL             CONFLICT-RESOLUTION
#     17.515   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK23
#     17.515   PROCEDURAL             CONFLICT-RESOLUTION
#     17.815   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     17.815   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     17.815   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     17.815   PROCEDURAL             CONFLICT-RESOLUTION
#     17.865   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#     17.865   PROCEDURAL             CONFLICT-RESOLUTION
#     17.915   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     17.915   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     17.915   DECLARATIVE            start-retrieval
#     17.915   PROCEDURAL             CONFLICT-RESOLUTION
#     18.015   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK24
#     18.015   PROCEDURAL             CONFLICT-RESOLUTION
#     18.150   DECLARATIVE            RETRIEVED-CHUNK ITEM2
#     18.150   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM2
#     18.150   PROCEDURAL             CONFLICT-RESOLUTION
#     18.200   ------                 Stopped because time limit reached
#     18.200   VISION                 visicon-update
#     18.285   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#     18.285   VISION                 No visual-object found
#     18.300   ------                 Stopped because time limit reached
#     18.300   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION3 NIL
#     18.300   VISION                 visicon-update
#     18.385   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#     18.385   VISION                 SET-BUFFER-CHUNK VISUAL TEXT3 NIL
#     18.450   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     18.450   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     18.450   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     18.450   PROCEDURAL             CONFLICT-RESOLUTION
#     18.500   PROCEDURAL             PRODUCTION-FIRED ELSE_NEW
#     18.500   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#     18.500   PROCEDURAL             CONFLICT-RESOLUTION
#     18.650   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK25
#     18.650   PROCEDURAL             CONFLICT-RESOLUTION
#     20.650   PROCEDURAL             PRODUCTION-FIRED HIGH-SECOND
#     20.650   PROCEDURAL             CLEAR-BUFFER VISUAL
#     20.650   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     20.650   PROCEDURAL             CONFLICT-RESOLUTION
#     20.850   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK26
#     20.850   PROCEDURAL             CONFLICT-RESOLUTION
#     20.900   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#     20.900   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     20.900   PROCEDURAL             CONFLICT-RESOLUTION
#     20.950   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     20.950   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     20.950   DECLARATIVE            start-retrieval
#     20.950   PROCEDURAL             CONFLICT-RESOLUTION
#     21.128   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     21.128   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     21.128   PROCEDURAL             CONFLICT-RESOLUTION
#     21.428   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     21.428   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     21.428   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     21.428   PROCEDURAL             CONFLICT-RESOLUTION
#     21.478   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     21.478   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     21.478   DECLARATIVE            start-retrieval
#     21.478   PROCEDURAL             CONFLICT-RESOLUTION
#     21.628   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK27
#     21.628   PROCEDURAL             CONFLICT-RESOLUTION
#     22.064   DECLARATIVE            RETRIEVED-CHUNK ITEM3
#     22.064   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM3
#     22.064   PROCEDURAL             CONFLICT-RESOLUTION
#     22.364   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     22.364   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     22.364   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     22.364   PROCEDURAL             CONFLICT-RESOLUTION
#     22.414   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     22.414   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     22.414   DECLARATIVE            start-retrieval
#     22.414   PROCEDURAL             CONFLICT-RESOLUTION
#     22.564   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK28
#     22.564   PROCEDURAL             CONFLICT-RESOLUTION
#     22.633   DECLARATIVE            RETRIEVED-CHUNK ITEM2
#     22.633   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM2
#     22.633   PROCEDURAL             CONFLICT-RESOLUTION
#     22.933   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     22.933   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     22.933   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     22.933   PROCEDURAL             CONFLICT-RESOLUTION
#     22.983   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     22.983   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     22.983   DECLARATIVE            start-retrieval
#     22.983   PROCEDURAL             CONFLICT-RESOLUTION
#     23.133   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK29
#     23.133   PROCEDURAL             CONFLICT-RESOLUTION
#     23.154   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     23.154   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     23.154   PROCEDURAL             CONFLICT-RESOLUTION
#     23.454   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     23.454   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     23.454   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     23.454   PROCEDURAL             CONFLICT-RESOLUTION
#     23.504   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     23.504   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     23.504   DECLARATIVE            start-retrieval
#     23.504   PROCEDURAL             CONFLICT-RESOLUTION
#     23.654   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK30
#     23.654   PROCEDURAL             CONFLICT-RESOLUTION
#     23.669   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     23.669   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     23.669   PROCEDURAL             CONFLICT-RESOLUTION
#     23.969   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     23.969   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     23.969   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     23.969   PROCEDURAL             CONFLICT-RESOLUTION
#     24.019   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     24.019   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     24.019   DECLARATIVE            start-retrieval
#     24.019   PROCEDURAL             CONFLICT-RESOLUTION
#     24.169   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK31
#     24.169   PROCEDURAL             CONFLICT-RESOLUTION
#     24.300   ------                 Stopped because time limit reached
#     24.300   VISION                 visicon-update
#     24.300   PROCEDURAL             CONFLICT-RESOLUTION
#     24.385   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#     24.385   VISION                 No visual-object found
#     24.385   PROCEDURAL             CONFLICT-RESOLUTION
#     24.398   DECLARATIVE            RETRIEVED-CHUNK ITEM3
#     24.398   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM3
#     24.398   PROCEDURAL             CONFLICT-RESOLUTION
#     24.400   ------                 Stopped because time limit reached
#     24.400   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION4 NIL
#     24.400   VISION                 visicon-update
#     24.485   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#     24.485   VISION                 SET-BUFFER-CHUNK VISUAL TEXT4 NIL
#     24.698   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     24.698   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     24.698   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     24.698   PROCEDURAL             CONFLICT-RESOLUTION
#     24.748   PROCEDURAL             PRODUCTION-FIRED ELSE_NEW
#     24.748   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#     24.748   PROCEDURAL             CONFLICT-RESOLUTION
#     24.898   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK32
#     24.898   PROCEDURAL             CONFLICT-RESOLUTION
#     24.948   PROCEDURAL             PRODUCTION-FIRED ATTEND-THIRD
#     24.948   PROCEDURAL             CLEAR-BUFFER VISUAL
#     24.948   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     24.948   PROCEDURAL             CONFLICT-RESOLUTION
#     25.148   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK33
#     25.148   PROCEDURAL             CONFLICT-RESOLUTION
#     25.198   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-3
#     25.198   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     25.198   PROCEDURAL             CONFLICT-RESOLUTION
#     25.248   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     25.248   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     25.248   DECLARATIVE            start-retrieval
#     25.248   PROCEDURAL             CONFLICT-RESOLUTION
#     25.308   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     25.308   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     25.308   PROCEDURAL             CONFLICT-RESOLUTION
#     25.608   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     25.608   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     25.608   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     25.608   PROCEDURAL             CONFLICT-RESOLUTION
#     25.658   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     25.658   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     25.658   DECLARATIVE            start-retrieval
#     25.658   PROCEDURAL             CONFLICT-RESOLUTION
#     25.808   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK34
#     25.808   PROCEDURAL             CONFLICT-RESOLUTION
#     25.882   DECLARATIVE            RETRIEVED-CHUNK ITEM3
#     25.882   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM3
#     25.882   PROCEDURAL             CONFLICT-RESOLUTION
#     26.182   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     26.182   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     26.182   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     26.182   PROCEDURAL             CONFLICT-RESOLUTION
#     26.232   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     26.232   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     26.232   DECLARATIVE            start-retrieval
#     26.232   PROCEDURAL             CONFLICT-RESOLUTION
#     26.382   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK35
#     26.382   PROCEDURAL             CONFLICT-RESOLUTION
#     27.091   DECLARATIVE            RETRIEVED-CHUNK ITEM4
#     27.091   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM4
#     27.091   PROCEDURAL             CONFLICT-RESOLUTION
#     27.391   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     27.391   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     27.391   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     27.391   PROCEDURAL             CONFLICT-RESOLUTION
#     27.441   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     27.441   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     27.441   DECLARATIVE            start-retrieval
#     27.441   PROCEDURAL             CONFLICT-RESOLUTION
#     27.544   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     27.544   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     27.544   PROCEDURAL             CONFLICT-RESOLUTION
#     27.591   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK36
#     27.591   PROCEDURAL             CONFLICT-RESOLUTION
#     27.891   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     27.891   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     27.891   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     27.891   PROCEDURAL             CONFLICT-RESOLUTION
#     27.941   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     27.941   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     27.941   DECLARATIVE            start-retrieval
#     27.941   PROCEDURAL             CONFLICT-RESOLUTION
#     28.070   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     28.070   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     28.070   PROCEDURAL             CONFLICT-RESOLUTION
#     28.091   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK37
#     28.091   PROCEDURAL             CONFLICT-RESOLUTION
#     28.391   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     28.391   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     28.391   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     28.391   PROCEDURAL             CONFLICT-RESOLUTION
#     28.441   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     28.441   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     28.441   DECLARATIVE            start-retrieval
#     28.441   PROCEDURAL             CONFLICT-RESOLUTION
#     28.591   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK38
#     28.591   PROCEDURAL             CONFLICT-RESOLUTION
#     28.775   DECLARATIVE            RETRIEVED-CHUNK ITEM3
#     28.775   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM3
#     28.775   PROCEDURAL             CONFLICT-RESOLUTION
#     29.075   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     29.075   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     29.075   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     29.075   PROCEDURAL             CONFLICT-RESOLUTION
#     29.125   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     29.125   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     29.125   DECLARATIVE            start-retrieval
#     29.125   PROCEDURAL             CONFLICT-RESOLUTION
#     29.275   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK39
#     29.275   PROCEDURAL             CONFLICT-RESOLUTION
#     29.647   DECLARATIVE            RETRIEVED-CHUNK ITEM4
#     29.647   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM4
#     29.647   PROCEDURAL             CONFLICT-RESOLUTION
#     29.947   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     29.947   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     29.947   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     29.947   PROCEDURAL             CONFLICT-RESOLUTION
#     29.997   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     29.997   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     29.997   DECLARATIVE            start-retrieval
#     29.997   PROCEDURAL             CONFLICT-RESOLUTION
#     30.142   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     30.142   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     30.142   PROCEDURAL             CONFLICT-RESOLUTION
#     30.147   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK40
#     30.147   PROCEDURAL             CONFLICT-RESOLUTION
#     30.400   ------                 Stopped because time limit reached
#     30.400   VISION                 visicon-update
#     30.447   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     30.447   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     30.447   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     30.447   PROCEDURAL             CONFLICT-RESOLUTION
#     30.485   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#     30.485   VISION                 No visual-object found
#     30.497   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     30.497   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     30.497   DECLARATIVE            start-retrieval
#     30.497   PROCEDURAL             CONFLICT-RESOLUTION
#     30.500   ------                 Stopped because time limit reached
#     30.500   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION5 NIL
#     30.500   VISION                 visicon-update
#     30.500   PROCEDURAL             CONFLICT-RESOLUTION
#     30.585   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#     30.585   VISION                 SET-BUFFER-CHUNK VISUAL TEXT5 NIL
#     30.585   PROCEDURAL             CONFLICT-RESOLUTION
#     30.647   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK41
#     30.647   PROCEDURAL             CONFLICT-RESOLUTION
#     30.684   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     30.684   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     30.684   PROCEDURAL             CONFLICT-RESOLUTION
#     30.984   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     30.984   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     30.984   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     30.984   PROCEDURAL             CONFLICT-RESOLUTION
#     31.034   PROCEDURAL             PRODUCTION-FIRED ELSE_NEW
#     31.034   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#     31.034   PROCEDURAL             CONFLICT-RESOLUTION
#     31.184   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK42
#     31.184   PROCEDURAL             CONFLICT-RESOLUTION
#     31.234   PROCEDURAL             PRODUCTION-FIRED ATTEND-SECOND
#     31.234   PROCEDURAL             CLEAR-BUFFER VISUAL
#     31.234   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     31.234   PROCEDURAL             CONFLICT-RESOLUTION
#     31.434   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK43
#     31.434   PROCEDURAL             CONFLICT-RESOLUTION
#     31.484   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#     31.484   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     31.484   PROCEDURAL             CONFLICT-RESOLUTION
#     31.534   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     31.534   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     31.534   DECLARATIVE            start-retrieval
#     31.534   PROCEDURAL             CONFLICT-RESOLUTION
#     31.643   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     31.643   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     31.643   PROCEDURAL             CONFLICT-RESOLUTION
#     31.943   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     31.943   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     31.943   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     31.943   PROCEDURAL             CONFLICT-RESOLUTION
#     31.993   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     31.993   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     31.993   DECLARATIVE            start-retrieval
#     31.993   PROCEDURAL             CONFLICT-RESOLUTION
#     32.143   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK44
#     32.143   PROCEDURAL             CONFLICT-RESOLUTION
#     32.637   DECLARATIVE            RETRIEVED-CHUNK ITEM5
#     32.637   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM5
#     32.637   PROCEDURAL             CONFLICT-RESOLUTION
#     32.937   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     32.937   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     32.937   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     32.937   PROCEDURAL             CONFLICT-RESOLUTION
#     32.987   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     32.987   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     32.987   DECLARATIVE            start-retrieval
#     32.987   PROCEDURAL             CONFLICT-RESOLUTION
#     33.137   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK45
#     33.137   PROCEDURAL             CONFLICT-RESOLUTION
#     33.451   DECLARATIVE            RETRIEVED-CHUNK ITEM4
#     33.451   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM4
#     33.451   PROCEDURAL             CONFLICT-RESOLUTION
#     33.751   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     33.751   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     33.751   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     33.751   PROCEDURAL             CONFLICT-RESOLUTION
#     33.801   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     33.801   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     33.801   DECLARATIVE            start-retrieval
#     33.801   PROCEDURAL             CONFLICT-RESOLUTION
#     33.951   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK46
#     33.951   PROCEDURAL             CONFLICT-RESOLUTION
#     33.956   DECLARATIVE            RETRIEVED-CHUNK ITEM0
#     33.956   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM0
#     33.956   PROCEDURAL             CONFLICT-RESOLUTION
#     34.256   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     34.256   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     34.256   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     34.256   PROCEDURAL             CONFLICT-RESOLUTION
#     34.306   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     34.306   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     34.306   DECLARATIVE            start-retrieval
#     34.306   PROCEDURAL             CONFLICT-RESOLUTION
#     34.399   DECLARATIVE            RETRIEVED-CHUNK ITEM1
#     34.399   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM1
#     34.399   PROCEDURAL             CONFLICT-RESOLUTION
#     34.456   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK47
#     34.456   PROCEDURAL             CONFLICT-RESOLUTION
#     34.756   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     34.756   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     34.756   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     34.756   PROCEDURAL             CONFLICT-RESOLUTION
#     34.806   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     34.806   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     34.806   DECLARATIVE            start-retrieval
#     34.806   PROCEDURAL             CONFLICT-RESOLUTION
#     34.956   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK48
#     34.956   PROCEDURAL             CONFLICT-RESOLUTION
#     35.179   DECLARATIVE            RETRIEVED-CHUNK ITEM5
#     35.179   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM5
#     35.179   PROCEDURAL             CONFLICT-RESOLUTION
#     35.479   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     35.479   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     35.479   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     35.479   PROCEDURAL             CONFLICT-RESOLUTION
#     35.529   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     35.529   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     35.529   DECLARATIVE            start-retrieval
#     35.529   PROCEDURAL             CONFLICT-RESOLUTION
#     35.679   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK49
#     35.679   PROCEDURAL             CONFLICT-RESOLUTION
#     35.835   DECLARATIVE            RETRIEVED-CHUNK ITEM4
#     35.835   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM4
#     35.835   PROCEDURAL             CONFLICT-RESOLUTION
#     36.135   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#     36.135   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     36.135   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#     36.135   PROCEDURAL             CONFLICT-RESOLUTION
#     36.185   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     36.185   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#     36.185   DECLARATIVE            start-retrieval
#     36.185   PROCEDURAL             CONFLICT-RESOLUTION
#     36.285   DECLARATIVE            RETRIEVED-CHUNK ITEM0
# ...
#    324.496   PROCEDURAL             CONFLICT-RESOLUTION
#    324.646   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK531
#    324.646   PROCEDURAL             CONFLICT-RESOLUTION
#    325.452   DECLARATIVE            RETRIEVED-CHUNK ITEM53
#    325.452   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM53
#    325.452   PROCEDURAL             CONFLICT-RESOLUTION
#    325.752   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    325.752   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    325.752   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    325.752   PROCEDURAL             CONFLICT-RESOLUTION
#    325.802   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#    325.802   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    325.802   DECLARATIVE            start-retrieval
#    325.802   PROCEDURAL             CONFLICT-RESOLUTION
#    325.919   DECLARATIVE            RETRIEVED-CHUNK ITEM45
#    325.919   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM45
#    325.919   PROCEDURAL             CONFLICT-RESOLUTION
#    325.952   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK532
#    325.952   PROCEDURAL             CONFLICT-RESOLUTION
#    326.252   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    326.252   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    326.252   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    326.252   PROCEDURAL             CONFLICT-RESOLUTION
#    326.302   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#    326.302   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    326.302   DECLARATIVE            start-retrieval
#    326.302   PROCEDURAL             CONFLICT-RESOLUTION
#    326.452   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK533
#    326.452   PROCEDURAL             CONFLICT-RESOLUTION
#    326.562   DECLARATIVE            RETRIEVED-CHUNK ITEM50
#    326.562   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM50
#    326.562   PROCEDURAL             CONFLICT-RESOLUTION
#    326.862   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    326.862   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    326.862   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    326.862   PROCEDURAL             CONFLICT-RESOLUTION
#    326.912   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#    326.912   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    326.912   DECLARATIVE            start-retrieval
#    326.912   PROCEDURAL             CONFLICT-RESOLUTION
#    327.062   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK534
#    327.062   PROCEDURAL             CONFLICT-RESOLUTION
#    327.209   DECLARATIVE            RETRIEVED-CHUNK ITEM52
#    327.209   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM52
#    327.209   PROCEDURAL             CONFLICT-RESOLUTION
#    327.509   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    327.509   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    327.509   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    327.509   PROCEDURAL             CONFLICT-RESOLUTION
#    327.559   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#    327.559   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    327.559   DECLARATIVE            start-retrieval
#    327.559   PROCEDURAL             CONFLICT-RESOLUTION
#    327.709   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK535
#    327.709   PROCEDURAL             CONFLICT-RESOLUTION
#    327.997   DECLARATIVE            RETRIEVED-CHUNK ITEM53
#    327.997   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM53
#    327.997   PROCEDURAL             CONFLICT-RESOLUTION
#    328.297   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    328.297   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    328.297   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    328.297   PROCEDURAL             CONFLICT-RESOLUTION
#    328.347   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#    328.347   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    328.347   DECLARATIVE            start-retrieval
#    328.347   PROCEDURAL             CONFLICT-RESOLUTION
#    328.479   DECLARATIVE            RETRIEVED-CHUNK ITEM45
#    328.479   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM45
#    328.479   PROCEDURAL             CONFLICT-RESOLUTION
#    328.497   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK536
#    328.497   PROCEDURAL             CONFLICT-RESOLUTION
#    328.797   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    328.797   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    328.797   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    328.797   PROCEDURAL             CONFLICT-RESOLUTION
#    328.847   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#    328.847   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    328.847   DECLARATIVE            start-retrieval
#    328.847   PROCEDURAL             CONFLICT-RESOLUTION
#    328.997   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK537
#    328.997   PROCEDURAL             CONFLICT-RESOLUTION
#    329.033   DECLARATIVE            RETRIEVED-CHUNK ITEM50
#    329.033   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM50
#    329.033   PROCEDURAL             CONFLICT-RESOLUTION
#    329.300   ------                 Stopped because time limit reached
#    329.300   VISION                 visicon-update
#    329.333   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    329.333   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    329.333   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    329.333   PROCEDURAL             CONFLICT-RESOLUTION
#    329.383   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#    329.383   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    329.383   DECLARATIVE            start-retrieval
#    329.383   PROCEDURAL             CONFLICT-RESOLUTION
#    329.385   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#    329.385   VISION                 No visual-object found
#    329.385   PROCEDURAL             CONFLICT-RESOLUTION
#    329.400   ------                 Stopped because time limit reached
#    329.400   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION54 NIL
#    329.400   VISION                 visicon-update
#    329.400   PROCEDURAL             CONFLICT-RESOLUTION
#    329.485   VISION                 Encoding-complete VISUAL-LOCATION0-1 NIL
#    329.485   VISION                 SET-BUFFER-CHUNK VISUAL TEXT54 NIL
#    329.485   PROCEDURAL             CONFLICT-RESOLUTION
#    329.533   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK538
#    329.533   PROCEDURAL             CONFLICT-RESOLUTION
#    329.537   DECLARATIVE            RETRIEVED-CHUNK ITEM52
#    329.537   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM52
#    329.537   PROCEDURAL             CONFLICT-RESOLUTION
#    329.837   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    329.837   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    329.837   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    329.837   PROCEDURAL             CONFLICT-RESOLUTION
#    329.887   PROCEDURAL             PRODUCTION-FIRED ELSE_NEW
#    329.887   PROCEDURAL             CLEAR-BUFFER VISUAL-LOCATION
#    329.887   PROCEDURAL             CONFLICT-RESOLUTION
#    330.037   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK539
#    330.037   PROCEDURAL             CONFLICT-RESOLUTION
#    330.087   PROCEDURAL             PRODUCTION-FIRED ATTEND-FIRST
#    330.087   PROCEDURAL             CLEAR-BUFFER VISUAL
#    330.087   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    330.087   PROCEDURAL             CONFLICT-RESOLUTION
#    330.287   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK540
#    330.287   PROCEDURAL             CONFLICT-RESOLUTION
#    330.337   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#    330.337   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    330.337   PROCEDURAL             CONFLICT-RESOLUTION
#    330.387   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#    330.387   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    330.387   DECLARATIVE            start-retrieval
#    330.387   PROCEDURAL             CONFLICT-RESOLUTION
#    330.637   DECLARATIVE            RETRIEVED-CHUNK ITEM54
#    330.637   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM54
#    330.637   PROCEDURAL             CONFLICT-RESOLUTION
#    330.937   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    330.937   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    330.937   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    330.937   PROCEDURAL             CONFLICT-RESOLUTION
#    330.987   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#    330.987   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    330.987   DECLARATIVE            start-retrieval
#    330.987   PROCEDURAL             CONFLICT-RESOLUTION
#    331.137   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK541
#    331.137   PROCEDURAL             CONFLICT-RESOLUTION
#    331.389   DECLARATIVE            RETRIEVED-CHUNK ITEM53
#    331.389   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM53
#    331.389   PROCEDURAL             CONFLICT-RESOLUTION
#    331.689   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    331.689   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    331.689   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    331.689   PROCEDURAL             CONFLICT-RESOLUTION
#    331.739   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#    331.739   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    331.739   DECLARATIVE            start-retrieval
#    331.739   PROCEDURAL             CONFLICT-RESOLUTION
#    331.854   DECLARATIVE            RETRIEVED-CHUNK ITEM45
#    331.854   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM45
#    331.854   PROCEDURAL             CONFLICT-RESOLUTION
#    331.889   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK542
#    331.889   PROCEDURAL             CONFLICT-RESOLUTION
#    332.189   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    332.189   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    332.189   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    332.189   PROCEDURAL             CONFLICT-RESOLUTION
#    332.239   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#    332.239   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    332.239   DECLARATIVE            start-retrieval
#    332.239   PROCEDURAL             CONFLICT-RESOLUTION
#    332.389   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK543
#    332.389   PROCEDURAL             CONFLICT-RESOLUTION
#    332.458   DECLARATIVE            RETRIEVED-CHUNK ITEM50
#    332.458   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM50
#    332.458   PROCEDURAL             CONFLICT-RESOLUTION
#    332.758   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    332.758   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    332.758   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    332.758   PROCEDURAL             CONFLICT-RESOLUTION
#    332.808   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#    332.808   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    332.808   DECLARATIVE            start-retrieval
#    332.808   PROCEDURAL             CONFLICT-RESOLUTION
#    332.958   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK544
#    332.958   PROCEDURAL             CONFLICT-RESOLUTION
#    333.275   DECLARATIVE            RETRIEVED-CHUNK ITEM54
#    333.275   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM54
#    333.275   PROCEDURAL             CONFLICT-RESOLUTION
#    333.575   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    333.575   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    333.575   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    333.575   PROCEDURAL             CONFLICT-RESOLUTION
#    333.625   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#    333.625   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    333.625   DECLARATIVE            start-retrieval
#    333.625   PROCEDURAL             CONFLICT-RESOLUTION
#    333.775   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK545
#    333.775   PROCEDURAL             CONFLICT-RESOLUTION
#    333.915   DECLARATIVE            RETRIEVED-CHUNK ITEM53
#    333.915   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM53
#    333.915   PROCEDURAL             CONFLICT-RESOLUTION
#    334.215   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    334.215   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    334.215   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    334.215   PROCEDURAL             CONFLICT-RESOLUTION
#    334.265   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#    334.265   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    334.265   DECLARATIVE            start-retrieval
#    334.265   PROCEDURAL             CONFLICT-RESOLUTION
#    334.382   DECLARATIVE            RETRIEVED-CHUNK ITEM45
#    334.382   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM45
#    334.382   PROCEDURAL             CONFLICT-RESOLUTION
#    334.415   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK546
#    334.415   PROCEDURAL             CONFLICT-RESOLUTION
#    334.715   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    334.715   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    334.715   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    334.715   PROCEDURAL             CONFLICT-RESOLUTION
#    334.765   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#    334.765   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    334.765   DECLARATIVE            start-retrieval
#    334.765   PROCEDURAL             CONFLICT-RESOLUTION
#    334.915   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK547
#    334.915   PROCEDURAL             CONFLICT-RESOLUTION
#    334.922   DECLARATIVE            RETRIEVED-CHUNK ITEM50
#    334.922   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL ITEM50
#    334.922   PROCEDURAL             CONFLICT-RESOLUTION
#    335.222   PROCEDURAL             PRODUCTION-FIRED REHEARSE-IT
#    335.222   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    335.222   PROCEDURAL             CLEAR-BUFFER IMAGINAL
#    335.222   PROCEDURAL             CONFLICT-RESOLUTION
#    335.272   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#    335.272   PROCEDURAL             CLEAR-BUFFER RETRIEVAL
#    335.272   DECLARATIVE            start-retrieval
#    335.272   PROCEDURAL             CONFLICT-RESOLUTION
#    335.400   ------                 Stopped because time limit reached
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-19c08be55e2d> in <module>
# ----> 1 do_experiment('controls',False,list_amount)
#
# <ipython-input-17-1d75a1d59e41> in do_experiment(subj, human, wlist_amount)
#      38                 color = "red"
#      39             actr.add_text_to_exp_window(window, word, x=475-len(word) , y=374, color=color, font_size=20) # change later
# ---> 40             actr.run(rehearsal_time, human) # True when choosing Human, False when choosing differently
#      41             actr.clear_exp_window(window)
#      42             actr.run(delay, human)  # 500-ms blank screen
#
# ~\Documents\Education\RUG\First-Year_Research\My_Project\Model\actr.py in run(time, real_time)
#     425
#     426 def run (time, real_time=False):
# --> 427     return current_connection.evaluate("run", time, real_time)
#     428
#     429 def run_full_time (time, real_time=False):
#
# ~\Documents\Education\RUG\First-Year_Research\My_Project\Model\actr.py in evaluate(self, *params)
#      43         p.insert(1,m)
#      44
# ---> 45         r = self.interface.send ("evaluate", *p)
#      46
#      47         if r[0] == False:
#
# ~\Documents\Education\RUG\First-Year_Research\My_Project\Model\actr.py in send(self, method, *params)
#     255
#     256         while not r.complete:
# --> 257           r.cv.wait()
#     258
#     259         return [r.success] + r.results
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Backup Reminder : DO IT!

# %% [markdown]
# # Here only the positions matter not the word?
