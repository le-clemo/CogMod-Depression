# %%
import actr
import pickle
import random
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from itertools import groupby
import json
# Out:
# ACT-R connection has been started.

# %%
help(actr)
# Out:
# Help on module actr:
#
# NAME
#     actr
#
# CLASSES
#     builtins.object
#         actr
#         interface
#         request
#
#     class actr(builtins.object)
#      |  actr(host, port)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, host, port)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  add_command(self, name, function, documentation='No documentation provided.', single=True, actr_name=None)
#      |
#      |  evaluate(self, *params)
#      |
#      |  evaluate_single(self, *params)
#      |
#      |  monitor_command(self, original, monitor)
#      |
#      |  remove_command(self, name)
#      |
#      |  remove_command_monitor(self, original, monitor)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class interface(builtins.object)
#      |  interface(host, port)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, host, port)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  add_command(self, name, function)
#      |
#      |  collect_data(self)
#      |
#      |  echo_output(self)
#      |
#      |  no_output(self)
#      |
#      |  output_monitor(self, string)
#      |
#      |  process_message(self, d)
#      |
#      |  run_command(self, command, command_name, model, id, params)
#      |
#      |  send(self, method, *params)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
#     class request(builtins.object)
#      |  request(id)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, id)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  notify_result(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# FUNCTIONS
#     act_r_output(output)
#
#     add_button_to_exp_window(window, text='', x=0, y=0, action=None, height=20, width=75, color='gray')
#
#     add_command(name, function=None, documentation='No documentation provided.', single=True, local_name=None)
#
#     add_dm(*chunks)
#
#     add_dm_fct(chunks)
#
#     add_image_to_exp_window(window, text, file, x=0, y=0, width=50, height=50, action=None)
#
#     add_items_to_exp_window(window, *items)
#
#     add_line_to_exp_window(window, start, end, color=False)
#
#     add_text_to_exp_window(window, text, x=0, y=0, color='black', height=20, width=75, font_size=12)
#
#     add_visicon_features(*features)
#
#     all_productions()
#
#     buffer_chunk(*params)
#
#     buffer_read(buffer)
#
#     buffer_status(*params)
#
#     buffers()
#
#     chunk_copied_from(chunk_name)
#
#     chunk_p(chunk_name)
#
#     chunk_slot_value(chunk_name, slot_name)
#
#     chunk_spec_to_chunk_def(spec_id)
#
#     clear_buffer(buffer)
#
#     clear_exp_window(win=None)
#
#     command_output(string)
#
#     connection()
#
#     copy_chunk(chunk_name)
#
#     correlation(results, data, output=True)
#
#     create_image_for_exp_window(window, text, file, x=0, y=0, width=50, height=50, action=None)
#
#     current_model()
#
#     define_chunk_spec(*spec)
#
#     define_chunks(*chunks)
#
#     define_chunks_fct(chunks)
#
#     define_module(name, buffers, params, interface=None)
#
#     delete_all_visicon_features()
#
#     delete_chunk(name)
#
#     delete_visicon_features(*features)
#
#     dm(*params)
#
#     extend_possible_slots(slot_name, warn=True)
#
#     get_history_data(history, *params)
#
#     get_parameter_value(param)
#
#     get_system_parameter_value(param)
#
#     get_time(model_time=True)
#
#     goal_focus(goal=None)
#
#     hide_output()
#
#     history_data_available(history, file=False, *params)
#
#     install_device(device)
#
#     load_act_r_code(path)
#
#     load_act_r_model(path)
#
#     mean_deviation(results, data, output=True)
#
#     mod_chunk(chunk_name, *mods)
#
#     mod_focus(*mods)
#
#     model_output(output_string)
#
#     modify_line_for_exp_window(line, start, end, color=False)
#
#     modify_visicon_features(*features)
#
#     modules_parameters(module)
#
#     modules_with_parameters()
#
#     monitor_command(original, monitor)
#
#     mp_models()
#
#     mp_show_queue(indicate_traced=False)
#
#     mp_time()
#
#     mp_time_ms()
#
#     new_digit_sound(digit, onset=False, time_in_ms=False)
#
#     new_tone_sound(freq, duration, onset=False, time_in_ms=False)
#
#     new_word_sound(word, onset=False, location='external', time_in_ms=False)
#
#     open_exp_window(title, visible=True, width=300, height=300, x=300, y=300)
#
#     pbreak(*params)
#
#     pdisable(*params)
#
#     penable(*params)
#
#     permute_list(l)
#
#     pp(*params)
#
#     pprint_chunks(*chunks)
#
#     predict_bold_response(start=None, end=None, output=None)
#
#     print_activation_trace(time, ms=True)
#
#     print_audicon()
#
#     print_chunk_activation_trace(chunk, time, ms=True)
#
#     print_dm_finsts()
#
#     print_visicon()
#
#     print_warning(warning)
#
#     printed_audicon()
#
#     printed_parameter_details(param)
#
#     printed_visicon()
#
#     process_events()
#
#     process_history_data(processor, file=False, data_params=None, processor_params=None)
#
#     punbreak(*params)
#
#     purge_chunk(name)
#
#     random(value)
#
#     record_history(*params)
#
#     release_chunk_spec(spec_id)
#
#     reload(compile=False)
#
#     remove_command(name)
#
#     remove_command_monitor(original, monitor)
#
#     remove_items_from_exp_window(window, *items)
#
#     reset()
#
#     resume_output()
#
#     run(time, real_time=False)
#
#     run_full_time(time, real_time=False)
#
#     run_n_events(event_count, real_time=False)
#
#     run_until_condition(condition, real_time=False)
#
#     run_until_time(time, real_time=False)
#
#     running()
#
#     save_history_data(history, file, comment='', *params)
#
#     saved_activation_history()
#
#     schedule_break_relative(time_delay, time_in_ms=False, priority=':max', details=None)
#
#     schedule_event(time, action, params=None, module=':NONE', priority=0, maintenance=False, destination=None, details=None, output=True, time_in_ms=False, precondition=None)
#
#     schedule_event_after_module(after_module, action, params=None, module=':NONE', maintenance=False, destination=None, details=None, output=True, precondition=None, dynamic=False, delay=True, include_maintenance=False)
#
#     schedule_event_now(action, params=None, module=':NONE', priority=0, maintenance=False, destination=None, details=None, output=True, precondition=None)
#
#     schedule_event_relative(time_delay, action, params=None, module=':NONE', priority=0, maintenance=False, destination=None, details=None, output=True, time_in_ms=False, precondition=None)
#
#     schedule_mod_buffer_chunk(buffer, mod_list_or_spec, time, module=':NONE', priority=0, output='low', time_in_ms=False)
#
#     schedule_set_buffer_chunk(buffer, chunk, time, module=':NONE', priority=0, output='low', time_in_ms=False, requested=True)
#
#     schedule_simple_mod_buffer_chunk(buffer, mod_list_or_spec, time, module='NONE', priority=0)
#
#     schedule_simple_set_buffer_chunk(buffer, chunk, time, module='NONE', priority=0, requested=True)
#
#     sdm(*params)
#
#     sdp(*params)
#
#     set_buffer_chunk(buffer_name, chunk_name, requested=True)
#
#     set_chunk_slot_value(chunk_name, slot_name, new_value)
#
#     set_current_model(name)
#
#     set_parameter_value(param, value)
#
#     set_system_parameter_value(param, value)
#
#     simulate_retrieval_request(*spec)
#
#     sorted_module_names()
#
#     spp(*params)
#
#     start(host=None, port=None)
#
#     start_hand_at_mouse()
#
#     stop()
#
#     stop_output()
#
#     stop_recording_history(*params)
#
#     trigger_reward(reward, maintenance=False)
#
#     undefine_module(name)
#
#     unhide_output()
#
#     used_production_buffers()
#
#     whynot(*params)
#
#     whynot_dm(*params)
#
# DATA
#     current_connection = <actr.actr object>
#     locals = <_thread._local object>
#
# FILE
#     c:\users\cleme\documents\education\rug\first-year_research\my_project\model\actr.py

# %% [markdown]
# #### Number of words in each list i.e. list_length should be n where (n-2)%3 == 0 because 2 neutral words are added in each list.
#
# #### The adjustable parameters in this experiment code.
#     - Number of lists
#     - Number of words in each list
#     - The time taken for rehearsal (6 + delay of .5 seconds) and recall(10)
# #### Adjustable parameters in ACT-R
#     - :declarative-num-finsts 21 ; number of items that are kept as recently retrieved (Change it to 5)
#     - :declarative-finst-span 21 ; how long items stay in the recently-retrieved state (5,100)

# %%
### Experiment part ###
def __init__(iteration):
    subject = ''

    current_list = ''

    recalled_words = defaultdict(list)

    rehearsed_words =  defaultdict(lambda: defaultdict(int))

    list_amount = 100   # No of lists (100, 200, 1000, 2000 AND 5000)

    list_length = 15   # No of words in a list

    rehearsal_time = 2  # No of seconds for which rehearsal happens and each word is shown

    delay = 0  #delay between rehearsal and recall

    recall_time = 90

    word_lists_dict = defaultdict(list)

    # Ensure there are enough unique words to create the word lists
    word_dict = {"positive": ["positive" + str(i) for i in range(999)],
                 "negative": ["negative" + str(i) for i in range(999)],
                 "neutral": ["neutral" + str(i) for i in range(999)]}

    filename = f'.\postman\postman_agents\delay_{delay}\words_{list_length}_lists_{list_amount}_rh_time_{rehearsal_time}_rec_time_{recall_time}_delay_{delay}_{iteration}.txt'
    
    results = {}



    results['x'] = {'data': [], # will be appended later in the analytics function
                          'info': "Storing range(len(word_lists_dict[0])) here"}

    results['rehearse_frequency'] = {'data': None,# will be appended later in the analytics function

                                     'info': "Storing list(rehearse_frequency.values()) here"}

    results['recall_probability'] = {'data': None, # will be appended later in the analytics function
                                        'info': "Storing list(recall_probability.values()) here"}

    results['first_recall'] = {'data': None, # will be appended later in the analytics function
                               'info': "Storing list(first_probability.values()) here"}

    with open(filename, 'w') as outfile:
        json.dump(results, outfile)

    with open(filename) as json_file:
        results = json.load(json_file)
#         #print(results)
    
    globals().update(locals())  ## Making everything public, worst code you can ever write!!

# %%
def add_words(i, list_length):
    '''
    Add the words to the word lists, ensures valence categories are balanced
    '''
    global word_lists_dict

    amnt_wanted = (list_length -2)/3   # Amount of each valence wanted, minus 2 neutrals controlling for primacy
    amt_positive, amt_negative, amt_neutral, count = 0, 0, 0, 0
    while len(word_lists_dict[i]) != list_length:
        count += 1
        #print(f"...................{count,word_lists_dict[i]}")
        if count >= 9999: # IF it takes too long to create a unique list at random, start over
            word_lists_dict[i] = []
            add_words(i, list_length)
        if len(word_lists_dict[i]) == 0: # Place two neutral words at the start to control for primacy effects
            word_to_add1 = word_dict["neutral"][random.randint(0, len(word_dict["neutral"])-1)]
            word_to_add2 = word_dict["neutral"][random.randint(0, len(word_dict["neutral"])-1)]
            if word_to_add1 not in word_lists_dict[i] and word_to_add2 not in word_lists_dict[i] and word_to_add1 != word_to_add2:
                word_lists_dict[i].append(word_to_add1)
                word_lists_dict[i].append(word_to_add2)
            else:
                continue # skip this loop iteration                   
        else: 
            random_valence = random.choice(["positive", "negative", "neutral"])
            word_to_add = word_dict[random_valence][random.randint(0, len(word_dict[random_valence])-1)]
            if word_to_add not in word_lists_dict[i] and word_lists_dict[i][-1] not in word_dict[random_valence] and \
               amt_positive <= amnt_wanted and amt_negative <= amnt_wanted and amt_neutral <= amnt_wanted:
                if random_valence == "positive" and amt_positive < amnt_wanted:
                    amt_positive += 1
                elif random_valence == "negative" and amt_negative < amnt_wanted:
                    amt_negative +=1
                elif random_valence == "neutral" and amt_neutral < amnt_wanted:
                    amt_neutral +=1
                else:
                    continue # skip this loop iteration
                word_lists_dict[i].append(word_to_add)

def create_lists(list_amount=3, list_length=2):
    '''
    Create the wordlists used during the free recall tasks 
    '''  
    global word_lists_dict 

    for i in range(list_amount):
        print(f'List {i+1}/{list_amount} created!', end="\r")
        add_words(i, list_length)

    # Save the dictionary to a .pickle file, so we do not have to create the word lists everytime we run the model                    
    file = open(f"word_lists/word_lists_dict_{list_length}_{list_amount}.pickle","wb")
    pickle.dump(word_lists_dict, file)
    file.close()
    return word_lists_dict

# Check if the word lists already exist, else create new word lists
def check_and_create_lists():
    global word_lists_dict
    try:
        file = open(f"word_lists/word_lists_dict_{list_length}_{list_amount}.pickle","rb")
        #file = open(f"word_lists_dict_100_items_only.pickle","rb")
        word_lists_dict = pickle.load(file)  
        file.close()
        print("\nSuccesfully loaded the word lists!\n")
    except FileNotFoundError:
        print("\nCreating word lists!\n")
        #amount_to_create = list_amount                              
        word_lists_dict = create_lists(list_amount,list_length)

def display_word_lists():
    '''
    Display the word lists loaded/created
    '''
    for key, value in word_lists_dict.items():
        print(f'List {key}:\n {value}\n')

def close_exp_window():
    '''
    Close opened ACT-R window
    '''
    return actr.current_connection.evaluate_single("close-exp-window")

def prepare_for_recall(): 
    '''
    Disable rehearsing productions, and clearing buffer contents to start the recalling phase 
    '''
    disable_list = ["rehearse-first", "rehearse-second", "rehearse-third", "rehearse-fourth", 
                    "rehearse-it", "skip-first", "skip-second", "skip-third", "skip-fourth"]
    for prod in disable_list:
        actr.pdisable(prod)
    actr.run(1, False) 
    for buff in ["imaginal", "retrieval", "production"]:
        actr.clear_buffer(buff)  

def setup_dm(word_list):
    '''
    Add words to declarative memory, since it can be assumed the test subjects know the English language already
    '''
    #print("\n\n############################################# Inside setup_dm i.e. Declarative Memory")
     
    colour_conversion = {'pos': 'GREEN', 'neg': 'RED', 'neu': 'BLACK'}
    for idx, word in enumerate(word_list):
        valence = ''.join([char for char in word if not char.isdigit()])[:3]
        actr.add_dm(('item'+str(idx), 'isa', 'memory', 'word', "'"+word+"'"))#, 'valence', colour_conversion[valence]))
#         if idx == 0:
#             print("\n Emaple of a chunk added in Declarative Memory is \n")
#             print('item'+str(idx), 'isa', 'memory', 'word', "'"+word+"'", 'valence', colour_conversion[valence],"\n")
        

def setup_experiment(human=True):
    '''
    Load the correct ACT-R model, and create a window to display the words
    '''
#     print("\n\n############################################# Inside setup_experiment")
#     print(f'\nSubject = {subject}\n')  

    loaded = None
    if subject == "controls":
        loaded = actr.load_act_r_model(r"C:\Users\cleme\Documents\Education\RUG\First-Year_Research\My_Project\Model\models\general_free_recall_model.lisp")
        #loaded = actr.load_act_r_model(r"C:\Users\cleme\Documents\Education\RUG\First-Year_Research\My_Project\Model\models\csm_free_recall_model.lisp")
    elif subject == "depressed":
        loaded = actr.load_act_r_model(r"")

    #print("\n\n############################################# Inside setup_experiment")
    #print(f'\nLoaded Act-r model = {loaded}\n')  



    window = actr.open_exp_window("Free Recall Experiment", width=1024, height=768, visible=human) # 15inch resolution window
    actr.install_device(window) 
    return window    

def record_words_recalled(item):
    '''
    Register which words were recalled during the experiment for a specific wordlist and strip the numbers
    '''
    valence = ''.join(char for char in item if not char.isdigit())
    item_idx = ''.join(char for char in item if char.isdigit())
    recalled_words[current_list].append((valence, item_idx))

def record_words_rehearsed(item):
    '''
    Register amount of rehearsals per word for each wordlist
    '''
    rehearsed_words[current_list][item] += 1

def create_lplot(idx, xlabel, ylabel, x, y, xticks_len, filename, ytick_range=None, show=False):
    '''
    Create line plot using matplotlib
    '''
    plt.figure(idx)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.plot(x, y)
    plt.xticks(np.arange(0, xticks_len, 1)) 
    plt.yticks(ytick_range)
    plt.savefig("images/"+subject+"_"+filename, bbox_inches='tight')
    if show:
        plt.show()    

        
def create_result_dict():
    '''
    Use a module-level function, instead of lambda function, to enable pickling it
    '''
    return defaultdict(int)

## Creating different pickle files to store results from multiple hyper-parameter values.


def analysis(wlist_amount, show_plots=False):
    '''
    Review results of the recall experiment
    '''
    global results
    result_dict = defaultdict(create_result_dict) # instead of defaultdict(lambda: defaultdict(int))
    first_recall = defaultdict(int)
    recall_probability = defaultdict(int)
    rehearse_frequency = defaultdict(int)
    transitions_amnt = 0
    thought_train_len = []

    for key, val in recalled_words.items():
        thought_train_len.extend([(k, sum(1 for _ in count)) for k, count in groupby([val[0] for val in val[2:]])])
        for idx, (retrieved_word, item_num) in enumerate(val[2:]):
            if idx != 0:
                if retrieved_word != val[2:][idx-1][0]:
                    transitions_amnt += 1/wlist_amount # average over word lists

    print(f'Avg. Amount of recall transitions = {int(transitions_amnt)}')
    neg_thought_train_len = 0
    neg_divider = 0.0001
    for x in thought_train_len:
        if x[0] == 'negative':
            neg_divider += 1
            neg_thought_train_len += x[1]
    print(f'Avg. Negative Thought train length = {round(neg_thought_train_len/neg_divider, 3)}')            

    for list_num, wlist in word_lists_dict.items():
        if list_num < wlist_amount:
            for key, val in recalled_words.items():
                if key==list_num:
                    first_recall[wlist.index(''.join(val[0]))] += 1   
                    for idx, word in enumerate(wlist):
                        first_recall[idx] += 0
                        if ((''.join(char for char in word if not char.isdigit()), 
                             ''.join(char for char in word if char.isdigit()))) in val:
                            recall_probability[idx] += 1
                        else:
                            recall_probability[idx] += 0                            
                for retrieved_word, item_num in val[2:4]:
                    result_dict["pstart"][retrieved_word] += 1  
                for retrieved_word, item_num in val[4:-2]:
                    result_dict["pstay"][retrieved_word] += 1
                for retrieved_word, item_num in val[-2:]:
                    result_dict["pstop"][retrieved_word] += 1                                                        
            for key, val in rehearsed_words.items():
                if key==list_num:
                    for idx, word in enumerate(wlist):
                        rehearse_frequency[idx] += rehearsed_words[key][word]
    
    for key, val in first_recall.items():
        first_recall[key] = val/wlist_amount

    for key, val in recall_probability.items():
        recall_probability[key] = val/wlist_amount

    for key, val in rehearse_frequency.items():
        rehearse_frequency[key] = val/wlist_amount      
        
    

    xticks_len = len(word_lists_dict[0])
    
    
    #results['x']['data'].append(range(len(word_lists_dict[0])))
    #results['xticks_len']['data'].append(len(word_lists_dict[0]) )
    results['rehearse_frequency']['data'] = list(rehearse_frequency.values())
    results['recall_probability']['data'] = list(recall_probability.values())
    results['first_recall']['data'] = list(first_recall.values()) 
    
    with open(filename, 'w') as outfile:
        json.dump(results, outfile)
        
    create_lplot(0, 'Serial input position', 'Rehearse Frequency', range(len(word_lists_dict[0])), list(rehearse_frequency.values()), 
                xticks_len, f'rehearse_frequency_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}_{delay}.png', None, show_plots)

    create_lplot(1, 'Serial input position', 'Starting Recall', range(len(word_lists_dict[0])), list(first_recall.values()), 
                xticks_len, f'starting_recall_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}_{delay}.png', np.arange(0, .5, .1), show_plots)                

    create_lplot(2, 'Serial input position', 'Recall Probability', range(len(word_lists_dict[0])), list(recall_probability.values()), 
                xticks_len, f'recall_probability_{list_length}_{list_amount}_{rehearsal_time}_{recall_time}_{delay}.png', np.arange(0, 1, .1), show_plots)   
    
#     create_lplot(3, 'Serial input position', 'Accuracy', range(len(word_lists_dict[0])), list(recall_accuracy.values()), 
#                 xticks_len, 'recall_accuracy.png', np.arange(0, 1, .1), show_plots) 

    file = open("results_"+subject+".pickle","wb")
    pickle.dump(result_dict, file)
    file.close()

    return result_dict

def do_experiment(subj="depressed", human=False, wlist_amount=2000):
    '''
    Run the experiment
    '''
    check_and_create_lists()
    global subject,word_lists_dict
    subject = subj
    assert wlist_amount <= len(word_lists_dict), "Chosen too many lists, choose less or create more word lists using function: create_lists()"
    
#     print("###################################################\n")
#     print("The original word list \n")
#     print(display_word_lists())
    
#     print("\n###################################################\n")
#     print("Experiment started, Trying to understand the flow\n")
  
    for idx, (key, value) in enumerate(word_lists_dict.items()):
        actr.reset()
        window = setup_experiment(human)
        
        actr.get_parameter_value(":dat")
        #actr.set_buffer_chunk("wm", "init", requested=True)
        
        global current_list
        current_list = idx # keep track for which list words are recalled
        setup_dm(value)   
        actr.add_command("retrieved-word", record_words_recalled,"Retrieves recalled words.")
        actr.add_command("rehearsed-word", record_words_rehearsed,"Retrieves rehearsed words.")
#         print("\n##################  Model started rehearsal ")
        for word in value:
            if "neutral" in word:
                color = "black"
            elif "positive" in word:
                color = "green"
            else:
                color = "red"
            actr.add_text_to_exp_window(window, word, x=475-len(word) , y=374, color=color, font_size=20) # change later 
            actr.run(rehearsal_time, human) # True when choosing Human, False when choosing differently
            actr.clear_exp_window(window)
            actr.run(delay, human)  # 500-ms blank screen                        
        prepare_for_recall()       
        actr.remove_command("rehearsed-word")
#         print("\n##################  Model finished rehearsal, list of rehearsed words is ")
#         print(f'{rehearsed_words}\n')
#         print("\n##################  Model started recall ")
        actr.goal_focus("startrecall") # set goal to start recalling
        actr.run(recall_time, human)  
        actr.remove_command("retrieved-word")
#         print("\n##################  Model finished recall, list of recalled words is ")
#         print(f'{recalled_words}\n')
        print(f'Experiment {idx+1}/{wlist_amount} completed!', end="\r")
        if idx == wlist_amount-1: # run for a chosen amount of word lists
            break
    close_exp_window() # close window at end of experiment     

    avg_recalled, avg_recalled_unique = 0, 0
    for key, val in recalled_words.items():
        avg_recalled += len(val)
        avg_recalled_unique += len(set(val))
    #    print(f'\nList {key} (length={len(val)}, unique={len(set(val))})')
    
    num_recalled = avg_recalled//wlist_amount
    num_unique_recalled = avg_recalled_unique//wlist_amount
    
    print(f'Avg. Amount of words recalled = {num_recalled}')
    print(f'Avg. Amount of unique words recalled = {num_unique_recalled}')
    
    results = analysis(list_amount, False)        

    for key, val in results.items():
        print(f'{key} = {dict(val)}')
    print()
 

    print("\n\n#############################################")
    print(f'\n[{subj}] Results!\n')
    return num_recalled, num_unique_recalled, results

# %%
num_agents = 1
total_recalled = 0
total_unique = 0
for agent in range(num_agents):
    print("------------------------------")
    print(f"Started for agent_{agent}")
    __init__(agent)
    
    try:
        num_recalled, num_unique, results = do_experiment('controls',False,list_amount)
        total_recalled += num_recalled
        total_unique += num_unique
    except ValueError:
        print("\nAgent recalled 0 items.")
        
avg_recall = total_recalled // num_agents
avg_unique = total_unique / num_agents
print(f"\nAverage number of recalled words ({num_agents} agents): {avg_recall}")
print(f"Unique: {avg_unique}")
# Out:
# ------------------------------
# Started for agent_0
#
# Succesfully loaded the word lists!
#
#      0.000   GOAL                   SET-BUFFER-CHUNK GOAL GOAL NIL
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.050   PROCEDURAL             PRODUCTION-FIRED FIND-UNATTENDED-WORD
#      0.050   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0
#      0.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.235   PROCEDURAL             PRODUCTION-FIRED ATTEND-WORD
#      0.435   PROCEDURAL             PRODUCTION-FIRED HIGH-THIRD
#      0.635   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK0
#      0.685   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-3
#      0.735   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      0.785   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      0.835   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#      1.327   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      1.377   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      1.427   PROCEDURAL             PRODUCTION-FIRED SKIP-FOURTH
#      1.477   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      1.527   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      1.577   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#      1.577   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK1
#      1.862   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      1.912   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      1.962   PROCEDURAL             PRODUCTION-FIRED SKIP-FOURTH
#      2.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#      2.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION1 NIL
#      2.012   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      2.062   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      2.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT1 NIL
#      2.112   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#      2.112   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK2
#      2.254   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      2.304   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      2.354   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      2.504   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK3
#      2.704   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#      2.904   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK4
#      2.954   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#      3.004   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#      3.231   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK4-0
#      3.281   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      3.331   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      3.381   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#      3.481   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK5
#      3.482   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      3.532   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      3.582   PROCEDURAL             PRODUCTION-FIRED SKIP-FOURTH
#      3.632   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#      3.732   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK6
#      3.815   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK4-0
#      3.865   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      3.915   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      3.965   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#      4.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#      4.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION2 NIL
#      4.043   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      4.065   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK7
#      4.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT2 NIL
#      4.115   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      4.165   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      4.315   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK8
#      4.515   PROCEDURAL             PRODUCTION-FIRED HIGH-SECOND
#      4.715   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK9
#      4.765   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#      4.815   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#      5.040   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK4-0
#      5.090   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      5.140   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#      5.290   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK10
#      5.921   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK9-0
#      5.971   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      6.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#      6.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION3 NIL
#      6.021   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#      6.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT3 NIL
#      6.152   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      6.171   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK11
#      6.221   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      6.271   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      6.421   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK12
#      6.621   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#      6.821   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK13
#      6.871   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#      6.921   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#      7.166   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK4-0
#      7.216   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      7.266   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#      7.416   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK14
#      7.706   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK9-0
#      7.756   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      7.806   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#      7.956   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK15
#      7.972   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      8.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#      8.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION4 NIL
#      8.022   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      8.072   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      8.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT4 NIL
#      8.222   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK16
#      9.404   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK13-0
#      9.454   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      9.504   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#      9.654   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK17
#      9.733   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK4-0
#      9.783   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      9.833   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#      9.983   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK18
#     10.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#     10.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCAT
000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION13 NIL
#     26.023   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     26.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT13 NIL
#     26.173   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK57
#     26.324   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK53-0
#     26.374   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     26.424   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     26.574   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK58
#     26.624   PROCEDURAL             PRODUCTION-FIRED REPLACE-FOURTH
#     26.824   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK59
#     26.874   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#     26.924   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     27.091   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK53-0
#     27.141   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     27.191   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     27.292   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK9-0
#     27.341   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK60
#     27.391   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     27.441   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     27.591   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK61
#     27.612   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK20-0
#     27.662   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     27.712   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     27.862   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK62
#     28.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#     28.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION14 NIL
#     28.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT14 NIL
#     28.497   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK59-0
#     28.547   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     28.597   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     28.747   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK63
#     28.827   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK53-0
#     28.877   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     28.927   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     29.031   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK9-0
#     29.077   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK64
#     29.127   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     29.177   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     29.320   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK20-0
#     29.327   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK65
#     29.377   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     29.427   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     29.577   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK66
#     29.852   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK59-0
#     29.902   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     29.952   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     30.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
# #|Warning: REHEARSE-IT is not the name of a production |#
#     30.102   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK67
#     30.137   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK53-0
#     30.187   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     30.387   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK68
#     30.387   ------                 Stopped because no events left to process
#     30.387   GOAL                   SET-BUFFER-CHUNK GOAL STARTRECALL NIL
#     30.437   PROCEDURAL             PRODUCTION-FIRED START-RECALL
#     30.487   PROCEDURAL             PRODUCTION-FIRED CHOOSE-FIRST
#     30.537   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-FIRST
#     30.898   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL GOAL-0
#     30.948   PROCEDURAL             PRODUCTION-FIRED RECALL-FIRST
# "neutral63"
#     30.998   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-SECOND
#     31.159   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL GOAL-0
#     31.209   PROCEDURAL             PRODUCTION-FIRED RECALL-SECOND
# "negative157"
#     31.259   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-THIRD
#     31.382   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL GOAL-0
#     31.432   PROCEDURAL             PRODUCTION-FIRED RECALL-THIRD
# "positive48"
#     31.482   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-FOURTH
#     31.616   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL GOAL-0
#     31.666   PROCEDURAL             PRODUCTION-FIRED RECALL-FOURTH
# "negative392"
#     31.716   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#     31.997   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#     32.047   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
#     32.097   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#     32.833   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK13-0
#     32.883   PROCEDURAL             PRODUCTION-FIRED RECALL-A-WORD
#     32.933   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-A-WORD
#     35.651   DECLARATIVE            RETRIEVAL-FAILURE
#     35.651   ------                 Stopped because no events left to process
#      0.000   GOAL                   SET-BUFFER-CHUNK GOAL GOAL NIL
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.050   PROCEDURAL             PRODUCTION-FIRED FIND-UNATTENDED-WORD
#      0.050   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0
#      0.185   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.235   PROCEDURAL             PRODUCTION-FIRED ATTEND-WORD
#      0.435   PROCEDURAL             PRODUCTION-FIRED HIGH-FOURTH
#      0.635   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK0
#      0.685   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-4
#      0.735   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      0.785   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      0.835   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      0.885   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      1.330   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      1.380   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      1.430   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      1.480   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      1.530   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      1.580   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      1.580   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK1
#      1.958   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      2.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#      2.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION1 NIL
#      2.008   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      2.058   PROCEDURAL             PRODUCTION-FIRED SKIP-FIRST
#      2.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT1 NIL
#      2.108   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      2.158   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      2.208   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK2
#      2.408   PROCEDURAL             PRODUCTION-FIRED HIGH-FIRST
#      2.608   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK3
#      2.658   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-1
#      2.708   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#      2.912   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK3-0
#      2.962   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      3.012   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      3.062   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      3.112   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      3.162   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK4
#      3.368   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      3.418   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      3.468   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#      3.618   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK5
#      3.623   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK3-0
#      3.673   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      3.723   PROCEDURAL             PRODUCTION-FIRED SKIP-SECOND
#      3.773   PROCEDURAL             PRODUCTION-FIRED SKIP-THIRD
#      3.823   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#      3.873   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK6
#      3.964   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK0-0
#      4.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#      4.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION2 NIL
#      4.014   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      4.064   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#      4.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT2 NIL
#      4.155   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK3-0
#      4.214   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK7
#      4.264   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#      4.314   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#      4.464   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUN
PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     12.395   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     12.545   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK26
#     12.595   PROCEDURAL             PRODUCTION-FIRED REPLACE-SECOND
#     12.795   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK27
#     12.845   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-2
#     12.895   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     13.136   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK12-0
#     13.186   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     13.236   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     13.386   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK28
#     13.934   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK27-0
#     13.984   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     14.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#     14.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION7 NIL
#     14.034   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     14.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT6 NIL
#     14.184   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK29
#     14.460   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK22-0
#     14.510   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     14.560   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     14.710   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK30
#     14.756   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK8-0
#     14.806   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     14.856   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     15.006   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK31
#     15.058   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK12-0
#     15.108   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     15.158   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     15.308   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK32
#     15.573   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK27-0
#     15.623   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     15.673   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     15.823   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK33
#     15.928   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK22-0
#     15.978   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     16.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#     16.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION8 NIL
#     16.028   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     16.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT7 NIL
#     16.178   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK34
#     16.222   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK8-0
#     16.272   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     16.322   PROCEDURAL             PRODUCTION-FIRED ATTEND-NEW-WORD
#     16.472   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK35
#     16.522   PROCEDURAL             PRODUCTION-FIRED REPLACE-THIRD
#     16.722   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK36
#     16.772   PROCEDURAL             PRODUCTION-FIRED ADD-TO-MEMORY-3
#     16.822   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     16.961   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK12-0
#     17.011   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     17.061   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     17.211   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK37
#     17.382   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK27-0
#     17.432   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     17.482   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     17.632   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK38
#     18.000   ------                 Stopped because time limit reached
# #|Warning: run-time must be a number greater than zero. |#
#     18.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION9 NIL
#     18.085   VISION                 SET-BUFFER-CHUNK VISUAL TEXT8 NIL
#     18.462   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK36-0
#     18.512   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     18.562   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FOURTH
#     18.712   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK39
#     18.777   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK8-0
#     18.827   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     18.877   PROCEDURAL             PRODUCTION-FIRED REHEARSE-FIRST
#     19.011   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK12-0
#     19.027   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK40
#     19.077   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     19.127   PROCEDURAL             PRODUCTION-FIRED REHEARSE-SECOND
#     19.277   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK41
#     19.397   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK27-0
#     19.447   PROCEDURAL             PRODUCTION-FIRED RETRIEVE-IT
#     19.497   PROCEDURAL             PRODUCTION-FIRED REHEARSE-THIRD
#     19.647   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK42
#     19.969   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL CHUNK36-0
#     20.000   ------                 Stopped because time limit reached
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d3fe33484cc8> in <module>
#       8
#       9     try:
# ---> 10         num_recalled, num_unique, results = do_experiment('controls',False,list_amount)
#      11         total_recalled += num_recalled
#      12         total_unique += num_unique
#
# <ipython-input-4-059fea3d032b> in do_experiment(subj, human, wlist_amount)
#     296                 color = "red"
#     297             actr.add_text_to_exp_window(window, word, x=475-len(word) , y=374, color=color, font_size=20) # change later
# --> 298             actr.run(rehearsal_time, human) # True when choosing Human, False when choosing differently
#     299             actr.clear_exp_window(window)
#     300             actr.run(delay, human)  # 500-ms blank screen
#
# ~\Documents\Education\RUG\First-Year_Research\My_Project\Model\actr.py in run(time, real_time)
#     425
#     426 def run (time, real_time=False):
# --> 427     return current_connection.evaluate("run", time, real_time)
#     428
#     429 def run_full_time (time, real_time=False):
#
# ~\Documents\Education\RUG\First-Year_Research\My_Project\Model\actr.py in evaluate(self, *params)
#      43         p.insert(1,m)
#      44
# ---> 45         r = self.interface.send ("evaluate", *p)
#      46
#      47         if r[0] == False:
#
# ~\Documents\Education\RUG\First-Year_Research\My_Project\Model\actr.py in send(self, method, *params)
#     255
#     256         while not r.complete:
# --> 257           r.cv.wait()
#     258
#     259         return [r.success] + r.results
#
# ~\anaconda3\lib\threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ##### do_experiment flow:
#
# 1. check_and_create_lists
# 	a. create_lists
# 	   return word_lists_dict
# 		i. add_words
#             adds to word_lists_dict
#
# 2. setup_experiment
#     return window
#
#
# 3. setup_dm
#
#
# 4. prepare_for_recall
#
#
# 5. close_exp_window
#
#
# 6. analysis
#     return result_dict
#         contains pstart, pstay, pstop
#     prints Avg recall transitions
#
#     prints Avg negative thought train length
